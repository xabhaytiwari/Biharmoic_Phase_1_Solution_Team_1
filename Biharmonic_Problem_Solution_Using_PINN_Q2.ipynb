# %%
import torch
import numpy as np

class NN(torch.nn.Module):
  def __init__(self) -> None:
    super(NN, self).__init__()
    self.L1 = torch.nn.Linear(2, 60) # Wider
    self.L2 = torch.nn.Linear(60, 60)
    self.L3 = torch.nn.Linear(60, 60)
    self.L4 = torch.nn.Linear(60, 60)
    self.L5 = torch.nn.Linear(60, 60) # Deeper
    self.L6 = torch.nn.Linear(60, 1)

  def forward(self, x, y):
    inputs = torch.cat([x, y], axis=1)
    x1 = torch.tanh(self.L1(inputs))
    x2 = torch.tanh(self.L2(x1))
    x3 = torch.tanh(self.L3(x2))
    x4 = torch.tanh(self.L4(x3))
    x5 = torch.tanh(self.L5(x4))
    x6 = self.L6(x5)
    return x6

  def init_weights(m):
    if isinstance(m, torch.nn.Linear):
      torch.nn.init.xavier_uniform_(m.weight)
      m.bias.data.fill_(0.0)

# %% [markdown]
# We'll gather Inputs, Collocation points, PDE Data and Balancing Parameter alpha.

# %%
from sympy import symbols, diff, sin, pi, lambdify

x1, x2 = symbols('x1 x2')
# u = (1 / (2 * (pi ** 2))) * sin(pi * x1) * sin(pi * x2)
u = (x1 ** 2) * (x2 ** 2) * ((1 - x1) ** 2) * ((1 - x2) ** 2)

laplacian_u = diff(u, x1, 2) + diff(u, x2, 2)
bi_laplacian_u = diff(laplacian_u, x1, 2) + diff(laplacian_u, x2, 2)

f_sym = bi_laplacian_u

u_x_sym = diff(u, x1)
u_y_sym = diff(u, x2)

u_xx_sym = diff(u, x1, 2)
u_yy_sym = diff(u, x2, 2)
u_xy_sym = diff(u, x1, x2)

ldu = lambdify((x1, x2), u, 'numpy')
ldu_x = lambdify((x1, x2), u_x_sym, 'numpy')
ldu_y = lambdify((x1, x2), u_y_sym, 'numpy')
ldf = lambdify((x1, x2), f_sym, 'numpy')

ldu_xx = lambdify((x1, x2), u_xx_sym, 'numpy')
ldu_yy = lambdify((x1, x2), u_yy_sym, 'numpy')
ldu_xy = lambdify((x1, x2), u_xy_sym, 'numpy')

def from_seq_to_array(items):
    out = []
    for item in items:
        out.append(np.array(item).reshape(-1, 1))
    if len(out) == 1:
        return out[0]
    return out


def data_gen_interior(collocations):
    u_gt = [ldu(x, y) for x, y in collocations]
    f_gt = [ldf(x, y) for x, y in collocations]
    return from_seq_to_array([u_gt, f_gt])

def data_gen_bdry(collocations, normal_vec):
    ybdry_vals_g1       = []
    ybdry_vals_g2       = []

    for (x, y), (n1, n2) in zip(collocations, normal_vec):
        ybdry_vals_g1.append(ldu(x, y))
        ybdry_vals_g2.append(ldu_x(x, y) * n1 + ldu_y(x, y) * n2)

    return from_seq_to_array([ybdry_vals_g1, ybdry_vals_g2])

# %%
import pickle as pkl
from scipy.stats import uniform
import os

N = 20000
dataname = '20000pts'

domain_data_x = uniform.rvs(size=N)
domain_data_y = uniform.rvs(size=N)

domain_data = np.array([domain_data_x,domain_data_y]).T
print(domain_data.shape)


Nb = 10000

def generate_random_bdry(Nb):
    '''
    Generate random boundary points.
    '''
    bdry_col = uniform.rvs(size=Nb*2).reshape([Nb,2])
    for i in range(Nb):
        randind = np.random.randint(0,2)
        if bdry_col[i,randind] <= 0.5:
            bdry_col[i,randind] = 0.0
        else:
            bdry_col[i,randind] = 1.0

    return bdry_col


def compute_normals(bdry_col, eps=1e-8):
    """
    Given bdry_col of shape (Nb,2) with points on the edges of [0,1]^2,
    returns two arrays n1,n2 of shape (Nb,1) giving the outward unit normals.

    Assumes:
      - if x ≈ 0 → normal = (-1, 0)
      - if x ≈ 1 → normal = ( 1, 0)
      - if y ≈ 0 → normal = ( 0,-1)
      - if y ≈ 1 → normal = ( 0, 1)
    """
    x = bdry_col[:, 0]
    y = bdry_col[:, 1]

    n1 = np.zeros_like(x)
    n2 = np.zeros_like(y)

    # left edge x=0
    mask = np.isclose(x, 0.0, atol=eps)
    n1[mask] = -1.0;  n2[mask] =  0.0

    # right edge x=1
    mask = np.isclose(x, 1.0, atol=eps)
    n1[mask] =  1.0;  n2[mask] =  0.0

    # bottom edge y=0
    mask = np.isclose(y, 0.0, atol=eps)
    n1[mask] =  0.0;  n2[mask] = -1.0

    # top edge y=1
    mask = np.isclose(y, 1.0, atol=eps)
    n1[mask] =  0.0;  n2[mask] =  1.0

    # reshape to column vectors
    return n1.reshape(-1,1), n2.reshape(-1,1)

bdry_col = generate_random_bdry(Nb)
n1_np, n2_np = compute_normals(bdry_col)
normal_vec = np.hstack([n1_np, n2_np])

print(normal_vec.shape)
print(bdry_col.shape)

if not os.path.exists('dataset/'):
    os.makedirs('dataset/')
with open('dataset/'+dataname,'wb') as pfile:
    pkl.dump(domain_data,pfile)
    pkl.dump(bdry_col,pfile)
    pkl.dump(normal_vec,pfile)


ugt,fgt = data_gen_interior(domain_data)
dirichlet_data, clamped_data = data_gen_bdry(bdry_col,normal_vec)


with open("dataset/gt_on_{}".format(dataname),'wb') as pfile:
    pkl.dump(ugt,pfile)
    pkl.dump(fgt,pfile)
    pkl.dump(dirichlet_data,pfile)
    pkl.dump(clamped_data,pfile)
# Out:
# (20000, 2)
# (10000, 2)
# (10000, 2)

# %%
mse_loss = torch.nn.MSELoss()

def pde(x1, x2, net):
    """
    Compute Δ²u = (u_xx + u_yy)_xx + (u_xx + u_yy)_yy
    at the points (x1, x2) via automatic differentiation.
    """
    # 1) forward pass
    u = net(x1, x2)

    # 2) first derivatives
    # u_x, u_y = torch.autograd.grad(
    #     u.sum(), (x1, x2), create_graph=True
    # )
    u_x = torch.autograd.grad(u.sum(), x1, create_graph=True)[0]
    u_y = torch.autograd.grad(u.sum(), x2, create_graph=True)[0]

    # 3) second derivatives
    u_xx = torch.autograd.grad(u_x.sum(), x1, create_graph=True)[0]
    u_yy = torch.autograd.grad(u_y.sum(), x2, create_graph=True)[0]

    # 4) Laplacian
    lap = u_xx + u_yy

    # 5) third derivatives of lap
    # lap_x, lap_y = torch.autograd.grad(
    #     lap.sum(), (x1, x2), create_graph=True
    # )
    lap_x = torch.autograd.grad(lap.sum(), x1, create_graph=True)[0]
    lap_y = torch.autograd.grad(lap.sum(), x2, create_graph=True)[0]

    # 6) fourth derivatives (bi‐Laplacian pieces)
    lap_xx = torch.autograd.grad(lap_x.sum(), x1, create_graph=True)[0]
    lap_yy = torch.autograd.grad(lap_y.sum(), x2, create_graph=True)[0]



    return lap_xx +  lap_yy



def bdry(x1,x2,n1,n2,net):
    out = net(x1,x2)
    u_x = torch.autograd.grad(out.sum(),x1,create_graph=True)[0]
    u_y = torch.autograd.grad(out.sum(),x2,create_graph=True)[0]

    return out, u_x*n1 + u_y*n2


def pdeloss(net,intx1,intx2,pdedata,bdx1,bdx2,nx1,nx2,bdrydata_diri,bdrydat_clamped,bw_diri,bw_clamped):
    bdx1  = bdx1.requires_grad_(True)
    bdx2  = bdx2.requires_grad_(True)
    pout = pde(intx1,intx2,net)
    bout_diri, bout_clamped = bdry(bdx1,bdx2,nx1,nx2,net)
    pres = mse_loss(pout,pdedata)
    bres = bw_diri*mse_loss(bout_diri,bdrydata_diri) + bw_clamped*mse_loss(bout_clamped,bdrydat_clamped)
    diri_loss = mse_loss(bout_diri,bdrydata_diri)
    clamped_loss = mse_loss(bout_clamped,bdrydat_clamped)


    loss = pres + bres

    return loss, pres, bres, diri_loss, clamped_loss

# %%
from torch.autograd import Variable

def from_numpy_to_tensor(numpys,require_grads,dtype=torch.float32):
    outputs = list()
    for ind in range(len(numpys)):
        outputs.append(
            Variable(torch.from_numpy(numpys[ind]),requires_grad=require_grads[ind]).type(dtype)
        )

    return outputs

# %%
from time import time
from tracemalloc import start
import numpy as np
import torch
from torch.utils.data import TensorDataset
import torch.optim as opt
import matplotlib.pyplot as plt
import torch.utils.data.dataset as Dataset
import torch.utils.data.dataloader as Dataloader
from torch.autograd import Variable
import pickle as pkl
from mpl_toolkits.mplot3d import Axes3D
from matplotlib import cm
from matplotlib.ticker import LinearLocator, FormatStrFormatter
from time import time
from torch.utils.data import TensorDataset

import os
os.environ['KMP_DUPLICATE_LIB_OK']='True'

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Using device: {device}")
torch.set_default_dtype(torch.float32)
start_time = time()

y = NN()
y.apply(NN.init_weights)
y.to(device)

dataname = '20000pts'
name = 'results/'
bw_dir = 1e4   # Start with 10,000
bw_clamp = 1e4 # Start with 10,000

if not os.path.exists(name):
    os.makedirs(name)
if not os.path.exists(name+"y_plot/"):
    os.makedirs(name+"y_plot/")

params = list(y.parameters())

# --- 1. Load all data from files ---
with open("dataset/"+dataname,'rb') as pfile:
    int_col = pkl.load(pfile)
    bdry_col = pkl.load(pfile)
    normal_vec = pkl.load(pfile)

with open("dataset/gt_on_{}".format(dataname),'rb') as pfile:
    u_gt_np = pkl.load(pfile)
    f_np = pkl.load(pfile)
    dirichlet_data_np = pkl.load(pfile)
    clamped_data_np = pkl.load(pfile)

print(f"Interior points: {int_col.shape}")
print(f"Boundary points: {bdry_col.shape}")
print(f"Forcing term: {f_np.shape}")
print(f"Dirichlet data: {dirichlet_data_np.shape}")
print(f"Clamped data: {clamped_data_np.shape}")

def compute_derivatives(net, x, y):
    """ Computes u, 1st, and 2nd derivatives """
    u = net(x, y)

    # 1st derivatives
    u_x, u_y = torch.autograd.grad(
        u.sum(), (x, y), create_graph=True
    )

    # 2nd derivatives
    u_xx = torch.autograd.grad(u_x.sum(), x, create_graph=True)[0]
    u_yy = torch.autograd.grad(u_y.sum(), y, create_graph=True)[0]
    u_xy = torch.autograd.grad(u_x.sum(), y, create_graph=True)[0]

    return u, u_x, u_y, u_xx, u_yy, u_xy

# --- 2. Create Tensors and DataLoaders ---

# Create a TensorDataset for INTERIOR points AND their forcing term ---
intx1_np, intx2_np = np.split(int_col, 2, axis=1)

# Convert interior data to tensors (no grad needed here, will be set in loop)
tintx1 = torch.from_numpy(intx1_np).float()
tintx2 = torch.from_numpy(intx2_np).float()
f_tensor = torch.from_numpy(f_np).float()

# Create a dataset and loader for interior points
interior_dataset = TensorDataset(tintx1, tintx2, f_tensor)
loader = torch.utils.data.DataLoader(interior_dataset, batch_size=2000, shuffle=True)


# Create Tensors for BOUNDARY data (with requires_grad=True) ---
bdx1_np, bdx2_np = np.split(bdry_col, 2, axis=1)
nx1_np, nx2_np = np.split(normal_vec, 2, axis=1)

# Boundary coordinates MUST have requires_grad=True
# Normals and ground truth data do NOT need gradients.
[tbdx1, tbdx2] = from_numpy_to_tensor([bdx1_np, bdx2_np], [True, True], dtype=torch.float32)
[tnx1, tnx2] = from_numpy_to_tensor([nx1_np, nx2_np], [False, False], dtype=torch.float32)
[bdrydata_dirichlet, bdrydata_clamped] = from_numpy_to_tensor(
    [dirichlet_data_np, clamped_data_np], [False, False], dtype=torch.float32
)

# Move all *full* boundary tensors to the device once
tbdx1 = tbdx1.to(device)
tbdx2 = tbdx2.to(device)
tnx1 = tnx1.to(device)
tnx2 = tnx2.to(device)
bdrydata_dirichlet = bdrydata_dirichlet.to(device)
bdrydata_clamped = bdrydata_clamped.to(device)

# Note: We won't use ygt for training, only for final error calculation
ygt = torch.from_numpy(u_gt_np).float().to(device)

optimizer = opt.Adam(params, lr=1e-3)
scheduler = opt.lr_scheduler.ReduceLROnPlateau(optimizer, patience=400)
train_start_time = time()
# --- 3. Define the Closure ---
def closure():
    tot_loss = 0
    tot_pres = 0
    tot_diri_loss = 0
    tot_clamped_loss = 0

    # Iterate over the DataLoader
    for i, (intx1_batch, intx2_batch, f_batch) in enumerate(loader):
       optimizer.zero_grad()

       # Set requires_grad=True for the BATCH coordinates
       ttintx1 = intx1_batch.to(device).requires_grad_(True)
       ttintx2 = intx2_batch.to(device).requires_grad_(True)

       # This is the ground-truth forcing term for the batch
       f_gt_batch = f_batch.to(device)

       # --- Pass the correct batch data to the loss function ---
       # We use the *batched* interior points and *batched* forcing term
       # We use the *full* set of boundary points
       loss, pres, bres, diri_loss, clamped_loss = pdeloss(
           y,
           ttintx1, ttintx2, f_gt_batch,  # Batched interior data
           tbdx1, tbdx2, tnx1, tnx2,     # Full boundary data
           bdrydata_dirichlet, bdrydata_clamped,
           bw_dir, bw_clamp
       )

       loss.backward()
       optimizer.step()

       # Detach losses to free memory
       tot_loss += loss.detach()
       tot_pres += pres.detach()
       tot_diri_loss += diri_loss.detach()
       tot_clamped_loss += clamped_loss.detach()

    # Get the average loss per batch
    num_batches = len(loader)
    avg_loss = tot_loss / num_batches
    avg_pres = tot_pres / num_batches
    avg_diri = tot_diri_loss / num_batches
    avg_clamp = tot_clamped_loss / num_batches

    # scheduler.step() uses the average loss
    scheduler.step(avg_loss)

    return (
        avg_loss.cpu().numpy(),
        avg_pres.cpu().numpy(),
        avg_diri.cpu().numpy(),
        avg_clamp.cpu().numpy()
    )

# --- 4. Run the Training Loop ---
losslist = list()
print("Starting training...")
for epoch in range(8000):
    loss, presloss, diri_loss, clamped_loss = closure()
    losslist.append(loss)
    if epoch % 10 == 0:
         print(f"Epoch {epoch} | Total loss: {loss:.8f} | Loss_int: {presloss:.8f} | Loss_Clamped: {clamped_loss:.8f} | Loss_dirichlet: {diri_loss:.8f}")
train_end_time = time()
print("Training finished.")
with open("results/loss.pkl",'wb') as pfile:
    pkl.dump(losslist,pfile)

# --- (After training is finished) ---

print("Calculating final errors...")

# Use the same grid as your plots
x_pts = np.linspace(0,1,200)
y_pts = np.linspace(0,1,200)
ms_x, ms_y = np.meshgrid(x_pts,y_pts)
x_flat = np.ravel(ms_x).reshape(-1,1)
y_flat = np.ravel(ms_y).reshape(-1,1)
collocations = np.concatenate([x_flat, y_flat], axis=1)

# --- 1. Get Ground Truth (GT) values ---
u_gt_np = ldu(x_flat, y_flat).flatten()
ux_gt_np = ldu_x(x_flat, y_flat).flatten()
uy_gt_np = ldu_y(x_flat, y_flat).flatten()
uxx_gt_np = ldu_xx(x_flat, y_flat).flatten()
uyy_gt_np = ldu_yy(x_flat, y_flat).flatten()
uxy_gt_np = ldu_xy(x_flat, y_flat).flatten()

# --- 2. Get Network Prediction (NN) values ---
pt_x = torch.from_numpy(x_flat).float().to(device).requires_grad_(True)
pt_y = torch.from_numpy(y_flat).float().to(device).requires_grad_(True)

u_nn, ux_nn, uy_nn, uxx_nn, uyy_nn, uxy_nn = compute_derivatives(y, pt_x, pt_y)

u_nn_np = u_nn.data.cpu().numpy().flatten()
ux_nn_np = ux_nn.data.cpu().numpy().flatten()
uy_nn_np = uy_nn.data.cpu().numpy().flatten()
uxx_nn_np = uxx_nn.data.cpu().numpy().flatten()
uyy_nn_np = uyy_nn.data.cpu().numpy().flatten()
uxy_nn_np = uxy_nn.data.cpu().numpy().flatten()

# --- 3. Compute Errors ---
# L2 Error
l2_error_u = np.sqrt(np.mean((u_gt_np - u_nn_np)**2))
l2_error = l2_error_u / np.sqrt(np.mean(u_gt_np**2))

# H1 Error
l2_error_ux = np.sqrt(np.mean((ux_gt_np - ux_nn_np)**2))
l2_error_uy = np.sqrt(np.mean((uy_gt_np - uy_nn_np)**2))
h1_error = np.sqrt(l2_error_u**2 + l2_error_ux**2 + l2_error_uy**2) / \
           np.sqrt(np.mean(u_gt_np**2) + np.mean(ux_gt_np**2) + np.mean(uy_gt_np**2))

# H2 Error
l2_error_uxx = np.sqrt(np.mean((uxx_gt_np - uxx_nn_np)**2))
l2_error_uyy = np.sqrt(np.mean((uyy_gt_np - uyy_nn_np)**2))
l2_error_uxy = np.sqrt(np.mean((uxy_gt_np - uxy_nn_np)**2))
h2_error = np.sqrt(l2_error_u**2 + l2_error_ux**2 + l2_error_uy**2 + \
                   l2_error_uxx**2 + l2_error_uyy**2 + l2_error_uxy**2) / \
           np.sqrt(np.mean(u_gt_np**2) + np.mean(ux_gt_np**2) + np.mean(uy_gt_np**2) + \
                   np.mean(uxx_gt_np**2) + np.mean(uyy_gt_np**2) + np.mean(uxy_gt_np**2))

print(f"Relative L2 Error: {l2_error:.4e}")
print(f"Relative H1 Error: {h1_error:.4e}")
print(f"Relative H2 Error: {h2_error:.4e}")

# --- 4. Reshape for Plotting ---
ms_ysol = u_nn_np.reshape(ms_x.shape)
ms_ugt = u_gt_np.reshape(ms_x.shape)

# --- Plot Loss History ---
print("Plotting loss history...")
fig_loss = plt.figure(figsize=(10, 6))
plt.plot(losslist)
plt.yscale('log') # Log scale is essential for loss plots
plt.title('Training Loss Dynamics')
plt.xlabel('Epoch')
plt.ylabel('Total Loss')
plt.grid(True, which="both", ls="--")
plt.savefig(name + 'loss_history_q2.png')
plt.close(fig_loss)

end_time = time()

print("\n---Training Summary ---")
print(f"Device: {device}")
print("\n[Network Architecture]")
print(y)
print("\n[Hyperparameters]")
print(f"  Optimizer: Adam (lr={1e-3})")
print(f"  Epochs (Adam): {8000}")
print(f"  Batch Size: {2000}")
print(f"  Interior Points: {int_col.shape[0]}")
print(f"  Boundary Points: {bdry_col.shape[0]}")
print(f"  Loss Weight (Dirichlet): {bw_dir:.1e}")
print(f"  Loss Weight (Clamped): {bw_clamp:.1e}")
print("\n[Performance]")
print(f"  Training Time: {train_end_time - train_start_time:.2f} seconds")
print(f"  Total Script Time: {end_time - start_time:.2f} seconds")
print(f"  Final Total Loss: {losslist[-1]:.4e}")
print(f"  Relative L2 Error: {l2_error:.4e}")
print(f"  Relative H1 Error: {h1_error:.4e}")
print(f"  Relative H2 Error: {h2_error:.4e}")

print("Plotting 3D solution comparison...")

fig = plt.figure(figsize=(18, 7))

# --- Plot 1: NN Solution ---
ax1 = fig.add_subplot(1, 2, 1, projection='3d')
surf1 = ax1.plot_surface(ms_x, ms_y, ms_ysol, cmap=cm.viridis,
                         linewidth=0, antialiased=False)
ax1.set_title('Neural Network Solution (u_nn)')
ax1.set_xlabel('x')
ax1.set_ylabel('y')
ax1.set_zlabel('u')
fig.colorbar(surf1, ax=ax1, shrink=0.5, aspect=5)

# --- Plot 2: Known Solution ---
ax2 = fig.add_subplot(1, 2, 2, projection='3d')
surf2 = ax2.plot_surface(ms_x, ms_y, ms_ugt, cmap=cm.viridis,
                         linewidth=0, antialiased=False)
ax2.set_title('Known Solution (u_gt)')
ax2.set_xlabel('x')
ax2.set_ylabel('y')
ax2.set_zlabel('u')
fig.colorbar(surf2, ax=ax2, shrink=0.5, aspect=5)

plt.savefig(name + '3D_solution_comparison_q2.png')
plt.close(fig)
# Out:
# Using device: cpu
# Interior points: (20000, 2)
# Boundary points: (10000, 2)
# Forcing term: (20000, 1)
# Dirichlet data: (10000, 1)
# Clamped data: (10000, 1)
# Starting training...
# Epoch 0 | Total loss: 82.95237732 | Loss_int: 5.91091299 | Loss_Clamped: 0.00545572 | Loss_dirichlet: 0.00224842
# Epoch 10 | Total loss: 5.64945745 | Loss_int: 5.57969761 | Loss_Clamped: 0.00000675 | Loss_dirichlet: 0.00000023
# Epoch 20 | Total loss: 5.44384098 | Loss_int: 5.36277485 | Loss_Clamped: 0.00000762 | Loss_dirichlet: 0.00000049
# Epoch 30 | Total loss: 8.22957039 | Loss_int: 4.87245417 | Loss_Clamped: 0.00011543 | Loss_dirichlet: 0.00022028
# Epoch 40 | Total loss: 4.44453526 | Loss_int: 4.13913679 | Loss_Clamped: 0.00002566 | Loss_dirichlet: 0.00000487
# Epoch 50 | Total loss: 4.20758915 | Loss_int: 3.90334558 | Loss_Clamped: 0.00002353 | Loss_dirichlet: 0.00000690
# Epoch 60 | Total loss: 3.96280169 | Loss_int: 3.70212603 | Loss_Clamped: 0.00001827 | Loss_dirichlet: 0.00000780
# Epoch 70 | Total loss: 3.68873143 | Loss_int: 3.45056987 | Loss_Clamped: 0.00001409 | Loss_dirichlet: 0.00000972
# Epoch 80 | Total loss: 4.40425587 | Loss_int: 2.99382424 | Loss_Clamped: 0.00005782 | Loss_dirichlet: 0.00008322
# Epoch 90 | Total loss: 2.70597959 | Loss_int: 2.50483418 | Loss_Clamped: 0.00001595 | Loss_dirichlet: 0.00000416
# Epoch 100 | Total loss: 2.24992251 | Loss_int: 1.95906675 | Loss_Clamped: 0.00002630 | Loss_dirichlet: 0.00000278
# Epoch 110 | Total loss: 1.45856404 | Loss_int: 1.20488322 | Loss_Clamped: 0.00002433 | Loss_dirichlet: 0.00000104
# Epoch 120 | Total loss: 1.18667960 | Loss_int: 0.98217553 | Loss_Clamped: 0.00001979 | Loss_dirichlet: 0.00000066
# Epoch 130 | Total loss: 1.07029247 | Loss_int: 0.88229561 | Loss_Clamped: 0.00001825 | Loss_dirichlet: 0.00000055
# Epoch 140 | Total loss: 0.99789602 | Loss_int: 0.81094790 | Loss_Clamped: 0.00001732 | Loss_dirichlet: 0.00000138
# Epoch 150 | Total loss: 1.82081759 | Loss_int: 0.78130442 | Loss_Clamped: 0.00004713 | Loss_dirichlet: 0.00005683
# Epoch 160 | Total loss: 0.82672846 | Loss_int: 0.68426412 | Loss_Clamped: 0.00001372 | Loss_dirichlet: 0.00000052
# Epoch 170 | Total loss: 0.80294484 | Loss_int: 0.61411750 | Loss_Clamped: 0.00001532 | Loss_dirichlet: 0.00000356
# Epoch 180 | Total loss: 0.71908188 | Loss_int: 0.58863401 | Loss_Clamped: 0.00001230 | Loss_dirichlet: 0.00000075
# Epoch 190 | Total loss: 0.69990909 | Loss_int: 0.53232658 | Loss_Clamped: 0.00001500 | Loss_dirichlet: 0.00000176
# Epoch 200 | Total loss: 0.68068534 | Loss_int: 0.52354574 | Loss_Clamped: 0.00001191 | Loss_dirichlet: 0.00000381
# Epoch 210 | Total loss: 0.58350337 | Loss_int: 0.46587944 | Loss_Clamped: 0.00001121 | Loss_dirichlet: 0.00000055
# Epoch 220 | Total loss: 0.59588814 | Loss_int: 0.45306176 | Loss_Clamped: 0.00001289 | Loss_dirichlet: 0.00000139
# Epoch 230 | Total loss: 0.57584709 | Loss_int: 0.45899382 | Loss_Clamped: 0.00000927 | Loss_dirichlet: 0.00000241
# Epoch 240 | Total loss: 0.52694046 | Loss_int: 0.44089705 | Loss_Clamped: 0.00000830 | Loss_dirichlet: 0.00000031
# Epoch 250 | Total loss: 0.52758038 | Loss_int: 0.43267661 | Loss_Clamped: 0.00000877 | Loss_dirichlet: 0.00000072
# Epoch 260 | Total loss: 0.50808203 | Loss_int: 0.43381754 | Loss_Clamped: 0.00000711 | Loss_dirichlet: 0.00000031
# Epoch 270 | Total loss: 0.55281514 | Loss_int: 0.42589825 | Loss_Clamped: 0.00000886 | Loss_dirichlet: 0.00000383
# Epoch 280 | Total loss: 0.88253850 | Loss_int: 0.43207279 | Loss_Clamped: 0.00003069 | Loss_dirichlet: 0.00001436
# Epoch 290 | Total loss: 0.50670147 | Loss_int: 0.42546710 | Loss_Clamped: 0.00000670 | Loss_dirichlet: 0.00000142
# Epoch 300 | Total loss: 1.89169860 | Loss_int: 0.42709073 | Loss_Clamped: 0.00005760 | Loss_dirichlet: 0.00008887
# Epoch 310 | Total loss: 0.50900191 | Loss_int: 0.41567659 | Loss_Clamped: 0.00000801 | Loss_dirichlet: 0.00000132
# Epoch 320 | Total loss: 0.49468598 | Loss_int: 0.40907273 | Loss_Clamped: 0.00000643 | Loss_dirichlet: 0.00000213
# Epoch 330 | Total loss: 1.26074231 | Loss_int: 0.41251263 | Loss_Clamped: 0.00006226 | Loss_dirichlet: 0.00002257
# Epoch 340 | Total loss: 0.46913233 | Loss_int: 0.40939790 | Loss_Clamped: 0.00000499 | Loss_dirichlet: 0.00000098
# Epoch 350 | Total loss: 1.33501852 | Loss_int: 0.40375090 | Loss_Clamped: 0.00002055 | Loss_dirichlet: 0.00007258
# Epoch 360 | Total loss: 0.46100944 | Loss_int: 0.40010887 | Loss_Clamped: 0.00000546 | Loss_dirichlet: 0.00000063
# Epoch 370 | Total loss: 0.78934693 | Loss_int: 0.39797467 | Loss_Clamped: 0.00001107 | Loss_dirichlet: 0.00002807
# Epoch 380 | Total loss: 0.77925009 | Loss_int: 0.39645162 | Loss_Clamped: 0.00001440 | Loss_dirichlet: 0.00002388
# Epoch 390 | Total loss: 0.59141988 | Loss_int: 0.39074296 | Loss_Clamped: 0.00000922 | Loss_dirichlet: 0.00001084
# Epoch 400 | Total loss: 0.44299746 | Loss_int: 0.38779372 | Loss_Clamped: 0.00000422 | Loss_dirichlet: 0.00000130
# Epoch 410 | Total loss: 0.43498382 | Loss_int: 0.38579702 | Loss_Clamped: 0.00000427 | Loss_dirichlet: 0.00000065
# Epoch 420 | Total loss: 0.42784888 | Loss_int: 0.38299233 | Loss_Clamped: 0.00000390 | Loss_dirichlet: 0.00000058
# Epoch 430 | Total loss: 0.52083588 | Loss_int: 0.38076600 | Loss_Clamped: 0.00000861 | Loss_dirichlet: 0.00000539
# Epoch 440 | Total loss: 0.54431683 | Loss_int: 0.38275442 | Loss_Clamped: 0.00001158 | Loss_dirichlet: 0.00000458
# Epoch 450 | Total loss: 0.43248662 | Loss_int: 0.37499300 | Loss_Clamped: 0.00000363 | Loss_dirichlet: 0.00000212
# Epoch 460 | Total loss: 0.50075591 | Loss_int: 0.36850992 | Loss_Clamped: 0.00000547 | Loss_dirichlet: 0.00000776
# Epoch 470 | Total loss: 0.44725400 | Loss_int: 0.36727867 | Loss_Clamped: 0.00000618 | Loss_dirichlet: 0.00000182
# Epoch 480 | Total loss: 1.07058513 | Loss_int: 0.36826125 | Loss_Clamped: 0.00005064 | Loss_dirichlet: 0.00001959
# Epoch 490 | Total loss: 0.39005160 | Loss_int: 0.35401475 | Loss_Clamped: 0.00000297 | Loss_dirichlet: 0.00000063
# Epoch 500 | Total loss: 0.92147195 | Loss_int: 0.34941086 | Loss_Clamped: 0.00003097 | Loss_dirichlet: 0.00002623
# Epoch 510 | Total loss: 0.85726100 | Loss_int: 0.35840482 | Loss_Clamped: 0.00002098 | Loss_dirichlet: 0.00002890
# Epoch 520 | Total loss: 0.35864693 | Loss_int: 0.32828525 | Loss_Clamped: 0.00000254 | Loss_dirichlet: 0.00000050
# Epoch 530 | Total loss: 1.14788210 | Loss_int: 0.31739688 | Loss_Clamped: 0.00004415 | Loss_dirichlet: 0.00003890
# Epoch 540 | Total loss: 0.72632718 | Loss_int: 0.29986504 | Loss_Clamped: 0.00001792 | Loss_dirichlet: 0.00002473
# Epoch 550 | Total loss: 0.39045283 | Loss_int: 0.29579735 | Loss_Clamped: 0.00000531 | Loss_dirichlet: 0.00000415
# Epoch 560 | Total loss: 2.02222848 | Loss_int: 0.27740529 | Loss_Clamped: 0.00010856 | Loss_dirichlet: 0.00006592
# Epoch 570 | Total loss: 0.45683861 | Loss_int: 0.22101739 | Loss_Clamped: 0.00001242 | Loss_dirichlet: 0.00001116
# Epoch 580 | Total loss: 0.26593250 | Loss_int: 0.18943205 | Loss_Clamped: 0.00000221 | Loss_dirichlet: 0.00000544
# Epoch 590 | Total loss: 0.20349857 | Loss_int: 0.16705459 | Loss_Clamped: 0.00000224 | Loss_dirichlet: 0.00000141
# Epoch 600 | Total loss: 0.18476635 | Loss_int: 0.15455951 | Loss_Clamped: 0.00000182 | Loss_dirichlet: 0.00000120
# Epoch 610 | Total loss: 0.22779889 | Loss_int: 0.13443507 | Loss_Clamped: 0.00000570 | Loss_dirichlet: 0.00000363
# Epoch 620 | Total loss: 0.22885557 | Loss_int: 0.09877829 | Loss_Clamped: 0.00000510 | Loss_dirichlet: 0.00000791
# Epoch 630 | Total loss: 0.26109967 | Loss_int: 0.09024148 | Loss_Clamped: 0.00000969 | Loss_dirichlet: 0.00000739
# Epoch 640 | Total loss: 0.15197314 | Loss_int: 0.07968687 | Loss_Clamped: 0.00000476 | Loss_dirichlet: 0.00000246
# Epoch 650 | Total loss: 0.12912576 | Loss_int: 0.07717265 | Loss_Clamped: 0.00000367 | Loss_dirichlet: 0.00000152
# Epoch 660 | Total loss: 0.09314048 | Loss_int: 0.07344380 | Loss_Clamped: 0.00000123 | Loss_dirichlet: 0.00000074
# Epoch 670 | Total loss: 0.11467328 | Loss_int: 0.07351695 | Loss_Clamped: 0.00000296 | Loss_dirichlet: 0.00000116
# Epoch 680 | Total loss: 1.14951205 | Loss_int: 0.08984941 | Loss_Clamped: 0.00002321 | Loss_dirichlet: 0.00008275
# Epoch 690 | Total loss: 0.28468484 | Loss_int: 0.07020241 | Loss_Clamped: 0.00001585 | Loss_dirichlet: 0.00000560
# Epoch 700 | Total loss: 0.07863291 | Loss_int: 0.06052782 | Loss_Clamped: 0.00000133 | Loss_dirichlet: 0.00000048
# Epoch 710 | Total loss: 0.07206837 | Loss_int: 0.05713034 | Loss_Clamped: 0.00000106 | Loss_dirichlet: 0.00000043
# Epoch 720 | Total loss: 0.09312757 | Loss_int: 0.06291961 | Loss_Clamped: 0.00000149 | Loss_dirichlet: 0.00000153
# Epoch 730 | Total loss: 0.06962652 | Loss_int: 0.05392835 | Loss_Clamped: 0.00000120 | Loss_dirichlet: 0.00000037
# Epoch 740 | Total loss: 0.06339097 | Loss_int: 0.05108205 | Loss_Clamped: 0.00000091 | Loss_dirichlet: 0.00000032
# Epoch 750 | Total loss: 0.45066053 | Loss_int: 0.06089094 | Loss_Clamped: 0.00002713 | Loss_dirichlet: 0.00001185
# Epoch 760 | Total loss: 0.11258601 | Loss_int: 0.05384845 | Loss_Clamped: 0.00000399 | Loss_dirichlet: 0.00000188
# Epoch 770 | Total loss: 0.05587244 | Loss_int: 0.04415343 | Loss_Clamped: 0.00000091 | Loss_dirichlet: 0.00000026
# Epoch 780 | Total loss: 0.05506217 | Loss_int: 0.04384302 | Loss_Clamped: 0.00000085 | Loss_dirichlet: 0.00000027
# Epoch 790 | Total loss: 0.82387698 | Loss_int: 0.05155554 | Loss_Clamped: 0.00004943 | Loss_dirichlet: 0.00002781
# Epoch 800 | Total loss: 0.12700555 | Loss_int: 0.04225581 | Loss_Clamped: 0.00000296 | Loss_dirichlet: 0.00000552
# Epoch 810 | Total loss: 0.04922905 | Loss_int: 0.03645758 | Loss_Clamped: 0.00000092 | Loss_dirichlet: 0.00000035
# Epoch 820 | Total loss: 0.04723686 | Loss_int: 0.03742495 | Loss_Clamped: 0.00000077 | Loss_dirichlet: 0.00000021
# Epoch 830 | Total loss: 0.06929951 | Loss_int: 0.03554920 | Loss_Clamped: 0.00000256 | Loss_dirichlet: 0.00000082
# Epoch 840 | Total loss: 0.05059598 | Loss_int: 0.03211017 | Loss_Clamped: 0.00000143 | Loss_dirichlet: 0.00000042
# Epoch 850 | Total loss: 0.20968819 | Loss_int: 0.03216544 | Loss_Clamped: 0.00001266 | Loss_dirichlet: 0.00000509
# Epoch 860 | Total loss: 0.31556717 | Loss_int: 0.03555981 | Loss_Clamped: 0.00001825 | Loss_dirichlet: 0.00000975
# Epoch 870 | Total loss: 0.15410089 | Loss_int: 0.02924708 | Loss_Clamped: 0.00000535 | Loss_dirichlet: 0.00000714
# Epoch 880 | Total loss: 0.04423852 | Loss_int: 0.02732695 | Loss_Clamped: 0.00000126 | Loss_dirichlet: 0.00000043
# Epoch 890 | Total loss: 0.03639879 | Loss_int: 0.02547741 | Loss_Clamped: 0.00000088 | Loss_dirichlet: 0.00000022
# Epoch 900 | Total loss: 0.41459903 | Loss_int: 0.03240756 | Loss_Clamped: 0.00001225 | Loss_dirichlet: 0.00002597
# Epoch 910 | Total loss: 0.47076312 | Loss_int: 0.03434176 | Loss_Clamped: 0.00003281 | Loss_dirichlet: 0.00001084
# Epoch 920 | Total loss: 0.02952310 | Loss_int: 0.02159725 | Loss_Clamped: 0.00000067 | Loss_dirichlet: 0.00000013
# Epoch 930 | Total loss: 0.04412698 | Loss_int: 0.02038980 | Loss_Clamped: 0.00000185 | Loss_dirichlet: 0.00000053
# Epoch 940 | Total loss: 0.06229370 | Loss_int: 0.02380787 | Loss_Clamped: 0.00000255 | Loss_dirichlet: 0.00000130
# Epoch 950 | Total loss: 0.27858394 | Loss_int: 0.02099494 | Loss_Clamped: 0.00001869 | Loss_dirichlet: 0.00000707
# Epoch 960 | Total loss: 0.04140553 | Loss_int: 0.01847311 | Loss_Clamped: 0.00000171 | Loss_dirichlet: 0.00000058
# Epoch 970 | Total loss: 0.06638260 | Loss_int: 0.01598140 | Loss_Clamped: 0.00000381 | Loss_dirichlet: 0.00000123
# Epoch 980 | Total loss: 0.03301619 | Loss_int: 0.01490411 | Loss_Clamped: 0.00000148 | Loss_dirichlet: 0.00000033
# Epoch 990 | Total loss: 0.02578057 | Loss_int: 0.01484489 | Loss_Clamped: 0.00000094 | Loss_dirichlet: 0.00000015
# Epoch 1000 | Total loss: 0.38563100 | Loss_int: 0.01991504 | Loss_Clamped: 0.00002458 | Loss_dirichlet: 0.00001199
# Epoch 1010 | Total loss: 0.08578314 | Loss_int: 0.01449261 | Loss_Clamped: 0.00000454 | Loss_dirichlet: 0.00000259
# Epoch 1020 | Total loss: 0.15025428 | Loss_int: 0.01616133 | Loss_Clamped: 0.00001007 | Loss_dirichlet: 0.00000334
# Epoch 1030 | Total loss: 0.02718949 | Loss_int: 0.01156903 | Loss_Clamped: 0.00000112 | Loss_dirichlet: 0.00000044
# Epoch 1040 | Total loss: 0.12741336 | Loss_int: 0.01407778 | Loss_Clamped: 0.00000814 | Loss_dirichlet: 0.00000319
# Epoch 1050 | Total loss: 0.27447304 | Loss_int: 0.01967928 | Loss_Clamped: 0.00001886 | Loss_dirichlet: 0.00000662
# Epoch 1060 | Total loss: 0.16856971 | Loss_int: 0.01394686 | Loss_Clamped: 0.00000650 | Loss_dirichlet: 0.00000896
# Epoch 1070 | Total loss: 0.01870174 | Loss_int: 0.01097086 | Loss_Clamped: 0.00000071 | Loss_dirichlet: 0.00000006
# Epoch 1080 | Total loss: 0.03207898 | Loss_int: 0.01020861 | Loss_Clamped: 0.00000151 | Loss_dirichlet: 0.00000068
# Epoch 1090 | Total loss: 0.11699411 | Loss_int: 0.01319945 | Loss_Clamped: 0.00000794 | Loss_dirichlet: 0.00000244
# Epoch 1100 | Total loss: 0.40727615 | Loss_int: 0.04188547 | Loss_Clamped: 0.00002703 | Loss_dirichlet: 0.00000951
# Epoch 1110 | Total loss: 0.01605548 | Loss_int: 0.00961368 | Loss_Clamped: 0.00000062 | Loss_dirichlet: 0.00000002
# Epoch 1120 | Total loss: 0.02955547 | Loss_int: 0.00950693 | Loss_Clamped: 0.00000158 | Loss_dirichlet: 0.00000043
# Epoch 1130 | Total loss: 0.02582135 | Loss_int: 0.01014766 | Loss_Clamped: 0.00000126 | Loss_dirichlet: 0.00000031
# Epoch 1140 | Total loss: 0.04323258 | Loss_int: 0.01002338 | Loss_Clamped: 0.00000261 | Loss_dirichlet: 0.00000071
# Epoch 1150 | Total loss: 0.07748460 | Loss_int: 0.01055180 | Loss_Clamped: 0.00000519 | Loss_dirichlet: 0.00000150
# Epoch 1160 | Total loss: 0.03568324 | Loss_int: 0.01433193 | Loss_Clamped: 0.00000161 | Loss_dirichlet: 0.00000053
# Epoch 1170 | Total loss: 0.04234869 | Loss_int: 0.00902661 | Loss_Clamped: 0.00000239 | Loss_dirichlet: 0.00000095
# Epoch 1180 | Total loss: 0.03387484 | Loss_int: 0.00917837 | Loss_Clamped: 0.00000200 | Loss_dirichlet: 0.00000047
# Epoch 1190 | Total loss: 0.36720780 | Loss_int: 0.02276422 | Loss_Clamped: 0.00002313 | Loss_dirichlet: 0.00001131
# Epoch 1200 | Total loss: 0.09794327 | Loss_int: 0.00982680 | Loss_Clamped: 0.00000669 | Loss_dirichlet: 0.00000212
# Epoch 1210 | Total loss: 0.04087060 | Loss_int: 0.00968981 | Loss_Clamped: 0.00000182 | Loss_dirichlet: 0.00000130
# Epoch 1220 | Total loss: 0.02682911 | Loss_int: 0.00781582 | Loss_Clamped: 0.00000139 | Loss_dirichlet: 0.00000051
# Epoch 1230 | Total loss: 0.02617818 | Loss_int: 0.00933277 | Loss_Clamped: 0.00000130 | Loss_dirichlet: 0.00000038
# Epoch 1240 | Total loss: 0.02561635 | Loss_int: 0.00777822 | Loss_Clamped: 0.00000128 | Loss_dirichlet: 0.00000050
# Epoch 1250 | Total loss: 0.15767430 | Loss_int: 0.01713443 | Loss_Clamped: 0.00000893 | Loss_dirichlet: 0.00000512
# Epoch 1260 | Total loss: 0.13551646 | Loss_int: 0.01639791 | Loss_Clamped: 0.00000833 | Loss_dirichlet: 0.00000359
# Epoch 1270 | Total loss: 0.21789901 | Loss_int: 0.01403660 | Loss_Clamped: 0.00001307 | Loss_dirichlet: 0.00000732
# Epoch 1280 | Total loss: 0.01421986 | Loss_int: 0.00779826 | Loss_Clamped: 0.00000061 | Loss_dirichlet: 0.00000003
# Epoch 1290 | Total loss: 0.06439994 | Loss_int: 0.01007554 | Loss_Clamped: 0.00000328 | Loss_dirichlet: 0.00000215
# Epoch 1300 | Total loss: 0.20513490 | Loss_int: 0.01680006 | Loss_Clamped: 0.00000884 | Loss_dirichlet: 0.00000999
# Epoch 1310 | Total loss: 0.03392312 | Loss_int: 0.00809179 | Loss_Clamped: 0.00000193 | Loss_dirichlet: 0.00000065
# Epoch 1320 | Total loss: 0.08404613 | Loss_int: 0.01523795 | Loss_Clamped: 0.00000379 | Loss_dirichlet: 0.00000309
# Epoch 1330 | Total loss: 0.18459328 | Loss_int: 0.02113095 | Loss_Clamped: 0.00001208 | Loss_dirichlet: 0.00000427
# Epoch 1340 | Total loss: 0.02490354 | Loss_int: 0.00713842 | Loss_Clamped: 0.00000137 | Loss_dirichlet: 0.00000041
# Epoch 1350 | Total loss: 0.02226275 | Loss_int: 0.00741544 | Loss_Clamped: 0.00000101 | Loss_dirichlet: 0.00000047
# Epoch 1360 | Total loss: 0.01390433 | Loss_int: 0.00664254 | Loss_Clamped: 0.00000063 | Loss_dirichlet: 0.00000009
# Epoch 1370 | Total loss: 0.01579043 | Loss_int: 0.00713062 | Loss_Clamped: 0.00000077 | Loss_dirichlet: 0.00000010
# Epoch 1380 | Total loss: 0.02783927 | Loss_int: 0.00742425 | Loss_Clamped: 0.00000164 | Loss_dirichlet: 0.00000040
# Epoch 1390 | Total loss: 0.09396975 | Loss_int: 0.01576177 | Loss_Clamped: 0.00000522 | Loss_dirichlet: 0.00000260
# Epoch 1400 | Total loss: 0.02267499 | Loss_int: 0.00704700 | Loss_Clamped: 0.00000105 | Loss_dirichlet: 0.00000051
# Epoch 1410 | Total loss: 0.08403184 | Loss_int: 0.00980570 | Loss_Clamped: 0.00000571 | Loss_dirichlet: 0.00000171
# Epoch 1420 | Total loss: 0.06958482 | Loss_int: 0.00892773 | Loss_Clamped: 0.00000380 | Loss_dirichlet: 0.00000226
# Epoch 1430 | Total loss: 0.08466040 | Loss_int: 0.01659990 | Loss_Clamped: 0.00000540 | Loss_dirichlet: 0.00000141
# Epoch 1440 | Total loss: 0.26918831 | Loss_int: 0.02528301 | Loss_Clamped: 0.00001804 | Loss_dirichlet: 0.00000635
# Epoch 1450 | Total loss: 0.03437958 | Loss_int: 0.00730046 | Loss_Clamped: 0.00000133 | Loss_dirichlet: 0.00000138
# Epoch 1460 | Total loss: 0.12591536 | Loss_int: 0.01501867 | Loss_Clamped: 0.00000744 | Loss_dirichlet: 0.00000365
# Epoch 1470 | Total loss: 0.01399262 | Loss_int: 0.00676520 | Loss_Clamped: 0.00000067 | Loss_dirichlet: 0.00000005
# Epoch 1480 | Total loss: 0.01273351 | Loss_int: 0.00598791 | Loss_Clamped: 0.00000061 | Loss_dirichlet: 0.00000006
# Epoch 1490 | Total loss: 0.03015639 | Loss_int: 0.00784590 | Loss_Clamped: 0.00000163 | Loss_dirichlet: 0.00000060
# Epoch 1500 | Total loss: 0.01330678 | Loss_int: 0.00585095 | Loss_Clamped: 0.00000067 | Loss_dirichlet: 0.00000008
# Epoch 1510 | Total loss: 0.04407417 | Loss_int: 0.01546841 | Loss_Clamped: 0.00000233 | Loss_dirichlet: 0.00000053
# Epoch 1520 | Total loss: 0.04418653 | Loss_int: 0.00675693 | Loss_Clamped: 0.00000260 | Loss_dirichlet: 0.00000114
# Epoch 1530 | Total loss: 0.14538188 | Loss_int: 0.01757301 | Loss_Clamped: 0.00000869 | Loss_dirichlet: 0.00000409
# Epoch 1540 | Total loss: 0.09359681 | Loss_int: 0.00830228 | Loss_Clamped: 0.00000415 | Loss_dirichlet: 0.00000438
# Epoch 1550 | Total loss: 0.05032120 | Loss_int: 0.00803215 | Loss_Clamped: 0.00000256 | Loss_dirichlet: 0.00000167
# Epoch 1560 | Total loss: 0.03476485 | Loss_int: 0.01466562 | Loss_Clamped: 0.00000152 | Loss_dirichlet: 0.00000049
# Epoch 1570 | Total loss: 0.07277690 | Loss_int: 0.00719385 | Loss_Clamped: 0.00000339 | Loss_dirichlet: 0.00000317
# Epoch 1580 | Total loss: 0.01307289 | Loss_int: 0.00568839 | Loss_Clamped: 0.00000061 | Loss_dirichlet: 0.00000012
# Epoch 1590 | Total loss: 0.07091239 | Loss_int: 0.00895104 | Loss_Clamped: 0.00000307 | Loss_dirichlet: 0.00000313
# Epoch 1600 | Total loss: 0.01293428 | Loss_int: 0.00699205 | Loss_Clamped: 0.00000055 | Loss_dirichlet: 0.00000005
# Epoch 1610 | Total loss: 0.01123363 | Loss_int: 0.00532629 | Loss_Clamped: 0.00000057 | Loss_dirichlet: 0.00000002
# Epoch 1620 | Total loss: 0.02544024 | Loss_int: 0.00721084 | Loss_Clamped: 0.00000130 | Loss_dirichlet: 0.00000052
# Epoch 1630 | Total loss: 0.02517475 | Loss_int: 0.00561883 | Loss_Clamped: 0.00000138 | Loss_dirichlet: 0.00000058
# Epoch 1640 | Total loss: 0.02621395 | Loss_int: 0.00539803 | Loss_Clamped: 0.00000124 | Loss_dirichlet: 0.00000084
# Epoch 1650 | Total loss: 0.08595235 | Loss_int: 0.00773971 | Loss_Clamped: 0.00000472 | Loss_dirichlet: 0.00000310
# Epoch 1660 | Total loss: 0.01743329 | Loss_int: 0.00608115 | Loss_Clamped: 0.00000088 | Loss_dirichlet: 0.00000026
# Epoch 1670 | Total loss: 0.09999301 | Loss_int: 0.00900662 | Loss_Clamped: 0.00000417 | Loss_dirichlet: 0.00000493
# Epoch 1680 | Total loss: 0.01857696 | Loss_int: 0.00592767 | Loss_Clamped: 0.00000092 | Loss_dirichlet: 0.00000035
# Epoch 1690 | Total loss: 0.04030813 | Loss_int: 0.01641707 | Loss_Clamped: 0.00000194 | Loss_dirichlet: 0.00000045
# Epoch 1700 | Total loss: 0.01146730 | Loss_int: 0.00560865 | Loss_Clamped: 0.00000056 | Loss_dirichlet: 0.00000002
# Epoch 1710 | Total loss: 0.01575659 | Loss_int: 0.00540821 | Loss_Clamped: 0.00000084 | Loss_dirichlet: 0.00000019
# Epoch 1720 | Total loss: 0.07230683 | Loss_int: 0.01718562 | Loss_Clamped: 0.00000445 | Loss_dirichlet: 0.00000106
# Epoch 1730 | Total loss: 0.01126710 | Loss_int: 0.00511300 | Loss_Clamped: 0.00000057 | Loss_dirichlet: 0.00000004
# Epoch 1740 | Total loss: 0.98062390 | Loss_int: 0.30974454 | Loss_Clamped: 0.00003964 | Loss_dirichlet: 0.00002745
# Epoch 1750 | Total loss: 0.01703285 | Loss_int: 0.01182843 | Loss_Clamped: 0.00000048 | Loss_dirichlet: 0.00000004
# Epoch 1760 | Total loss: 0.01240902 | Loss_int: 0.00681921 | Loss_Clamped: 0.00000053 | Loss_dirichlet: 0.00000003
# Epoch 1770 | Total loss: 0.01113604 | Loss_int: 0.00528211 | Loss_Clamped: 0.00000055 | Loss_dirichlet: 0.00000003
# Epoch 1780 | Total loss: 0.01293731 | Loss_int: 0.00518204 | Loss_Clamped: 0.00000065 | Loss_dirichlet: 0.00000013
# Epoch 1790 | Total loss: 0.01055788 | Loss_int: 0.00472912 | Loss_Clamped: 0.00000055 | Loss_dirichlet: 0.00000003
# Epoch 1800 | Total loss: 0.01137661 | Loss_int: 0.00455936 | Loss_Clamped: 0.00000061 | Loss_dirichlet: 0.00000007
# Epoch 1810 | Total loss: 0.01088305 | Loss_int: 0.00477361 | Loss_Clamped: 0.00000057 | Loss_dirichlet: 0.00000004
# Epoch 1820 | Total loss: 0.01137929 | Loss_int: 0.00474773 | Loss_Clamped: 0.00000059 | Loss_dirichlet: 0.00000007
# Epoch 1830 | Total loss: 0.01503267 | Loss_int: 0.00519340 | Loss_Clamped: 0.00000074 | Loss_dirichlet: 0.00000025
# Epoch 1840 | Total loss: 0.01453665 | Loss_int: 0.00506914 | Loss_Clamped: 0.00000067 | Loss_dirichlet: 0.00000028
# Epoch 1850 | Total loss: 0.03563097 | Loss_int: 0.00793087 | Loss_Clamped: 0.00000195 | Loss_dirichlet: 0.00000082
# Epoch 1860 | Total loss: 0.01167265 | Loss_int: 0.00482625 | Loss_Clamped: 0.00000058 | Loss_dirichlet: 0.00000011
# Epoch 1870 | Total loss: 0.01322645 | Loss_int: 0.00519687 | Loss_Clamped: 0.00000067 | Loss_dirichlet: 0.00000014
# Epoch 1880 | Total loss: 0.13340974 | Loss_int: 0.00965365 | Loss_Clamped: 0.00000529 | Loss_dirichlet: 0.00000709
# Epoch 1890 | Total loss: 0.01323595 | Loss_int: 0.00554100 | Loss_Clamped: 0.00000070 | Loss_dirichlet: 0.00000007
# Epoch 1900 | Total loss: 0.07661391 | Loss_int: 0.00967737 | Loss_Clamped: 0.00000450 | Loss_dirichlet: 0.00000219
# Epoch 1910 | Total loss: 0.02676011 | Loss_int: 0.01021410 | Loss_Clamped: 0.00000130 | Loss_dirichlet: 0.00000035
# Epoch 1920 | Total loss: 0.01144086 | Loss_int: 0.00508515 | Loss_Clamped: 0.00000055 | Loss_dirichlet: 0.00000008
# Epoch 1930 | Total loss: 0.01011014 | Loss_int: 0.00468231 | Loss_Clamped: 0.00000051 | Loss_dirichlet: 0.00000004
# Epoch 1940 | Total loss: 0.01082594 | Loss_int: 0.00467310 | Loss_Clamped: 0.00000056 | Loss_dirichlet: 0.00000006
# Epoch 1950 | Total loss: 0.01759539 | Loss_int: 0.00542010 | Loss_Clamped: 0.00000082 | Loss_dirichlet: 0.00000040
# Epoch 1960 | Total loss: 0.01816192 | Loss_int: 0.00483751 | Loss_Clamped: 0.00000095 | Loss_dirichlet: 0.00000038
# Epoch 1970 | Total loss: 0.04087118 | Loss_int: 0.00788319 | Loss_Clamped: 0.00000237 | Loss_dirichlet: 0.00000093
# Epoch 1980 | Total loss: 0.03424259 | Loss_int: 0.00660043 | Loss_Clamped: 0.00000149 | Loss_dirichlet: 0.00000127
# Epoch 1990 | Total loss: 0.03240189 | Loss_int: 0.00549278 | Loss_Clamped: 0.00000131 | Loss_dirichlet: 0.00000138
# Epoch 2000 | Total loss: 0.02558762 | Loss_int: 0.00656543 | Loss_Clamped: 0.00000141 | Loss_dirichlet: 0.00000049
# Epoch 2010 | Total loss: 0.01284883 | Loss_int: 0.00467852 | Loss_Clamped: 0.00000068 | Loss_dirichlet: 0.00000014
# Epoch 2020 | Total loss: 0.04799985 | Loss_int: 0.01186586 | Loss_Clamped: 0.00000242 | Loss_dirichlet: 0.00000119
# Epoch 2030 | Total loss: 0.22283587 | Loss_int: 0.03242552 | Loss_Clamped: 0.00001442 | Loss_dirichlet: 0.00000462
# Epoch 2040 | Total loss: 0.01371833 | Loss_int: 0.00480569 | Loss_Clamped: 0.00000057 | Loss_dirichlet: 0.00000032
# Epoch 2050 | Total loss: 0.02247469 | Loss_int: 0.00815993 | Loss_Clamped: 0.00000119 | Loss_dirichlet: 0.00000024
# Epoch 2060 | Total loss: 0.06846742 | Loss_int: 0.01640593 | Loss_Clamped: 0.00000329 | Loss_dirichlet: 0.00000192
# Epoch 2070 | Total loss: 0.03849219 | Loss_int: 0.00967088 | Loss_Clamped: 0.00000208 | Loss_dirichlet: 0.00000080
# Epoch 2080 | Total loss: 0.00967210 | Loss_int: 0.00449797 | Loss_Clamped: 0.00000048 | Loss_dirichlet: 0.00000003
# Epoch 2090 | Total loss: 0.03092980 | Loss_int: 0.00742571 | Loss_Clamped: 0.00000114 | Loss_dirichlet: 0.00000121
# Epoch 2100 | Total loss: 0.01383004 | Loss_int: 0.00465892 | Loss_Clamped: 0.00000073 | Loss_dirichlet: 0.00000019
# Epoch 2110 | Total loss: 0.01412668 | Loss_int: 0.00412098 | Loss_Clamped: 0.00000069 | Loss_dirichlet: 0.00000031
# Epoch 2120 | Total loss: 3.89337611 | Loss_int: 2.86351633 | Loss_Clamped: 0.00007467 | Loss_dirichlet: 0.00002832
# Epoch 2130 | Total loss: 0.53680438 | Loss_int: 0.43034425 | Loss_Clamped: 0.00000994 | Loss_dirichlet: 0.00000070
# Epoch 2140 | Total loss: 0.31231752 | Loss_int: 0.26070982 | Loss_Clamped: 0.00000447 | Loss_dirichlet: 0.00000069
# Epoch 2150 | Total loss: 0.20092931 | Loss_int: 0.17041478 | Loss_Clamped: 0.00000237 | Loss_dirichlet: 0.00000068
# Epoch 2160 | Total loss: 0.14612579 | Loss_int: 0.12550883 | Loss_Clamped: 0.00000158 | Loss_dirichlet: 0.00000048
# Epoch 2170 | Total loss: 0.11186185 | Loss_int: 0.09547423 | Loss_Clamped: 0.00000121 | Loss_dirichlet: 0.00000043
# Epoch 2180 | Total loss: 0.09062044 | Loss_int: 0.07644257 | Loss_Clamped: 0.00000098 | Loss_dirichlet: 0.00000044
# Epoch 2190 | Total loss: 0.07814153 | Loss_int: 0.06534467 | Loss_Clamped: 0.00000081 | Loss_dirichlet: 0.00000047
# Epoch 2200 | Total loss: 0.06847098 | Loss_int: 0.05660882 | Loss_Clamped: 0.00000068 | Loss_dirichlet: 0.00000051
# Epoch 2210 | Total loss: 0.06259579 | Loss_int: 0.05150563 | Loss_Clamped: 0.00000060 | Loss_dirichlet: 0.00000051
# Epoch 2220 | Total loss: 0.05660076 | Loss_int: 0.04571787 | Loss_Clamped: 0.00000057 | Loss_dirichlet: 0.00000052
# Epoch 2230 | Total loss: 0.05621846 | Loss_int: 0.04408946 | Loss_Clamped: 0.00000064 | Loss_dirichlet: 0.00000058
# Epoch 2240 | Total loss: 0.04904299 | Loss_int: 0.03862955 | Loss_Clamped: 0.00000053 | Loss_dirichlet: 0.00000051
# Epoch 2250 | Total loss: 0.04682202 | Loss_int: 0.03451299 | Loss_Clamped: 0.00000065 | Loss_dirichlet: 0.00000058
# Epoch 2260 | Total loss: 0.04283721 | Loss_int: 0.03288367 | Loss_Clamped: 0.00000053 | Loss_dirichlet: 0.00000047
# Epoch 2270 | Total loss: 0.03942633 | Loss_int: 0.02921722 | Loss_Clamped: 0.00000056 | Loss_dirichlet: 0.00000046
# Epoch 2280 | Total loss: 0.03903055 | Loss_int: 0.02917800 | Loss_Clamped: 0.00000056 | Loss_dirichlet: 0.00000043
# Epoch 2290 | Total loss: 0.03562210 | Loss_int: 0.02536546 | Loss_Clamped: 0.00000062 | Loss_dirichlet: 0.00000041
# Epoch 2300 | Total loss: 0.04533643 | Loss_int: 0.02344545 | Loss_Clamped: 0.00000122 | Loss_dirichlet: 0.00000097
# Epoch 2310 | Total loss: 0.03073937 | Loss_int: 0.02136659 | Loss_Clamped: 0.00000060 | Loss_dirichlet: 0.00000034
# Epoch 2320 | Total loss: 0.03141611 | Loss_int: 0.02075941 | Loss_Clamped: 0.00000067 | Loss_dirichlet: 0.00000039
# Epoch 2330 | Total loss: 0.03367559 | Loss_int: 0.01840869 | Loss_Clamped: 0.00000101 | Loss_dirichlet: 0.00000051
# Epoch 2340 | Total loss: 0.03058564 | Loss_int: 0.01714389 | Loss_Clamped: 0.00000097 | Loss_dirichlet: 0.00000038
# Epoch 2350 | Total loss: 0.02621067 | Loss_int: 0.01742297 | Loss_Clamped: 0.00000065 | Loss_dirichlet: 0.00000023
# Epoch 2360 | Total loss: 0.03335599 | Loss_int: 0.01568455 | Loss_Clamped: 0.00000122 | Loss_dirichlet: 0.00000054
# Epoch 2370 | Total loss: 0.02643802 | Loss_int: 0.01435984 | Loss_Clamped: 0.00000080 | Loss_dirichlet: 0.00000041
# Epoch 2380 | Total loss: 0.02445786 | Loss_int: 0.01357263 | Loss_Clamped: 0.00000075 | Loss_dirichlet: 0.00000034
# Epoch 2390 | Total loss: 0.02267291 | Loss_int: 0.01241520 | Loss_Clamped: 0.00000080 | Loss_dirichlet: 0.00000023
# Epoch 2400 | Total loss: 0.02061870 | Loss_int: 0.01173547 | Loss_Clamped: 0.00000070 | Loss_dirichlet: 0.00000019
# Epoch 2410 | Total loss: 0.03022559 | Loss_int: 0.01141048 | Loss_Clamped: 0.00000130 | Loss_dirichlet: 0.00000059
# Epoch 2420 | Total loss: 0.02756582 | Loss_int: 0.01095039 | Loss_Clamped: 0.00000122 | Loss_dirichlet: 0.00000045
# Epoch 2430 | Total loss: 0.02145586 | Loss_int: 0.00973590 | Loss_Clamped: 0.00000087 | Loss_dirichlet: 0.00000030
# Epoch 2440 | Total loss: 0.02079999 | Loss_int: 0.00950519 | Loss_Clamped: 0.00000079 | Loss_dirichlet: 0.00000034
# Epoch 2450 | Total loss: 0.01731424 | Loss_int: 0.00814068 | Loss_Clamped: 0.00000072 | Loss_dirichlet: 0.00000019
# Epoch 2460 | Total loss: 0.09019733 | Loss_int: 0.01118570 | Loss_Clamped: 0.00000447 | Loss_dirichlet: 0.00000343
# Epoch 2470 | Total loss: 0.01537636 | Loss_int: 0.00719544 | Loss_Clamped: 0.00000059 | Loss_dirichlet: 0.00000023
# Epoch 2480 | Total loss: 0.01365176 | Loss_int: 0.00663531 | Loss_Clamped: 0.00000060 | Loss_dirichlet: 0.00000010
# Epoch 2490 | Total loss: 0.01190231 | Loss_int: 0.00615909 | Loss_Clamped: 0.00000052 | Loss_dirichlet: 0.00000005
# Epoch 2500 | Total loss: 0.01177442 | Loss_int: 0.00603893 | Loss_Clamped: 0.00000052 | Loss_dirichlet: 0.00000005
# Epoch 2510 | Total loss: 0.01169537 | Loss_int: 0.00595617 | Loss_Clamped: 0.00000052 | Loss_dirichlet: 0.00000005
# Epoch 2520 | Total loss: 0.01156515 | Loss_int: 0.00584598 | Loss_Clamped: 0.00000052 | Loss_dirichlet: 0.00000005
# Epoch 2530 | Total loss: 0.01147739 | Loss_int: 0.00576317 | Loss_Clamped: 0.00000052 | Loss_dirichlet: 0.00000005
# Epoch 2540 | Total loss: 0.01135536 | Loss_int: 0.00565198 | Loss_Clamped: 0.00000052 | Loss_dirichlet: 0.00000005
# Epoch 2550 | Total loss: 0.01126161 | Loss_int: 0.00556351 | Loss_Clamped: 0.00000052 | Loss_dirichlet: 0.00000005
# Epoch 2560 | Total loss: 0.01115354 | Loss_int: 0.00546599 | Loss_Clamped: 0.00000052 | Loss_dirichlet: 0.00000005
# Epoch 2570 | Total loss: 0.01101020 | Loss_int: 0.00533921 | Loss_Clamped: 0.00000052 | Loss_dirichlet: 0.00000005
# Epoch 2580 | Total loss: 0.01091235 | Loss_int: 0.00525279 | Loss_Clamped: 0.00000052 | Loss_dirichlet: 0.00000005
# Epoch 2590 | Total loss: 0.01081990 | Loss_int: 0.00516496 | Loss_Clamped: 0.00000052 | Loss_dirichlet: 0.00000005
# Epoch 2600 | Total loss: 0.01066814 | Loss_int: 0.00503604 | Loss_Clamped: 0.00000052 | Loss_dirichlet: 0.00000005
# Epoch 2610 | Total loss: 0.01051150 | Loss_int: 0.00490222 | Loss_Clamped: 0.00000052 | Loss_dirichlet: 0.00000004
# Epoch 2620 | Total loss: 0.01039531 | Loss_int: 0.00480491 | Loss_Clamped: 0.00000052 | Loss_dirichlet: 0.00000004
# Epoch 2630 | Total loss: 0.01028989 | Loss_int: 0.00471973 | Loss_Clamped: 0.00000052 | Loss_dirichlet: 0.00000004
# Epoch 2640 | Total loss: 0.01011525 | Loss_int: 0.00456561 | Loss_Clamped: 0.00000051 | Loss_dirichlet: 0.00000004
# Epoch 2650 | Total loss: 0.01002375 | Loss_int: 0.00449773 | Loss_Clamped: 0.00000051 | Loss_dirichlet: 0.00000004
# Epoch 2660 | Total loss: 0.00985307 | Loss_int: 0.00435150 | Loss_Clamped: 0.00000051 | Loss_dirichlet: 0.00000004
# Epoch 2670 | Total loss: 0.00969600 | Loss_int: 0.00423013 | Loss_Clamped: 0.00000051 | Loss_dirichlet: 0.00000004
# Epoch 2680 | Total loss: 0.00957872 | Loss_int: 0.00413436 | Loss_Clamped: 0.00000051 | Loss_dirichlet: 0.00000004
# Epoch 2690 | Total loss: 0.00948423 | Loss_int: 0.00407762 | Loss_Clamped: 0.00000050 | Loss_dirichlet: 0.00000004
# Epoch 2700 | Total loss: 0.00929906 | Loss_int: 0.00392977 | Loss_Clamped: 0.00000050 | Loss_dirichlet: 0.00000003
# Epoch 2710 | Total loss: 0.00912403 | Loss_int: 0.00379947 | Loss_Clamped: 0.00000050 | Loss_dirichlet: 0.00000003
# Epoch 2720 | Total loss: 0.00903335 | Loss_int: 0.00374910 | Loss_Clamped: 0.00000050 | Loss_dirichlet: 0.00000003
# Epoch 2730 | Total loss: 0.00885582 | Loss_int: 0.00362295 | Loss_Clamped: 0.00000049 | Loss_dirichlet: 0.00000003
# Epoch 2740 | Total loss: 0.00869958 | Loss_int: 0.00351667 | Loss_Clamped: 0.00000049 | Loss_dirichlet: 0.00000003
# Epoch 2750 | Total loss: 0.00857824 | Loss_int: 0.00345361 | Loss_Clamped: 0.00000048 | Loss_dirichlet: 0.00000003
# Epoch 2760 | Total loss: 0.00846493 | Loss_int: 0.00339772 | Loss_Clamped: 0.00000048 | Loss_dirichlet: 0.00000003
# Epoch 2770 | Total loss: 0.00828092 | Loss_int: 0.00329776 | Loss_Clamped: 0.00000047 | Loss_dirichlet: 0.00000003
# Epoch 2780 | Total loss: 0.00814710 | Loss_int: 0.00321623 | Loss_Clamped: 0.00000047 | Loss_dirichlet: 0.00000002
# Epoch 2790 | Total loss: 0.00799696 | Loss_int: 0.00313767 | Loss_Clamped: 0.00000046 | Loss_dirichlet: 0.00000002
# Epoch 2800 | Total loss: 0.00790511 | Loss_int: 0.00311348 | Loss_Clamped: 0.00000046 | Loss_dirichlet: 0.00000002
# Epoch 2810 | Total loss: 0.00778059 | Loss_int: 0.00306745 | Loss_Clamped: 0.00000045 | Loss_dirichlet: 0.00000002
# Epoch 2820 | Total loss: 0.00758638 | Loss_int: 0.00298949 | Loss_Clamped: 0.00000044 | Loss_dirichlet: 0.00000002
# Epoch 2830 | Total loss: 0.00747687 | Loss_int: 0.00295472 | Loss_Clamped: 0.00000043 | Loss_dirichlet: 0.00000002
# Epoch 2840 | Total loss: 0.00737307 | Loss_int: 0.00293878 | Loss_Clamped: 0.00000043 | Loss_dirichlet: 0.00000002
# Epoch 2850 | Total loss: 0.00723967 | Loss_int: 0.00289521 | Loss_Clamped: 0.00000042 | Loss_dirichlet: 0.00000002
# Epoch 2860 | Total loss: 0.00711357 | Loss_int: 0.00288637 | Loss_Clamped: 0.00000041 | Loss_dirichlet: 0.00000001
# Epoch 2870 | Total loss: 0.00692510 | Loss_int: 0.00281061 | Loss_Clamped: 0.00000040 | Loss_dirichlet: 0.00000001
# Epoch 2880 | Total loss: 0.00681374 | Loss_int: 0.00279914 | Loss_Clamped: 0.00000039 | Loss_dirichlet: 0.00000001
# Epoch 2890 | Total loss: 0.00768029 | Loss_int: 0.00279996 | Loss_Clamped: 0.00000045 | Loss_dirichlet: 0.00000003
# Epoch 2900 | Total loss: 0.00658220 | Loss_int: 0.00277958 | Loss_Clamped: 0.00000037 | Loss_dirichlet: 0.00000001
# Epoch 2910 | Total loss: 0.00751486 | Loss_int: 0.00281856 | Loss_Clamped: 0.00000043 | Loss_dirichlet: 0.00000004
# Epoch 2920 | Total loss: 0.00742375 | Loss_int: 0.00273596 | Loss_Clamped: 0.00000041 | Loss_dirichlet: 0.00000006
# Epoch 2930 | Total loss: 0.00638593 | Loss_int: 0.00268980 | Loss_Clamped: 0.00000034 | Loss_dirichlet: 0.00000003
# Epoch 2940 | Total loss: 0.00614071 | Loss_int: 0.00269327 | Loss_Clamped: 0.00000033 | Loss_dirichlet: 0.00000001
# Epoch 2950 | Total loss: 0.00624716 | Loss_int: 0.00263498 | Loss_Clamped: 0.00000035 | Loss_dirichlet: 0.00000001
# Epoch 2960 | Total loss: 0.00598250 | Loss_int: 0.00261393 | Loss_Clamped: 0.00000033 | Loss_dirichlet: 0.00000001
# Epoch 2970 | Total loss: 0.00746921 | Loss_int: 0.00262268 | Loss_Clamped: 0.00000042 | Loss_dirichlet: 0.00000007
# Epoch 2980 | Total loss: 0.00693518 | Loss_int: 0.00259353 | Loss_Clamped: 0.00000036 | Loss_dirichlet: 0.00000008
# Epoch 2990 | Total loss: 0.00740716 | Loss_int: 0.00261606 | Loss_Clamped: 0.00000039 | Loss_dirichlet: 0.00000008
# Epoch 3000 | Total loss: 0.00585861 | Loss_int: 0.00252468 | Loss_Clamped: 0.00000028 | Loss_dirichlet: 0.00000005
# Epoch 3010 | Total loss: 0.00575887 | Loss_int: 0.00251067 | Loss_Clamped: 0.00000029 | Loss_dirichlet: 0.00000003
# Epoch 3020 | Total loss: 0.00571631 | Loss_int: 0.00250985 | Loss_Clamped: 0.00000030 | Loss_dirichlet: 0.00000002
# Epoch 3030 | Total loss: 0.00519800 | Loss_int: 0.00244584 | Loss_Clamped: 0.00000026 | Loss_dirichlet: 0.00000001
# Epoch 3040 | Total loss: 0.00554510 | Loss_int: 0.00251498 | Loss_Clamped: 0.00000027 | Loss_dirichlet: 0.00000003
# Epoch 3050 | Total loss: 0.00741593 | Loss_int: 0.00247697 | Loss_Clamped: 0.00000040 | Loss_dirichlet: 0.00000010
# Epoch 3060 | Total loss: 0.00520966 | Loss_int: 0.00242094 | Loss_Clamped: 0.00000025 | Loss_dirichlet: 0.00000002
# Epoch 3070 | Total loss: 0.00481496 | Loss_int: 0.00242663 | Loss_Clamped: 0.00000023 | Loss_dirichlet: 0.00000001
# Epoch 3080 | Total loss: 0.00481712 | Loss_int: 0.00243538 | Loss_Clamped: 0.00000022 | Loss_dirichlet: 0.00000001
# Epoch 3090 | Total loss: 0.00461161 | Loss_int: 0.00231419 | Loss_Clamped: 0.00000022 | Loss_dirichlet: 0.00000001
# Epoch 3100 | Total loss: 0.00471613 | Loss_int: 0.00227528 | Loss_Clamped: 0.00000021 | Loss_dirichlet: 0.00000003
# Epoch 3110 | Total loss: 0.00426842 | Loss_int: 0.00224147 | Loss_Clamped: 0.00000019 | Loss_dirichlet: 0.00000001
# Epoch 3120 | Total loss: 0.00469639 | Loss_int: 0.00224882 | Loss_Clamped: 0.00000022 | Loss_dirichlet: 0.00000002
# Epoch 3130 | Total loss: 0.00581939 | Loss_int: 0.00231578 | Loss_Clamped: 0.00000030 | Loss_dirichlet: 0.00000005
# Epoch 3140 | Total loss: 0.00416347 | Loss_int: 0.00223989 | Loss_Clamped: 0.00000018 | Loss_dirichlet: 0.00000001
# Epoch 3150 | Total loss: 0.00453000 | Loss_int: 0.00217164 | Loss_Clamped: 0.00000020 | Loss_dirichlet: 0.00000003
# Epoch 3160 | Total loss: 0.00451258 | Loss_int: 0.00217383 | Loss_Clamped: 0.00000021 | Loss_dirichlet: 0.00000003
# Epoch 3170 | Total loss: 0.00416455 | Loss_int: 0.00216352 | Loss_Clamped: 0.00000017 | Loss_dirichlet: 0.00000003
# Epoch 3180 | Total loss: 0.00374721 | Loss_int: 0.00211691 | Loss_Clamped: 0.00000016 | Loss_dirichlet: 0.00000001
# Epoch 3190 | Total loss: 0.00361892 | Loss_int: 0.00213042 | Loss_Clamped: 0.00000014 | Loss_dirichlet: 0.00000000
# Epoch 3200 | Total loss: 0.00364630 | Loss_int: 0.00204680 | Loss_Clamped: 0.00000015 | Loss_dirichlet: 0.00000001
# Epoch 3210 | Total loss: 0.00692643 | Loss_int: 0.00208619 | Loss_Clamped: 0.00000022 | Loss_dirichlet: 0.00000027
# Epoch 3220 | Total loss: 0.00371511 | Loss_int: 0.00201257 | Loss_Clamped: 0.00000016 | Loss_dirichlet: 0.00000001
# Epoch 3230 | Total loss: 0.00416509 | Loss_int: 0.00201756 | Loss_Clamped: 0.00000018 | Loss_dirichlet: 0.00000004
# Epoch 3240 | Total loss: 0.00339028 | Loss_int: 0.00201654 | Loss_Clamped: 0.00000012 | Loss_dirichlet: 0.00000001
# Epoch 3250 | Total loss: 0.00342255 | Loss_int: 0.00193512 | Loss_Clamped: 0.00000013 | Loss_dirichlet: 0.00000002
# Epoch 3260 | Total loss: 0.00347761 | Loss_int: 0.00191397 | Loss_Clamped: 0.00000012 | Loss_dirichlet: 0.00000003
# Epoch 3270 | Total loss: 0.00317629 | Loss_int: 0.00190797 | Loss_Clamped: 0.00000012 | Loss_dirichlet: 0.00000001
# Epoch 3280 | Total loss: 0.00316308 | Loss_int: 0.00189786 | Loss_Clamped: 0.00000012 | Loss_dirichlet: 0.00000001
# Epoch 3290 | Total loss: 0.00354686 | Loss_int: 0.00186658 | Loss_Clamped: 0.00000013 | Loss_dirichlet: 0.00000004
# Epoch 3300 | Total loss: 0.00297832 | Loss_int: 0.00182816 | Loss_Clamped: 0.00000011 | Loss_dirichlet: 0.00000001
# Epoch 3310 | Total loss: 0.00363743 | Loss_int: 0.00182832 | Loss_Clamped: 0.00000016 | Loss_dirichlet: 0.00000003
# Epoch 3320 | Total loss: 0.00325417 | Loss_int: 0.00182224 | Loss_Clamped: 0.00000012 | Loss_dirichlet: 0.00000002
# Epoch 3330 | Total loss: 0.00294781 | Loss_int: 0.00183098 | Loss_Clamped: 0.00000010 | Loss_dirichlet: 0.00000001
# Epoch 3340 | Total loss: 0.00288703 | Loss_int: 0.00173088 | Loss_Clamped: 0.00000010 | Loss_dirichlet: 0.00000002
# Epoch 3350 | Total loss: 0.00299716 | Loss_int: 0.00173267 | Loss_Clamped: 0.00000011 | Loss_dirichlet: 0.00000002
# Epoch 3360 | Total loss: 0.00278244 | Loss_int: 0.00170046 | Loss_Clamped: 0.00000010 | Loss_dirichlet: 0.00000001
# Epoch 3370 | Total loss: 0.00352518 | Loss_int: 0.00173486 | Loss_Clamped: 0.00000013 | Loss_dirichlet: 0.00000005
# Epoch 3380 | Total loss: 0.00295505 | Loss_int: 0.00166740 | Loss_Clamped: 0.00000011 | Loss_dirichlet: 0.00000002
# Epoch 3390 | Total loss: 0.00384219 | Loss_int: 0.00172008 | Loss_Clamped: 0.00000013 | Loss_dirichlet: 0.00000008
# Epoch 3400 | Total loss: 0.00258954 | Loss_int: 0.00163541 | Loss_Clamped: 0.00000009 | Loss_dirichlet: 0.00000001
# Epoch 3410 | Total loss: 0.00254832 | Loss_int: 0.00162455 | Loss_Clamped: 0.00000009 | Loss_dirichlet: 0.00000001
# Epoch 3420 | Total loss: 0.00406209 | Loss_int: 0.00166388 | Loss_Clamped: 0.00000012 | Loss_dirichlet: 0.00000012
# Epoch 3430 | Total loss: 0.00262875 | Loss_int: 0.00153283 | Loss_Clamped: 0.00000009 | Loss_dirichlet: 0.00000002
# Epoch 3440 | Total loss: 0.00247368 | Loss_int: 0.00153314 | Loss_Clamped: 0.00000008 | Loss_dirichlet: 0.00000001
# Epoch 3450 | Total loss: 0.00237508 | Loss_int: 0.00154340 | Loss_Clamped: 0.00000007 | Loss_dirichlet: 0.00000001
# Epoch 3460 | Total loss: 0.00239302 | Loss_int: 0.00148718 | Loss_Clamped: 0.00000008 | Loss_dirichlet: 0.00000001
# Epoch 3470 | Total loss: 0.00236316 | Loss_int: 0.00149157 | Loss_Clamped: 0.00000008 | Loss_dirichlet: 0.00000001
# Epoch 3480 | Total loss: 0.00317164 | Loss_int: 0.00151537 | Loss_Clamped: 0.00000010 | Loss_dirichlet: 0.00000007
# Epoch 3490 | Total loss: 0.00238191 | Loss_int: 0.00146981 | Loss_Clamped: 0.00000008 | Loss_dirichlet: 0.00000001
# Epoch 3500 | Total loss: 0.00247611 | Loss_int: 0.00144061 | Loss_Clamped: 0.00000009 | Loss_dirichlet: 0.00000001
# Epoch 3510 | Total loss: 0.00261416 | Loss_int: 0.00139313 | Loss_Clamped: 0.00000008 | Loss_dirichlet: 0.00000005
# Epoch 3520 | Total loss: 0.00376459 | Loss_int: 0.00143633 | Loss_Clamped: 0.00000015 | Loss_dirichlet: 0.00000008
# Epoch 3530 | Total loss: 0.00322863 | Loss_int: 0.00142298 | Loss_Clamped: 0.00000012 | Loss_dirichlet: 0.00000006
# Epoch 3540 | Total loss: 0.00250808 | Loss_int: 0.00137856 | Loss_Clamped: 0.00000009 | Loss_dirichlet: 0.00000002
# Epoch 3550 | Total loss: 0.00221561 | Loss_int: 0.00132256 | Loss_Clamped: 0.00000008 | Loss_dirichlet: 0.00000001
# Epoch 3560 | Total loss: 0.00221884 | Loss_int: 0.00129929 | Loss_Clamped: 0.00000007 | Loss_dirichlet: 0.00000002
# Epoch 3570 | Total loss: 0.00212245 | Loss_int: 0.00128733 | Loss_Clamped: 0.00000007 | Loss_dirichlet: 0.00000001
# Epoch 3580 | Total loss: 0.00202726 | Loss_int: 0.00129171 | Loss_Clamped: 0.00000006 | Loss_dirichlet: 0.00000001
# Epoch 3590 | Total loss: 0.00195381 | Loss_int: 0.00128885 | Loss_Clamped: 0.00000006 | Loss_dirichlet: 0.00000000
# Epoch 3600 | Total loss: 0.00197432 | Loss_int: 0.00123123 | Loss_Clamped: 0.00000006 | Loss_dirichlet: 0.00000001
# Epoch 3610 | Total loss: 0.00329350 | Loss_int: 0.00131882 | Loss_Clamped: 0.00000016 | Loss_dirichlet: 0.00000004
# Epoch 3620 | Total loss: 0.00192467 | Loss_int: 0.00118751 | Loss_Clamped: 0.00000006 | Loss_dirichlet: 0.00000001
# Epoch 3630 | Total loss: 0.00212600 | Loss_int: 0.00118929 | Loss_Clamped: 0.00000006 | Loss_dirichlet: 0.00000003
# Epoch 3640 | Total loss: 0.00518883 | Loss_int: 0.00131123 | Loss_Clamped: 0.00000028 | Loss_dirichlet: 0.00000011
# Epoch 3650 | Total loss: 0.00355673 | Loss_int: 0.00121381 | Loss_Clamped: 0.00000010 | Loss_dirichlet: 0.00000014
# Epoch 3660 | Total loss: 0.00188758 | Loss_int: 0.00118820 | Loss_Clamped: 0.00000006 | Loss_dirichlet: 0.00000001
# Epoch 3670 | Total loss: 0.00206196 | Loss_int: 0.00119400 | Loss_Clamped: 0.00000007 | Loss_dirichlet: 0.00000001
# Epoch 3680 | Total loss: 0.00205940 | Loss_int: 0.00114793 | Loss_Clamped: 0.00000007 | Loss_dirichlet: 0.00000002
# Epoch 3690 | Total loss: 0.00209959 | Loss_int: 0.00110854 | Loss_Clamped: 0.00000007 | Loss_dirichlet: 0.00000003
# Epoch 3700 | Total loss: 0.00223255 | Loss_int: 0.00115425 | Loss_Clamped: 0.00000009 | Loss_dirichlet: 0.00000002
# Epoch 3710 | Total loss: 0.00177867 | Loss_int: 0.00104723 | Loss_Clamped: 0.00000006 | Loss_dirichlet: 0.00000002
# Epoch 3720 | Total loss: 0.00199312 | Loss_int: 0.00111397 | Loss_Clamped: 0.00000008 | Loss_dirichlet: 0.00000001
# Epoch 3730 | Total loss: 0.00168857 | Loss_int: 0.00103140 | Loss_Clamped: 0.00000005 | Loss_dirichlet: 0.00000001
# Epoch 3740 | Total loss: 0.00290405 | Loss_int: 0.00103558 | Loss_Clamped: 0.00000008 | Loss_dirichlet: 0.00000011
# Epoch 3750 | Total loss: 0.00164827 | Loss_int: 0.00102875 | Loss_Clamped: 0.00000005 | Loss_dirichlet: 0.00000001
# Epoch 3760 | Total loss: 0.00383882 | Loss_int: 0.00106394 | Loss_Clamped: 0.00000012 | Loss_dirichlet: 0.00000016
# Epoch 3770 | Total loss: 0.00178006 | Loss_int: 0.00102692 | Loss_Clamped: 0.00000007 | Loss_dirichlet: 0.00000001
# Epoch 3780 | Total loss: 0.00321250 | Loss_int: 0.00107801 | Loss_Clamped: 0.00000010 | Loss_dirichlet: 0.00000011
# Epoch 3790 | Total loss: 0.00153252 | Loss_int: 0.00094709 | Loss_Clamped: 0.00000005 | Loss_dirichlet: 0.00000001
# Epoch 3800 | Total loss: 0.00138729 | Loss_int: 0.00091600 | Loss_Clamped: 0.00000004 | Loss_dirichlet: 0.00000000
# Epoch 3810 | Total loss: 0.00393938 | Loss_int: 0.00101087 | Loss_Clamped: 0.00000013 | Loss_dirichlet: 0.00000016
# Epoch 3820 | Total loss: 0.00183021 | Loss_int: 0.00091957 | Loss_Clamped: 0.00000008 | Loss_dirichlet: 0.00000001
# Epoch 3830 | Total loss: 0.00142121 | Loss_int: 0.00087967 | Loss_Clamped: 0.00000005 | Loss_dirichlet: 0.00000001
# Epoch 3840 | Total loss: 0.00149263 | Loss_int: 0.00089697 | Loss_Clamped: 0.00000005 | Loss_dirichlet: 0.00000001
# Epoch 3850 | Total loss: 0.00194023 | Loss_int: 0.00090230 | Loss_Clamped: 0.00000008 | Loss_dirichlet: 0.00000002
# Epoch 3860 | Total loss: 0.00515568 | Loss_int: 0.00100319 | Loss_Clamped: 0.00000019 | Loss_dirichlet: 0.00000023
# Epoch 3870 | Total loss: 0.00175454 | Loss_int: 0.00086388 | Loss_Clamped: 0.00000007 | Loss_dirichlet: 0.00000002
# Epoch 3880 | Total loss: 0.00275116 | Loss_int: 0.00087334 | Loss_Clamped: 0.00000009 | Loss_dirichlet: 0.00000010
# Epoch 3890 | Total loss: 0.00354919 | Loss_int: 0.00092967 | Loss_Clamped: 0.00000014 | Loss_dirichlet: 0.00000013
# Epoch 3900 | Total loss: 0.00129118 | Loss_int: 0.00081397 | Loss_Clamped: 0.00000004 | Loss_dirichlet: 0.00000001
# Epoch 3910 | Total loss: 0.00133407 | Loss_int: 0.00077946 | Loss_Clamped: 0.00000005 | Loss_dirichlet: 0.00000001
# Epoch 3920 | Total loss: 0.00359734 | Loss_int: 0.00086539 | Loss_Clamped: 0.00000022 | Loss_dirichlet: 0.00000006
# Epoch 3930 | Total loss: 0.00130648 | Loss_int: 0.00079562 | Loss_Clamped: 0.00000005 | Loss_dirichlet: 0.00000001
# Epoch 3940 | Total loss: 0.00216261 | Loss_int: 0.00080239 | Loss_Clamped: 0.00000010 | Loss_dirichlet: 0.00000004
# Epoch 3950 | Total loss: 0.00133824 | Loss_int: 0.00073980 | Loss_Clamped: 0.00000005 | Loss_dirichlet: 0.00000001
# Epoch 3960 | Total loss: 0.00386353 | Loss_int: 0.00081552 | Loss_Clamped: 0.00000023 | Loss_dirichlet: 0.00000007
# Epoch 3970 | Total loss: 0.00286980 | Loss_int: 0.00085822 | Loss_Clamped: 0.00000014 | Loss_dirichlet: 0.00000006
# Epoch 3980 | Total loss: 0.00284058 | Loss_int: 0.00077244 | Loss_Clamped: 0.00000008 | Loss_dirichlet: 0.00000013
# Epoch 3990 | Total loss: 0.00116959 | Loss_int: 0.00069314 | Loss_Clamped: 0.00000004 | Loss_dirichlet: 0.00000000
# Epoch 4000 | Total loss: 0.00166497 | Loss_int: 0.00071027 | Loss_Clamped: 0.00000008 | Loss_dirichlet: 0.00000002
# Epoch 4010 | Total loss: 0.00110017 | Loss_int: 0.00067738 | Loss_Clamped: 0.00000004 | Loss_dirichlet: 0.00000000
# Epoch 4020 | Total loss: 0.00219724 | Loss_int: 0.00072077 | Loss_Clamped: 0.00000010 | Loss_dirichlet: 0.00000005
# Epoch 4030 | Total loss: 0.00290971 | Loss_int: 0.00072991 | Loss_Clamped: 0.00000016 | Loss_dirichlet: 0.00000005
# Epoch 4040 | Total loss: 0.00200156 | Loss_int: 0.00071990 | Loss_Clamped: 0.00000008 | Loss_dirichlet: 0.00000005
# Epoch 4050 | Total loss: 0.00129468 | Loss_int: 0.00064281 | Loss_Clamped: 0.00000005 | Loss_dirichlet: 0.00000001
# Epoch 4060 | Total loss: 0.00114919 | Loss_int: 0.00063315 | Loss_Clamped: 0.00000004 | Loss_dirichlet: 0.00000001
# Epoch 4070 | Total loss: 0.00128673 | Loss_int: 0.00061765 | Loss_Clamped: 0.00000005 | Loss_dirichlet: 0.00000001
# Epoch 4080 | Total loss: 0.00118152 | Loss_int: 0.00058378 | Loss_Clamped: 0.00000004 | Loss_dirichlet: 0.00000002
# Epoch 4090 | Total loss: 0.00131425 | Loss_int: 0.00059184 | Loss_Clamped: 0.00000006 | Loss_dirichlet: 0.00000001
# Epoch 4100 | Total loss: 0.00098806 | Loss_int: 0.00060658 | Loss_Clamped: 0.00000003 | Loss_dirichlet: 0.00000000
# Epoch 4110 | Total loss: 0.00104993 | Loss_int: 0.00062160 | Loss_Clamped: 0.00000004 | Loss_dirichlet: 0.00000001
# Epoch 4120 | Total loss: 0.00136392 | Loss_int: 0.00059283 | Loss_Clamped: 0.00000007 | Loss_dirichlet: 0.00000001
# Epoch 4130 | Total loss: 0.00095188 | Loss_int: 0.00056329 | Loss_Clamped: 0.00000003 | Loss_dirichlet: 0.00000001
# Epoch 4140 | Total loss: 0.00348595 | Loss_int: 0.00062345 | Loss_Clamped: 0.00000017 | Loss_dirichlet: 0.00000011
# Epoch 4150 | Total loss: 0.00100418 | Loss_int: 0.00056384 | Loss_Clamped: 0.00000004 | Loss_dirichlet: 0.00000001
# ...
# Epoch 6700 | Total loss: 0.00030291 | Loss_int: 0.00018859 | Loss_Clamped: 0.00000001 | Loss_dirichlet: 0.00000000
# Epoch 6710 | Total loss: 0.00030305 | Loss_int: 0.00018852 | Loss_Clamped: 0.00000001 | Loss_dirichlet: 0.00000000
# Epoch 6720 | Total loss: 0.00030550 | Loss_int: 0.00019021 | Loss_Clamped: 0.00000001 | Loss_dirichlet: 0.00000000
# Epoch 6730 | Total loss: 0.00030172 | Loss_int: 0.00018806 | Loss_Clamped: 0.00000001 | Loss_dirichlet: 0.00000000
# Epoch 6740 | Total loss: 0.00030468 | Loss_int: 0.00018893 | Loss_Clamped: 0.00000001 | Loss_dirichlet: 0.00000000
# Epoch 6750 | Total loss: 0.00030151 | Loss_int: 0.00018803 | Loss_Clamped: 0.00000001 | Loss_dirichlet: 0.00000000
# Epoch 6760 | Total loss: 0.00030009 | Loss_int: 0.00018591 | Loss_Clamped: 0.00000001 | Loss_dirichlet: 0.00000000
# Epoch 6770 | Total loss: 0.00030092 | Loss_int: 0.00018667 | Loss_Clamped: 0.00000001 | Loss_dirichlet: 0.00000000
# Epoch 6780 | Total loss: 0.00030574 | Loss_int: 0.00019024 | Loss_Clamped: 0.00000001 | Loss_dirichlet: 0.00000000
# Epoch 6790 | Total loss: 0.00030100 | Loss_int: 0.00018691 | Loss_Clamped: 0.00000001 | Loss_dirichlet: 0.00000000
# Epoch 6800 | Total loss: 0.00030033 | Loss_int: 0.00018574 | Loss_Clamped: 0.00000001 | Loss_dirichlet: 0.00000000
# Epoch 6810 | Total loss: 0.00029729 | Loss_int: 0.00018542 | Loss_Clamped: 0.00000001 | Loss_dirichlet: 0.00000000
# Epoch 6820 | Total loss: 0.00030013 | Loss_int: 0.00018757 | Loss_Clamped: 0.00000001 | Loss_dirichlet: 0.00000000
# Epoch 6830 | Total loss: 0.00030401 | Loss_int: 0.00018733 | Loss_Clamped: 0.00000001 | Loss_dirichlet: 0.00000000
# Epoch 6840 | Total loss: 0.00029759 | Loss_int: 0.00018348 | Loss_Clamped: 0.00000001 | Loss_dirichlet: 0.00000000
# Epoch 6850 | Total loss: 0.00029924 | Loss_int: 0.00018558 | Loss_Clamped: 0.00000001 | Loss_dirichlet: 0.00000000
# Epoch 6860 | Total loss: 0.00030652 | Loss_int: 0.00018526 | Loss_Clamped: 0.00000001 | Loss_dirichlet: 0.00000000
# Epoch 6870 | Total loss: 0.00030274 | Loss_int: 0.00018551 | Loss_Clamped: 0.00000001 | Loss_dirichlet: 0.00000000
# Epoch 6880 | Total loss: 0.00030195 | Loss_int: 0.00018636 | Loss_Clamped: 0.00000001 | Loss_dirichlet: 0.00000000
# Epoch 6890 | Total loss: 0.00030611 | Loss_int: 0.00018563 | Loss_Clamped: 0.00000001 | Loss_dirichlet: 0.00000000
# Epoch 6900 | Total loss: 0.00030592 | Loss_int: 0.00018659 | Loss_Clamped: 0.00000001 | Loss_dirichlet: 0.00000000
# Epoch 6910 | Total loss: 0.00029911 | Loss_int: 0.00018323 | Loss_Clamped: 0.00000001 | Loss_dirichlet: 0.00000000
# Epoch 6920 | Total loss: 0.00029666 | Loss_int: 0.00018428 | Loss_Clamped: 0.00000001 | Loss_dirichlet: 0.00000000
# Epoch 6930 | Total loss: 0.00029456 | Loss_int: 0.00018252 | Loss_Clamped: 0.00000001 | Loss_dirichlet: 0.00000000
# Epoch 6940 | Total loss: 0.00029557 | Loss_int: 0.00018081 | Loss_Clamped: 0.00000001 | Loss_dirichlet: 0.00000000
# Epoch 6950 | Total loss: 0.00030182 | Loss_int: 0.00018386 | Loss_Clamped: 0.00000001 | Loss_dirichlet: 0.00000000
# Epoch 6960 | Total loss: 0.00030519 | Loss_int: 0.00018266 | Loss_Clamped: 0.00000001 | Loss_dirichlet: 0.00000000
# Epoch 6970 | Total loss: 0.00029311 | Loss_int: 0.00018025 | Loss_Clamped: 0.00000001 | Loss_dirichlet: 0.00000000
# Epoch 6980 | Total loss: 0.00029371 | Loss_int: 0.00018192 | Loss_Clamped: 0.00000001 | Loss_dirichlet: 0.00000000
# Epoch 6990 | Total loss: 0.00029423 | Loss_int: 0.00018027 | Loss_Clamped: 0.00000001 | Loss_dirichlet: 0.00000000
# Epoch 7000 | Total loss: 0.00030150 | Loss_int: 0.00018212 | Loss_Clamped: 0.00000001 | Loss_dirichlet: 0.00000000
# Epoch 7010 | Total loss: 0.00029097 | Loss_int: 0.00017975 | Loss_Clamped: 0.00000001 | Loss_dirichlet: 0.00000000
# Epoch 7020 | Total loss: 0.00029164 | Loss_int: 0.00017970 | Loss_Clamped: 0.00000001 | Loss_dirichlet: 0.00000000
# Epoch 7030 | Total loss: 0.00029344 | Loss_int: 0.00018033 | Loss_Clamped: 0.00000001 | Loss_dirichlet: 0.00000000
# Epoch 7040 | Total loss: 0.00029131 | Loss_int: 0.00017798 | Loss_Clamped: 0.00000001 | Loss_dirichlet: 0.00000000
# Epoch 7050 | Total loss: 0.00029248 | Loss_int: 0.00017923 | Loss_Clamped: 0.00000001 | Loss_dirichlet: 0.00000000
# Epoch 7060 | Total loss: 0.00028658 | Loss_int: 0.00017686 | Loss_Clamped: 0.00000001 | Loss_dirichlet: 0.00000000
# Epoch 7070 | Total loss: 0.00028771 | Loss_int: 0.00017643 | Loss_Clamped: 0.00000001 | Loss_dirichlet: 0.00000000
# Epoch 7080 | Total loss: 0.00028807 | Loss_int: 0.00017767 | Loss_Clamped: 0.00000001 | Loss_dirichlet: 0.00000000
# Epoch 7090 | Total loss: 0.00028598 | Loss_int: 0.00017606 | Loss_Clamped: 0.00000001 | Loss_dirichlet: 0.00000000
# Epoch 7100 | Total loss: 0.00028911 | Loss_int: 0.00017973 | Loss_Clamped: 0.00000001 | Loss_dirichlet: 0.00000000
# Epoch 7110 | Total loss: 0.00028759 | Loss_int: 0.00017532 | Loss_Clamped: 0.00000001 | Loss_dirichlet: 0.00000000
# Epoch 7120 | Total loss: 0.00028198 | Loss_int: 0.00017512 | Loss_Clamped: 0.00000001 | Loss_dirichlet: 0.00000000
# Epoch 7130 | Total loss: 0.00028831 | Loss_int: 0.00017516 | Loss_Clamped: 0.00000001 | Loss_dirichlet: 0.00000000
# Epoch 7140 | Total loss: 0.00028457 | Loss_int: 0.00017402 | Loss_Clamped: 0.00000001 | Loss_dirichlet: 0.00000000
# Epoch 7150 | Total loss: 0.00028608 | Loss_int: 0.00017526 | Loss_Clamped: 0.00000001 | Loss_dirichlet: 0.00000000
# Epoch 7160 | Total loss: 0.00028385 | Loss_int: 0.00017577 | Loss_Clamped: 0.00000001 | Loss_dirichlet: 0.00000000
# Epoch 7170 | Total loss: 0.00028047 | Loss_int: 0.00017341 | Loss_Clamped: 0.00000001 | Loss_dirichlet: 0.00000000
# Epoch 7180 | Total loss: 0.00028694 | Loss_int: 0.00017464 | Loss_Clamped: 0.00000001 | Loss_dirichlet: 0.00000000
# Epoch 7190 | Total loss: 0.00028361 | Loss_int: 0.00017158 | Loss_Clamped: 0.00000001 | Loss_dirichlet: 0.00000000
# Epoch 7200 | Total loss: 0.00027653 | Loss_int: 0.00017168 | Loss_Clamped: 0.00000001 | Loss_dirichlet: 0.00000000
# Epoch 7210 | Total loss: 0.00028249 | Loss_int: 0.00017443 | Loss_Clamped: 0.00000001 | Loss_dirichlet: 0.00000000
# Epoch 7220 | Total loss: 0.00028202 | Loss_int: 0.00017199 | Loss_Clamped: 0.00000001 | Loss_dirichlet: 0.00000000
# Epoch 7230 | Total loss: 0.00028476 | Loss_int: 0.00017306 | Loss_Clamped: 0.00000001 | Loss_dirichlet: 0.00000000
# Epoch 7240 | Total loss: 0.00028336 | Loss_int: 0.00017257 | Loss_Clamped: 0.00000001 | Loss_dirichlet: 0.00000000
# Epoch 7250 | Total loss: 0.00028352 | Loss_int: 0.00017302 | Loss_Clamped: 0.00000001 | Loss_dirichlet: 0.00000000
# Epoch 7260 | Total loss: 0.00027765 | Loss_int: 0.00016958 | Loss_Clamped: 0.00000001 | Loss_dirichlet: 0.00000000
# Epoch 7270 | Total loss: 0.00027740 | Loss_int: 0.00017050 | Loss_Clamped: 0.00000001 | Loss_dirichlet: 0.00000000
# Epoch 7280 | Total loss: 0.00027567 | Loss_int: 0.00016949 | Loss_Clamped: 0.00000001 | Loss_dirichlet: 0.00000000
# Epoch 7290 | Total loss: 0.00027752 | Loss_int: 0.00017027 | Loss_Clamped: 0.00000001 | Loss_dirichlet: 0.00000000
# Epoch 7300 | Total loss: 0.00027636 | Loss_int: 0.00017129 | Loss_Clamped: 0.00000001 | Loss_dirichlet: 0.00000000
# Epoch 7310 | Total loss: 0.00027745 | Loss_int: 0.00017151 | Loss_Clamped: 0.00000001 | Loss_dirichlet: 0.00000000
# Epoch 7320 | Total loss: 0.00028085 | Loss_int: 0.00017188 | Loss_Clamped: 0.00000001 | Loss_dirichlet: 0.00000000
# Epoch 7330 | Total loss: 0.00027929 | Loss_int: 0.00017419 | Loss_Clamped: 0.00000001 | Loss_dirichlet: 0.00000000
# Epoch 7340 | Total loss: 0.00027288 | Loss_int: 0.00016756 | Loss_Clamped: 0.00000001 | Loss_dirichlet: 0.00000000
# Epoch 7350 | Total loss: 0.00027874 | Loss_int: 0.00017187 | Loss_Clamped: 0.00000001 | Loss_dirichlet: 0.00000000
# Epoch 7360 | Total loss: 0.00026854 | Loss_int: 0.00016585 | Loss_Clamped: 0.00000001 | Loss_dirichlet: 0.00000000
# Epoch 7370 | Total loss: 0.00027192 | Loss_int: 0.00016674 | Loss_Clamped: 0.00000001 | Loss_dirichlet: 0.00000000
# Epoch 7380 | Total loss: 0.00027061 | Loss_int: 0.00016766 | Loss_Clamped: 0.00000001 | Loss_dirichlet: 0.00000000
# Epoch 7390 | Total loss: 0.00027978 | Loss_int: 0.00016781 | Loss_Clamped: 0.00000001 | Loss_dirichlet: 0.00000000
# Epoch 7400 | Total loss: 0.00027477 | Loss_int: 0.00016677 | Loss_Clamped: 0.00000001 | Loss_dirichlet: 0.00000000
# Epoch 7410 | Total loss: 0.00027654 | Loss_int: 0.00016879 | Loss_Clamped: 0.00000001 | Loss_dirichlet: 0.00000000
# Epoch 7420 | Total loss: 0.00027177 | Loss_int: 0.00016711 | Loss_Clamped: 0.00000001 | Loss_dirichlet: 0.00000000
# Epoch 7430 | Total loss: 0.00026561 | Loss_int: 0.00016376 | Loss_Clamped: 0.00000001 | Loss_dirichlet: 0.00000000
# Epoch 7440 | Total loss: 0.00026850 | Loss_int: 0.00016656 | Loss_Clamped: 0.00000001 | Loss_dirichlet: 0.00000000
# Epoch 7450 | Total loss: 0.00027424 | Loss_int: 0.00016578 | Loss_Clamped: 0.00000001 | Loss_dirichlet: 0.00000000
# Epoch 7460 | Total loss: 0.00027528 | Loss_int: 0.00017083 | Loss_Clamped: 0.00000001 | Loss_dirichlet: 0.00000000
# Epoch 7470 | Total loss: 0.00028344 | Loss_int: 0.00016729 | Loss_Clamped: 0.00000001 | Loss_dirichlet: 0.00000000
# Epoch 7480 | Total loss: 0.00027009 | Loss_int: 0.00016506 | Loss_Clamped: 0.00000001 | Loss_dirichlet: 0.00000000
# Epoch 7490 | Total loss: 0.00026634 | Loss_int: 0.00016430 | Loss_Clamped: 0.00000001 | Loss_dirichlet: 0.00000000
# Epoch 7500 | Total loss: 0.00026656 | Loss_int: 0.00016346 | Loss_Clamped: 0.00000001 | Loss_dirichlet: 0.00000000
# Epoch 7510 | Total loss: 0.00026684 | Loss_int: 0.00016498 | Loss_Clamped: 0.00000001 | Loss_dirichlet: 0.00000000
# Epoch 7520 | Total loss: 0.00026499 | Loss_int: 0.00016274 | Loss_Clamped: 0.00000001 | Loss_dirichlet: 0.00000000
# Epoch 7530 | Total loss: 0.00026861 | Loss_int: 0.00016074 | Loss_Clamped: 0.00000001 | Loss_dirichlet: 0.00000000
# Epoch 7540 | Total loss: 0.00026211 | Loss_int: 0.00015937 | Loss_Clamped: 0.00000001 | Loss_dirichlet: 0.00000000
# Epoch 7550 | Total loss: 0.00026512 | Loss_int: 0.00016382 | Loss_Clamped: 0.00000001 | Loss_dirichlet: 0.00000000
# Epoch 7560 | Total loss: 0.00026447 | Loss_int: 0.00016312 | Loss_Clamped: 0.00000001 | Loss_dirichlet: 0.00000000
# Epoch 7570 | Total loss: 0.00026609 | Loss_int: 0.00016119 | Loss_Clamped: 0.00000001 | Loss_dirichlet: 0.00000000
# Epoch 7580 | Total loss: 0.00026091 | Loss_int: 0.00016193 | Loss_Clamped: 0.00000001 | Loss_dirichlet: 0.00000000
# Epoch 7590 | Total loss: 0.00026497 | Loss_int: 0.00016036 | Loss_Clamped: 0.00000001 | Loss_dirichlet: 0.00000000
# Epoch 7600 | Total loss: 0.00027523 | Loss_int: 0.00016371 | Loss_Clamped: 0.00000001 | Loss_dirichlet: 0.00000000
# Epoch 7610 | Total loss: 0.00026023 | Loss_int: 0.00015998 | Loss_Clamped: 0.00000001 | Loss_dirichlet: 0.00000000
# Epoch 7620 | Total loss: 0.00026475 | Loss_int: 0.00016473 | Loss_Clamped: 0.00000001 | Loss_dirichlet: 0.00000000
# Epoch 7630 | Total loss: 0.00026220 | Loss_int: 0.00016136 | Loss_Clamped: 0.00000001 | Loss_dirichlet: 0.00000000
# Epoch 7640 | Total loss: 0.00026936 | Loss_int: 0.00016303 | Loss_Clamped: 0.00000001 | Loss_dirichlet: 0.00000000
# Epoch 7650 | Total loss: 0.00027991 | Loss_int: 0.00016338 | Loss_Clamped: 0.00000001 | Loss_dirichlet: 0.00000000
# Epoch 7660 | Total loss: 0.00025625 | Loss_int: 0.00015808 | Loss_Clamped: 0.00000001 | Loss_dirichlet: 0.00000000
# Epoch 7670 | Total loss: 0.00025763 | Loss_int: 0.00015798 | Loss_Clamped: 0.00000001 | Loss_dirichlet: 0.00000000
# Epoch 7680 | Total loss: 0.00025946 | Loss_int: 0.00015770 | Loss_Clamped: 0.00000001 | Loss_dirichlet: 0.00000000
# Epoch 7690 | Total loss: 0.00026481 | Loss_int: 0.00015773 | Loss_Clamped: 0.00000001 | Loss_dirichlet: 0.00000000
# Epoch 7700 | Total loss: 0.00025399 | Loss_int: 0.00015599 | Loss_Clamped: 0.00000001 | Loss_dirichlet: 0.00000000
# Epoch 7710 | Total loss: 0.00026275 | Loss_int: 0.00015837 | Loss_Clamped: 0.00000001 | Loss_dirichlet: 0.00000000
# Epoch 7720 | Total loss: 0.00025981 | Loss_int: 0.00015689 | Loss_Clamped: 0.00000001 | Loss_dirichlet: 0.00000000
# Epoch 7730 | Total loss: 0.00026484 | Loss_int: 0.00016490 | Loss_Clamped: 0.00000001 | Loss_dirichlet: 0.00000000
# Epoch 7740 | Total loss: 0.00025631 | Loss_int: 0.00015768 | Loss_Clamped: 0.00000001 | Loss_dirichlet: 0.00000000
# Epoch 7750 | Total loss: 0.00025728 | Loss_int: 0.00015804 | Loss_Clamped: 0.00000001 | Loss_dirichlet: 0.00000000
# Epoch 7760 | Total loss: 0.00025746 | Loss_int: 0.00015518 | Loss_Clamped: 0.00000001 | Loss_dirichlet: 0.00000000
# Epoch 7770 | Total loss: 0.00026084 | Loss_int: 0.00015955 | Loss_Clamped: 0.00000001 | Loss_dirichlet: 0.00000000
# Epoch 7780 | Total loss: 0.00025447 | Loss_int: 0.00015580 | Loss_Clamped: 0.00000001 | Loss_dirichlet: 0.00000000
# Epoch 7790 | Total loss: 0.00025880 | Loss_int: 0.00015714 | Loss_Clamped: 0.00000001 | Loss_dirichlet: 0.00000000
# Epoch 7800 | Total loss: 0.00025178 | Loss_int: 0.00015413 | Loss_Clamped: 0.00000001 | Loss_dirichlet: 0.00000000
# Epoch 7810 | Total loss: 0.00025163 | Loss_int: 0.00015397 | Loss_Clamped: 0.00000001 | Loss_dirichlet: 0.00000000
# Epoch 7820 | Total loss: 0.00025562 | Loss_int: 0.00015556 | Loss_Clamped: 0.00000001 | Loss_dirichlet: 0.00000000
# Epoch 7830 | Total loss: 0.00025325 | Loss_int: 0.00015462 | Loss_Clamped: 0.00000001 | Loss_dirichlet: 0.00000000
# Epoch 7840 | Total loss: 0.00025180 | Loss_int: 0.00015311 | Loss_Clamped: 0.00000001 | Loss_dirichlet: 0.00000000
# Epoch 7850 | Total loss: 0.00025457 | Loss_int: 0.00015766 | Loss_Clamped: 0.00000001 | Loss_dirichlet: 0.00000000
# Epoch 7860 | Total loss: 0.00025499 | Loss_int: 0.00015649 | Loss_Clamped: 0.00000001 | Loss_dirichlet: 0.00000000
# Epoch 7870 | Total loss: 0.00026362 | Loss_int: 0.00015451 | Loss_Clamped: 0.00000001 | Loss_dirichlet: 0.00000000
# Epoch 7880 | Total loss: 0.00025471 | Loss_int: 0.00015292 | Loss_Clamped: 0.00000001 | Loss_dirichlet: 0.00000000
# Epoch 7890 | Total loss: 0.00024840 | Loss_int: 0.00015172 | Loss_Clamped: 0.00000001 | Loss_dirichlet: 0.00000000
# Epoch 7900 | Total loss: 0.00025206 | Loss_int: 0.00015213 | Loss_Clamped: 0.00000001 | Loss_dirichlet: 0.00000000
# Epoch 7910 | Total loss: 0.00024784 | Loss_int: 0.00015180 | Loss_Clamped: 0.00000001 | Loss_dirichlet: 0.00000000
# Epoch 7920 | Total loss: 0.00025723 | Loss_int: 0.00015431 | Loss_Clamped: 0.00000001 | Loss_dirichlet: 0.00000000
# Epoch 7930 | Total loss: 0.00024652 | Loss_int: 0.00015146 | Loss_Clamped: 0.00000001 | Loss_dirichlet: 0.00000000
# Epoch 7940 | Total loss: 0.00024814 | Loss_int: 0.00015062 | Loss_Clamped: 0.00000001 | Loss_dirichlet: 0.00000000
# Epoch 7950 | Total loss: 0.00025523 | Loss_int: 0.00015217 | Loss_Clamped: 0.00000001 | Loss_dirichlet: 0.00000000
# Epoch 7960 | Total loss: 0.00024670 | Loss_int: 0.00015096 | Loss_Clamped: 0.00000001 | Loss_dirichlet: 0.00000000
# Epoch 7970 | Total loss: 0.00024561 | Loss_int: 0.00015149 | Loss_Clamped: 0.00000001 | Loss_dirichlet: 0.00000000
# Epoch 7980 | Total loss: 0.00024394 | Loss_int: 0.00015023 | Loss_Clamped: 0.00000001 | Loss_dirichlet: 0.00000000
# Epoch 7990 | Total loss: 0.00024932 | Loss_int: 0.00014931 | Loss_Clamped: 0.00000001 | Loss_dirichlet: 0.00000000
# Training finished.
# Calculating final errors...
# Relative L2 Error: 1.8243e-02
# Relative H1 Error: 3.4321e-02
# Relative H2 Error: 5.5712e-02
# Plotting loss history...
#
# ---Training Summary ---
# Device: cpu
#
# [Network Architecture]
# NN(
#   (L1): Linear(in_features=2, out_features=60, bias=True)
#   (L2): Linear(in_features=60, out_features=60, bias=True)
#   (L3): Linear(in_features=60, out_features=60, bias=True)
#   (L4): Linear(in_features=60, out_features=60, bias=True)
#   (L5): Linear(in_features=60, out_features=60, bias=True)
#   (L6): Linear(in_features=60, out_features=1, bias=True)
# )
#
# [Hyperparameters]
#   Optimizer: Adam (lr=0.001)
#   Epochs (Adam): 8000
#   Batch Size: 2000
#   Interior Points: 20000
#   Boundary Points: 10000
#   Loss Weight (Dirichlet): 1.0e+04
#   Loss Weight (Clamped): 1.0e+04
#
# [Performance]
#   Training Time: 45116.46 seconds
#   Total Script Time: 45118.04 seconds
#   Final Total Loss: 2.4871e-04
#   Relative L2 Error: 1.8243e-02
#   Relative H1 Error: 3.4321e-02
#   Relative H2 Error: 5.5712e-02
# Plotting 3D solution comparison...
