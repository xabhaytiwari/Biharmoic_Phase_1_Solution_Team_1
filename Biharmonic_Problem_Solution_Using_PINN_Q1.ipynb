# %%
import torch
import numpy as np

class NN(torch.nn.Module):
  def __init__(self) -> None:
    super(NN, self).__init__()
    self.L1 = torch.nn.Linear(2, 60) # Wider
    self.L2 = torch.nn.Linear(60, 60)
    self.L3 = torch.nn.Linear(60, 60)
    self.L4 = torch.nn.Linear(60, 60)
    self.L5 = torch.nn.Linear(60, 60) # Deeper
    self.L6 = torch.nn.Linear(60, 1)

  def forward(self, x, y):
    inputs = torch.cat([x, y], axis=1)
    x1 = torch.tanh(self.L1(inputs))
    x2 = torch.tanh(self.L2(x1))
    x3 = torch.tanh(self.L3(x2))
    x4 = torch.tanh(self.L4(x3))
    x5 = torch.tanh(self.L5(x4))
    x6 = self.L6(x5)
    return x6

  def init_weights(m):
    if isinstance(m, torch.nn.Linear):
      torch.nn.init.xavier_uniform_(m.weight)
      m.bias.data.fill_(0.0)

# %% [markdown]
# We'll gather Inputs, Collocation points, PDE Data and Balancing Parameter alpha.

# %%
from sympy import symbols, diff, sin, pi, lambdify

x1, x2 = symbols('x1 x2')
u = (1 / (2 * (pi ** 2))) * sin(pi * x1) * sin(pi * x2)
# u = (x1 ** 2) * (x2 ** 2) * ((1 - x1) ** 2) * ((1 - x2) ** 2)

laplacian_u = diff(u, x1, 2) + diff(u, x2, 2)
bi_laplacian_u = diff(laplacian_u, x1, 2) + diff(laplacian_u, x2, 2)

f_sym = bi_laplacian_u

u_x_sym = diff(u, x1)
u_y_sym = diff(u, x2)

u_xx_sym = diff(u, x1, 2)
u_yy_sym = diff(u, x2, 2)
u_xy_sym = diff(u, x1, x2)

ldu = lambdify((x1, x2), u, 'numpy')
ldu_x = lambdify((x1, x2), u_x_sym, 'numpy')
ldu_y = lambdify((x1, x2), u_y_sym, 'numpy')
ldf = lambdify((x1, x2), f_sym, 'numpy')

ldu_xx = lambdify((x1, x2), u_xx_sym, 'numpy')
ldu_yy = lambdify((x1, x2), u_yy_sym, 'numpy')
ldu_xy = lambdify((x1, x2), u_xy_sym, 'numpy')

def from_seq_to_array(items):
    out = []
    for item in items:
        out.append(np.array(item).reshape(-1, 1))
    if len(out) == 1:
        return out[0]
    return out


def data_gen_interior(collocations):
    u_gt = [ldu(x, y) for x, y in collocations]
    f_gt = [ldf(x, y) for x, y in collocations]
    return from_seq_to_array([u_gt, f_gt])

def data_gen_bdry(collocations, normal_vec):
    ybdry_vals_g1       = []
    ybdry_vals_g2       = []

    for (x, y), (n1, n2) in zip(collocations, normal_vec):
        ybdry_vals_g1.append(ldu(x, y))
        ybdry_vals_g2.append(ldu_x(x, y) * n1 + ldu_y(x, y) * n2)

    return from_seq_to_array([ybdry_vals_g1, ybdry_vals_g2])

# %%
import pickle as pkl
from scipy.stats import uniform
import os

N = 20000
dataname = '20000pts'

domain_data_x = uniform.rvs(size=N)
domain_data_y = uniform.rvs(size=N)

domain_data = np.array([domain_data_x,domain_data_y]).T
print(domain_data.shape)


Nb = 10000

def generate_random_bdry(Nb):
    '''
    Generate random boundary points.
    '''
    bdry_col = uniform.rvs(size=Nb*2).reshape([Nb,2])
    for i in range(Nb):
        randind = np.random.randint(0,2)
        if bdry_col[i,randind] <= 0.5:
            bdry_col[i,randind] = 0.0
        else:
            bdry_col[i,randind] = 1.0

    return bdry_col


def compute_normals(bdry_col, eps=1e-8):
    """
    Given bdry_col of shape (Nb,2) with points on the edges of [0,1]^2,
    returns two arrays n1,n2 of shape (Nb,1) giving the outward unit normals.

    Assumes:
      - if x ≈ 0 → normal = (-1, 0)
      - if x ≈ 1 → normal = ( 1, 0)
      - if y ≈ 0 → normal = ( 0,-1)
      - if y ≈ 1 → normal = ( 0, 1)
    """
    x = bdry_col[:, 0]
    y = bdry_col[:, 1]

    n1 = np.zeros_like(x)
    n2 = np.zeros_like(y)

    # left edge x=0
    mask = np.isclose(x, 0.0, atol=eps)
    n1[mask] = -1.0;  n2[mask] =  0.0

    # right edge x=1
    mask = np.isclose(x, 1.0, atol=eps)
    n1[mask] =  1.0;  n2[mask] =  0.0

    # bottom edge y=0
    mask = np.isclose(y, 0.0, atol=eps)
    n1[mask] =  0.0;  n2[mask] = -1.0

    # top edge y=1
    mask = np.isclose(y, 1.0, atol=eps)
    n1[mask] =  0.0;  n2[mask] =  1.0

    # reshape to column vectors
    return n1.reshape(-1,1), n2.reshape(-1,1)

bdry_col = generate_random_bdry(Nb)
n1_np, n2_np = compute_normals(bdry_col)
normal_vec = np.hstack([n1_np, n2_np])

print(normal_vec.shape)
print(bdry_col.shape)

if not os.path.exists('dataset/'):
    os.makedirs('dataset/')
with open('dataset/'+dataname,'wb') as pfile:
    pkl.dump(domain_data,pfile)
    pkl.dump(bdry_col,pfile)
    pkl.dump(normal_vec,pfile)


ugt,fgt = data_gen_interior(domain_data)
dirichlet_data, clamped_data = data_gen_bdry(bdry_col,normal_vec)


with open("dataset/gt_on_{}".format(dataname),'wb') as pfile:
    pkl.dump(ugt,pfile)
    pkl.dump(fgt,pfile)
    pkl.dump(dirichlet_data,pfile)
    pkl.dump(clamped_data,pfile)
# Out:
# (20000, 2)
# (10000, 2)
# (10000, 2)

# %%
mse_loss = torch.nn.MSELoss()

def pde(x1, x2, net):
    """
    Compute Δ²u = (u_xx + u_yy)_xx + (u_xx + u_yy)_yy
    at the points (x1, x2) via automatic differentiation.
    """
    # 1) forward pass
    u = net(x1, x2)

    # 2) first derivatives
    # u_x, u_y = torch.autograd.grad(
    #     u.sum(), (x1, x2), create_graph=True
    # )
    u_x = torch.autograd.grad(u.sum(), x1, create_graph=True)[0]
    u_y = torch.autograd.grad(u.sum(), x2, create_graph=True)[0]

    # 3) second derivatives
    u_xx = torch.autograd.grad(u_x.sum(), x1, create_graph=True)[0]
    u_yy = torch.autograd.grad(u_y.sum(), x2, create_graph=True)[0]

    # 4) Laplacian
    lap = u_xx + u_yy

    # 5) third derivatives of lap
    # lap_x, lap_y = torch.autograd.grad(
    #     lap.sum(), (x1, x2), create_graph=True
    # )
    lap_x = torch.autograd.grad(lap.sum(), x1, create_graph=True)[0]
    lap_y = torch.autograd.grad(lap.sum(), x2, create_graph=True)[0]

    # 6) fourth derivatives (bi‐Laplacian pieces)
    lap_xx = torch.autograd.grad(lap_x.sum(), x1, create_graph=True)[0]
    lap_yy = torch.autograd.grad(lap_y.sum(), x2, create_graph=True)[0]



    return lap_xx +  lap_yy



def bdry(x1,x2,n1,n2,net):
    out = net(x1,x2)
    u_x = torch.autograd.grad(out.sum(),x1,create_graph=True)[0]
    u_y = torch.autograd.grad(out.sum(),x2,create_graph=True)[0]

    return out, u_x*n1 + u_y*n2


def pdeloss(net,intx1,intx2,pdedata,bdx1,bdx2,nx1,nx2,bdrydata_diri,bdrydat_clamped,bw_diri,bw_clamped):
    bdx1  = bdx1.requires_grad_(True)
    bdx2  = bdx2.requires_grad_(True)
    pout = pde(intx1,intx2,net)
    bout_diri, bout_clamped = bdry(bdx1,bdx2,nx1,nx2,net)
    pres = mse_loss(pout,pdedata)
    bres = bw_diri*mse_loss(bout_diri,bdrydata_diri) + bw_clamped*mse_loss(bout_clamped,bdrydat_clamped)
    diri_loss = mse_loss(bout_diri,bdrydata_diri)
    clamped_loss = mse_loss(bout_clamped,bdrydat_clamped)


    loss = pres + bres

    return loss, pres, bres, diri_loss, clamped_loss

# %%
from torch.autograd import Variable

def from_numpy_to_tensor(numpys,require_grads,dtype=torch.float32):
    outputs = list()
    for ind in range(len(numpys)):
        outputs.append(
            Variable(torch.from_numpy(numpys[ind]),requires_grad=require_grads[ind]).type(dtype)
        )

    return outputs

# %%
from time import time
from tracemalloc import start
import numpy as np
import torch
from torch.utils.data import TensorDataset
import torch.optim as opt
import matplotlib.pyplot as plt
import torch.utils.data.dataset as Dataset
import torch.utils.data.dataloader as Dataloader
from torch.autograd import Variable
import pickle as pkl
from mpl_toolkits.mplot3d import Axes3D
from matplotlib import cm
from matplotlib.ticker import LinearLocator, FormatStrFormatter
from time import time
from torch.utils.data import TensorDataset

import os
os.environ['KMP_DUPLICATE_LIB_OK']='True'

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Using device: {device}")
torch.set_default_dtype(torch.float32)
start_time = time()

y = NN()
y.apply(NN.init_weights)
y.to(device)

dataname = '20000pts'
name = 'results/'
bw_dir = 1e4   # Start with 10,000
bw_clamp = 1e4 # Start with 10,000

if not os.path.exists(name):
    os.makedirs(name)
if not os.path.exists(name+"y_plot/"):
    os.makedirs(name+"y_plot/")

params = list(y.parameters())

# --- 1. Load all data from files ---
with open("dataset/"+dataname,'rb') as pfile:
    int_col = pkl.load(pfile)
    bdry_col = pkl.load(pfile)
    normal_vec = pkl.load(pfile)

with open("dataset/gt_on_{}".format(dataname),'rb') as pfile:
    u_gt_np = pkl.load(pfile)
    f_np = pkl.load(pfile)
    dirichlet_data_np = pkl.load(pfile)
    clamped_data_np = pkl.load(pfile)

print(f"Interior points: {int_col.shape}")
print(f"Boundary points: {bdry_col.shape}")
print(f"Forcing term: {f_np.shape}")
print(f"Dirichlet data: {dirichlet_data_np.shape}")
print(f"Clamped data: {clamped_data_np.shape}")

def compute_derivatives(net, x, y):
    """ Computes u, 1st, and 2nd derivatives """
    u = net(x, y)

    # 1st derivatives
    u_x, u_y = torch.autograd.grad(
        u.sum(), (x, y), create_graph=True
    )

    # 2nd derivatives
    u_xx = torch.autograd.grad(u_x.sum(), x, create_graph=True)[0]
    u_yy = torch.autograd.grad(u_y.sum(), y, create_graph=True)[0]
    u_xy = torch.autograd.grad(u_x.sum(), y, create_graph=True)[0]

    return u, u_x, u_y, u_xx, u_yy, u_xy

# --- 2. Create Tensors and DataLoaders ---

# Create a TensorDataset for INTERIOR points AND their forcing term ---
intx1_np, intx2_np = np.split(int_col, 2, axis=1)

# Convert interior data to tensors (no grad needed here, will be set in loop)
tintx1 = torch.from_numpy(intx1_np).float()
tintx2 = torch.from_numpy(intx2_np).float()
f_tensor = torch.from_numpy(f_np).float()

# Create a dataset and loader for interior points
interior_dataset = TensorDataset(tintx1, tintx2, f_tensor)
loader = torch.utils.data.DataLoader(interior_dataset, batch_size=2000, shuffle=True)


# Create Tensors for BOUNDARY data (with requires_grad=True) ---
bdx1_np, bdx2_np = np.split(bdry_col, 2, axis=1)
nx1_np, nx2_np = np.split(normal_vec, 2, axis=1)

# Boundary coordinates MUST have requires_grad=True
# Normals and ground truth data do NOT need gradients.
[tbdx1, tbdx2] = from_numpy_to_tensor([bdx1_np, bdx2_np], [True, True], dtype=torch.float32)
[tnx1, tnx2] = from_numpy_to_tensor([nx1_np, nx2_np], [False, False], dtype=torch.float32)
[bdrydata_dirichlet, bdrydata_clamped] = from_numpy_to_tensor(
    [dirichlet_data_np, clamped_data_np], [False, False], dtype=torch.float32
)

# Move all *full* boundary tensors to the device once
tbdx1 = tbdx1.to(device)
tbdx2 = tbdx2.to(device)
tnx1 = tnx1.to(device)
tnx2 = tnx2.to(device)
bdrydata_dirichlet = bdrydata_dirichlet.to(device)
bdrydata_clamped = bdrydata_clamped.to(device)

# Note: We won't use ygt for training, only for final error calculation
ygt = torch.from_numpy(u_gt_np).float().to(device)

optimizer = opt.Adam(params, lr=1e-3)
scheduler = opt.lr_scheduler.ReduceLROnPlateau(optimizer, patience=400)
train_start_time = time()
# --- 3. Define the Closure ---
def closure():
    tot_loss = 0
    tot_pres = 0
    tot_diri_loss = 0
    tot_clamped_loss = 0

    # Iterate over the DataLoader
    for i, (intx1_batch, intx2_batch, f_batch) in enumerate(loader):
       optimizer.zero_grad()

       # Set requires_grad=True for the BATCH coordinates
       ttintx1 = intx1_batch.to(device).requires_grad_(True)
       ttintx2 = intx2_batch.to(device).requires_grad_(True)

       # This is the ground-truth forcing term for the batch
       f_gt_batch = f_batch.to(device)

       # --- Pass the correct batch data to the loss function ---
       # We use the *batched* interior points and *batched* forcing term
       # We use the *full* set of boundary points
       loss, pres, bres, diri_loss, clamped_loss = pdeloss(
           y,
           ttintx1, ttintx2, f_gt_batch,  # Batched interior data
           tbdx1, tbdx2, tnx1, tnx2,     # Full boundary data
           bdrydata_dirichlet, bdrydata_clamped,
           bw_dir, bw_clamp
       )

       loss.backward()
       optimizer.step()

       # Detach losses to free memory
       tot_loss += loss.detach()
       tot_pres += pres.detach()
       tot_diri_loss += diri_loss.detach()
       tot_clamped_loss += clamped_loss.detach()

    # Get the average loss per batch
    num_batches = len(loader)
    avg_loss = tot_loss / num_batches
    avg_pres = tot_pres / num_batches
    avg_diri = tot_diri_loss / num_batches
    avg_clamp = tot_clamped_loss / num_batches

    # scheduler.step() uses the average loss
    scheduler.step(avg_loss)

    return (
        avg_loss.cpu().numpy(),
        avg_pres.cpu().numpy(),
        avg_diri.cpu().numpy(),
        avg_clamp.cpu().numpy()
    )

# --- 4. Run the Training Loop ---
losslist = list()
print("Starting training...")
for epoch in range(8000):
    loss, presloss, diri_loss, clamped_loss = closure()
    losslist.append(loss)
    if epoch % 10 == 0:
         print(f"Epoch {epoch} | Total loss: {loss:.8f} | Loss_int: {presloss:.8f} | Loss_Clamped: {clamped_loss:.8f} | Loss_dirichlet: {diri_loss:.8f}")
train_end_time = time()
print("Training finished.")
with open("results/loss.pkl",'wb') as pfile:
    pkl.dump(losslist,pfile)

# --- (After training is finished) ---

print("Calculating final errors...")

# Use the same grid as your plots
x_pts = np.linspace(0,1,200)
y_pts = np.linspace(0,1,200)
ms_x, ms_y = np.meshgrid(x_pts,y_pts)
x_flat = np.ravel(ms_x).reshape(-1,1)
y_flat = np.ravel(ms_y).reshape(-1,1)
collocations = np.concatenate([x_flat, y_flat], axis=1)

# --- 1. Get Ground Truth (GT) values ---
u_gt_np = ldu(x_flat, y_flat).flatten()
ux_gt_np = ldu_x(x_flat, y_flat).flatten()
uy_gt_np = ldu_y(x_flat, y_flat).flatten()
uxx_gt_np = ldu_xx(x_flat, y_flat).flatten()
uyy_gt_np = ldu_yy(x_flat, y_flat).flatten()
uxy_gt_np = ldu_xy(x_flat, y_flat).flatten()

# --- 2. Get Network Prediction (NN) values ---
pt_x = torch.from_numpy(x_flat).float().to(device).requires_grad_(True)
pt_y = torch.from_numpy(y_flat).float().to(device).requires_grad_(True)

u_nn, ux_nn, uy_nn, uxx_nn, uyy_nn, uxy_nn = compute_derivatives(y, pt_x, pt_y)

u_nn_np = u_nn.data.cpu().numpy().flatten()
ux_nn_np = ux_nn.data.cpu().numpy().flatten()
uy_nn_np = uy_nn.data.cpu().numpy().flatten()
uxx_nn_np = uxx_nn.data.cpu().numpy().flatten()
uyy_nn_np = uyy_nn.data.cpu().numpy().flatten()
uxy_nn_np = uxy_nn.data.cpu().numpy().flatten()

# --- 3. Compute Errors ---
# L2 Error
l2_error_u = np.sqrt(np.mean((u_gt_np - u_nn_np)**2))
l2_error = l2_error_u / np.sqrt(np.mean(u_gt_np**2))

# H1 Error
l2_error_ux = np.sqrt(np.mean((ux_gt_np - ux_nn_np)**2))
l2_error_uy = np.sqrt(np.mean((uy_gt_np - uy_nn_np)**2))
h1_error = np.sqrt(l2_error_u**2 + l2_error_ux**2 + l2_error_uy**2) / \
           np.sqrt(np.mean(u_gt_np**2) + np.mean(ux_gt_np**2) + np.mean(uy_gt_np**2))

# H2 Error
l2_error_uxx = np.sqrt(np.mean((uxx_gt_np - uxx_nn_np)**2))
l2_error_uyy = np.sqrt(np.mean((uyy_gt_np - uyy_nn_np)**2))
l2_error_uxy = np.sqrt(np.mean((uxy_gt_np - uxy_nn_np)**2))
h2_error = np.sqrt(l2_error_u**2 + l2_error_ux**2 + l2_error_uy**2 + \
                   l2_error_uxx**2 + l2_error_uyy**2 + l2_error_uxy**2) / \
           np.sqrt(np.mean(u_gt_np**2) + np.mean(ux_gt_np**2) + np.mean(uy_gt_np**2) + \
                   np.mean(uxx_gt_np**2) + np.mean(uyy_gt_np**2) + np.mean(uxy_gt_np**2))

print(f"Relative L2 Error: {l2_error:.4e}")
print(f"Relative H1 Error: {h1_error:.4e}")
print(f"Relative H2 Error: {h2_error:.4e}")

# --- 4. Reshape for Plotting ---
ms_ysol = u_nn_np.reshape(ms_x.shape)
ms_ugt = u_gt_np.reshape(ms_x.shape)

# --- Plot Loss History ---
print("Plotting loss history...")
fig_loss = plt.figure(figsize=(10, 6))
plt.plot(losslist)
plt.yscale('log') # Log scale is essential for loss plots
plt.title('Training Loss Dynamics')
plt.xlabel('Epoch')
plt.ylabel('Total Loss')
plt.grid(True, which="both", ls="--")
plt.savefig(name + 'loss_history_q1.png')
plt.close(fig_loss)

end_time = time()

print("\n---Training Summary ---")
print(f"Device: {device}")
print("\n[Network Architecture]")
print(y)
print("\n[Hyperparameters]")
print(f"  Optimizer: Adam (lr={1e-3})")
print(f"  Epochs (Adam): {8000}")
print(f"  Batch Size: {2000}")
print(f"  Interior Points: {int_col.shape[0]}")
print(f"  Boundary Points: {bdry_col.shape[0]}")
print(f"  Loss Weight (Dirichlet): {bw_dir:.1e}")
print(f"  Loss Weight (Clamped): {bw_clamp:.1e}")
print("\n[Performance]")
print(f"  Training Time: {train_end_time - train_start_time:.2f} seconds")
print(f"  Total Script Time: {end_time - start_time:.2f} seconds")
print(f"  Final Total Loss: {losslist[-1]:.4e}")
print(f"  Relative L2 Error: {l2_error:.4e}")
print(f"  Relative H1 Error: {h1_error:.4e}")
print(f"  Relative H2 Error: {h2_error:.4e}")

print("Plotting 3D solution comparison...")

fig = plt.figure(figsize=(18, 7))

# --- Plot 1: NN Solution ---
ax1 = fig.add_subplot(1, 2, 1, projection='3d')
surf1 = ax1.plot_surface(ms_x, ms_y, ms_ysol, cmap=cm.viridis,
                         linewidth=0, antialiased=False)
ax1.set_title('Neural Network Solution (u_nn)')
ax1.set_xlabel('x')
ax1.set_ylabel('y')
ax1.set_zlabel('u')
fig.colorbar(surf1, ax=ax1, shrink=0.5, aspect=5)

# --- Plot 2: Known Solution ---
ax2 = fig.add_subplot(1, 2, 2, projection='3d')
surf2 = ax2.plot_surface(ms_x, ms_y, ms_ugt, cmap=cm.viridis,
                         linewidth=0, antialiased=False)
ax2.set_title('Known Solution (u_gt)')
ax2.set_xlabel('x')
ax2.set_ylabel('y')
ax2.set_zlabel('u')
fig.colorbar(surf2, ax=ax2, shrink=0.5, aspect=5)

plt.savefig(name + '3D_solution_comparison_q1.png')
plt.close(fig)
# Out:
# Using device: cpu
# Interior points: (20000, 2)
# Boundary points: (10000, 2)
# Forcing term: (20000, 1)
# Dirichlet data: (10000, 1)
# Clamped data: (10000, 1)
# Starting training...
# Epoch 0 | Total loss: 256.88900757 | Loss_int: 93.67102051 | Loss_Clamped: 0.01401437 | Loss_dirichlet: 0.00230743
# Epoch 10 | Total loss: 25.50180435 | Loss_int: 14.06181526 | Loss_Clamped: 0.00098732 | Loss_dirichlet: 0.00015667
# Epoch 20 | Total loss: 17.25325203 | Loss_int: 10.66226387 | Loss_Clamped: 0.00057545 | Loss_dirichlet: 0.00008365
# Epoch 30 | Total loss: 11.48204994 | Loss_int: 7.21509171 | Loss_Clamped: 0.00034619 | Loss_dirichlet: 0.00008051
# Epoch 40 | Total loss: 2.71214056 | Loss_int: 1.86601615 | Loss_Clamped: 0.00005825 | Loss_dirichlet: 0.00002637
# Epoch 50 | Total loss: 0.27984995 | Loss_int: 0.15180236 | Loss_Clamped: 0.00000923 | Loss_dirichlet: 0.00000358
# Epoch 60 | Total loss: 0.20318604 | Loss_int: 0.10298246 | Loss_Clamped: 0.00000616 | Loss_dirichlet: 0.00000386
# Epoch 70 | Total loss: 0.26436529 | Loss_int: 0.08728291 | Loss_Clamped: 0.00000878 | Loss_dirichlet: 0.00000893
# Epoch 80 | Total loss: 1.83665311 | Loss_int: 0.07221874 | Loss_Clamped: 0.00011088 | Loss_dirichlet: 0.00006556
# Epoch 90 | Total loss: 0.22610383 | Loss_int: 0.06561013 | Loss_Clamped: 0.00000697 | Loss_dirichlet: 0.00000907
# Epoch 100 | Total loss: 0.09709229 | Loss_int: 0.05275321 | Loss_Clamped: 0.00000236 | Loss_dirichlet: 0.00000207
# Epoch 110 | Total loss: 0.10266662 | Loss_int: 0.05137243 | Loss_Clamped: 0.00000266 | Loss_dirichlet: 0.00000247
# Epoch 120 | Total loss: 0.64205486 | Loss_int: 0.04873157 | Loss_Clamped: 0.00003928 | Loss_dirichlet: 0.00002005
# Epoch 130 | Total loss: 3.02946782 | Loss_int: 0.05998160 | Loss_Clamped: 0.00012627 | Loss_dirichlet: 0.00017068
# Epoch 140 | Total loss: 0.07030402 | Loss_int: 0.04097856 | Loss_Clamped: 0.00000145 | Loss_dirichlet: 0.00000149
# Epoch 150 | Total loss: 0.61183333 | Loss_int: 0.04805762 | Loss_Clamped: 0.00002997 | Loss_dirichlet: 0.00002640
# Epoch 160 | Total loss: 0.06245986 | Loss_int: 0.03725118 | Loss_Clamped: 0.00000121 | Loss_dirichlet: 0.00000131
# Epoch 170 | Total loss: 0.06025472 | Loss_int: 0.03476634 | Loss_Clamped: 0.00000123 | Loss_dirichlet: 0.00000132
# Epoch 180 | Total loss: 0.06241421 | Loss_int: 0.03607712 | Loss_Clamped: 0.00000117 | Loss_dirichlet: 0.00000147
# Epoch 190 | Total loss: 0.05348327 | Loss_int: 0.03266733 | Loss_Clamped: 0.00000098 | Loss_dirichlet: 0.00000111
# Epoch 200 | Total loss: 0.05881903 | Loss_int: 0.03079542 | Loss_Clamped: 0.00000141 | Loss_dirichlet: 0.00000139
# Epoch 210 | Total loss: 0.04752915 | Loss_int: 0.03058906 | Loss_Clamped: 0.00000076 | Loss_dirichlet: 0.00000093
# Epoch 220 | Total loss: 0.11611746 | Loss_int: 0.03012932 | Loss_Clamped: 0.00000335 | Loss_dirichlet: 0.00000524
# Epoch 230 | Total loss: 0.06082199 | Loss_int: 0.02787962 | Loss_Clamped: 0.00000148 | Loss_dirichlet: 0.00000181
# Epoch 240 | Total loss: 0.05710296 | Loss_int: 0.03004381 | Loss_Clamped: 0.00000122 | Loss_dirichlet: 0.00000148
# Epoch 250 | Total loss: 0.03992535 | Loss_int: 0.02687530 | Loss_Clamped: 0.00000055 | Loss_dirichlet: 0.00000076
# Epoch 260 | Total loss: 1.22654486 | Loss_int: 0.03350508 | Loss_Clamped: 0.00007367 | Loss_dirichlet: 0.00004563
# Epoch 270 | Total loss: 0.09618483 | Loss_int: 0.02740544 | Loss_Clamped: 0.00000208 | Loss_dirichlet: 0.00000480
# Epoch 280 | Total loss: 0.15265784 | Loss_int: 0.02504913 | Loss_Clamped: 0.00000806 | Loss_dirichlet: 0.00000470
# Epoch 290 | Total loss: 0.20003343 | Loss_int: 0.02552643 | Loss_Clamped: 0.00001018 | Loss_dirichlet: 0.00000727
# Epoch 300 | Total loss: 0.04184587 | Loss_int: 0.02337796 | Loss_Clamped: 0.00000083 | Loss_dirichlet: 0.00000102
# Epoch 310 | Total loss: 0.13055530 | Loss_int: 0.02473904 | Loss_Clamped: 0.00000416 | Loss_dirichlet: 0.00000642
# Epoch 320 | Total loss: 0.54226601 | Loss_int: 0.02645571 | Loss_Clamped: 0.00003042 | Loss_dirichlet: 0.00002116
# Epoch 330 | Total loss: 0.03848119 | Loss_int: 0.02204530 | Loss_Clamped: 0.00000091 | Loss_dirichlet: 0.00000074
# Epoch 340 | Total loss: 0.04151001 | Loss_int: 0.02070991 | Loss_Clamped: 0.00000085 | Loss_dirichlet: 0.00000123
# Epoch 350 | Total loss: 0.39493489 | Loss_int: 0.02251543 | Loss_Clamped: 0.00002059 | Loss_dirichlet: 0.00001665
# Epoch 360 | Total loss: 0.16751298 | Loss_int: 0.02086706 | Loss_Clamped: 0.00000991 | Loss_dirichlet: 0.00000475
# Epoch 370 | Total loss: 0.14863852 | Loss_int: 0.01984051 | Loss_Clamped: 0.00000727 | Loss_dirichlet: 0.00000561
# Epoch 380 | Total loss: 0.28277966 | Loss_int: 0.02131374 | Loss_Clamped: 0.00001466 | Loss_dirichlet: 0.00001149
# Epoch 390 | Total loss: 0.64367235 | Loss_int: 0.02556142 | Loss_Clamped: 0.00001704 | Loss_dirichlet: 0.00004477
# Epoch 400 | Total loss: 0.77561587 | Loss_int: 0.02293367 | Loss_Clamped: 0.00005018 | Loss_dirichlet: 0.00002509
# Epoch 410 | Total loss: 0.05300568 | Loss_int: 0.01738044 | Loss_Clamped: 0.00000163 | Loss_dirichlet: 0.00000194
# Epoch 420 | Total loss: 0.05992832 | Loss_int: 0.01783993 | Loss_Clamped: 0.00000220 | Loss_dirichlet: 0.00000201
# Epoch 430 | Total loss: 0.16486999 | Loss_int: 0.01779919 | Loss_Clamped: 0.00001016 | Loss_dirichlet: 0.00000454
# Epoch 440 | Total loss: 0.02196894 | Loss_int: 0.01584396 | Loss_Clamped: 0.00000026 | Loss_dirichlet: 0.00000036
# Epoch 450 | Total loss: 0.02188814 | Loss_int: 0.01561669 | Loss_Clamped: 0.00000025 | Loss_dirichlet: 0.00000037
# Epoch 460 | Total loss: 0.02631193 | Loss_int: 0.01544818 | Loss_Clamped: 0.00000040 | Loss_dirichlet: 0.00000068
# Epoch 470 | Total loss: 0.32733721 | Loss_int: 0.01952471 | Loss_Clamped: 0.00001028 | Loss_dirichlet: 0.00002050
# Epoch 480 | Total loss: 0.02993215 | Loss_int: 0.01520335 | Loss_Clamped: 0.00000079 | Loss_dirichlet: 0.00000069
# Epoch 490 | Total loss: 0.02861561 | Loss_int: 0.01402317 | Loss_Clamped: 0.00000060 | Loss_dirichlet: 0.00000086
# Epoch 500 | Total loss: 0.04035712 | Loss_int: 0.01408047 | Loss_Clamped: 0.00000100 | Loss_dirichlet: 0.00000162
# Epoch 510 | Total loss: 0.22518201 | Loss_int: 0.01428916 | Loss_Clamped: 0.00000469 | Loss_dirichlet: 0.00001640
# Epoch 520 | Total loss: 0.04067222 | Loss_int: 0.01331570 | Loss_Clamped: 0.00000165 | Loss_dirichlet: 0.00000108
# Epoch 530 | Total loss: 0.12551983 | Loss_int: 0.01461788 | Loss_Clamped: 0.00000289 | Loss_dirichlet: 0.00000820
# Epoch 540 | Total loss: 0.25925916 | Loss_int: 0.01561514 | Loss_Clamped: 0.00001716 | Loss_dirichlet: 0.00000720
# Epoch 550 | Total loss: 0.17830949 | Loss_int: 0.01524468 | Loss_Clamped: 0.00000471 | Loss_dirichlet: 0.00001159
# Epoch 560 | Total loss: 0.09030241 | Loss_int: 0.01224061 | Loss_Clamped: 0.00000529 | Loss_dirichlet: 0.00000252
# Epoch 570 | Total loss: 0.01589170 | Loss_int: 0.01155163 | Loss_Clamped: 0.00000018 | Loss_dirichlet: 0.00000026
# Epoch 580 | Total loss: 0.26369461 | Loss_int: 0.01463100 | Loss_Clamped: 0.00001462 | Loss_dirichlet: 0.00001029
# Epoch 590 | Total loss: 0.20599894 | Loss_int: 0.01362048 | Loss_Clamped: 0.00000867 | Loss_dirichlet: 0.00001056
# Epoch 600 | Total loss: 0.02385898 | Loss_int: 0.01064297 | Loss_Clamped: 0.00000072 | Loss_dirichlet: 0.00000061
# Epoch 610 | Total loss: 0.08829945 | Loss_int: 0.01153252 | Loss_Clamped: 0.00000219 | Loss_dirichlet: 0.00000549
# Epoch 620 | Total loss: 0.30532324 | Loss_int: 0.01591884 | Loss_Clamped: 0.00002028 | Loss_dirichlet: 0.00000866
# Epoch 630 | Total loss: 0.03594404 | Loss_int: 0.01042627 | Loss_Clamped: 0.00000146 | Loss_dirichlet: 0.00000110
# Epoch 640 | Total loss: 0.18763268 | Loss_int: 0.01309946 | Loss_Clamped: 0.00001171 | Loss_dirichlet: 0.00000575
# Epoch 650 | Total loss: 0.03215871 | Loss_int: 0.00977141 | Loss_Clamped: 0.00000122 | Loss_dirichlet: 0.00000101
# Epoch 660 | Total loss: 0.02695234 | Loss_int: 0.00959084 | Loss_Clamped: 0.00000092 | Loss_dirichlet: 0.00000081
# Epoch 670 | Total loss: 0.01316929 | Loss_int: 0.00895702 | Loss_Clamped: 0.00000018 | Loss_dirichlet: 0.00000024
# Epoch 680 | Total loss: 0.03714767 | Loss_int: 0.00887301 | Loss_Clamped: 0.00000121 | Loss_dirichlet: 0.00000162
# Epoch 690 | Total loss: 0.01155486 | Loss_int: 0.00846385 | Loss_Clamped: 0.00000010 | Loss_dirichlet: 0.00000020
# Epoch 700 | Total loss: 0.09963548 | Loss_int: 0.01074338 | Loss_Clamped: 0.00000536 | Loss_dirichlet: 0.00000353
# Epoch 710 | Total loss: 0.86259115 | Loss_int: 0.03466917 | Loss_Clamped: 0.00003970 | Loss_dirichlet: 0.00004309
# Epoch 720 | Total loss: 0.02171126 | Loss_int: 0.00833212 | Loss_Clamped: 0.00000066 | Loss_dirichlet: 0.00000068
# Epoch 730 | Total loss: 0.01065740 | Loss_int: 0.00766003 | Loss_Clamped: 0.00000011 | Loss_dirichlet: 0.00000019
# Epoch 740 | Total loss: 0.48501888 | Loss_int: 0.02055019 | Loss_Clamped: 0.00003200 | Loss_dirichlet: 0.00001445
# Epoch 750 | Total loss: 0.01080943 | Loss_int: 0.00724351 | Loss_Clamped: 0.00000012 | Loss_dirichlet: 0.00000024
# Epoch 760 | Total loss: 0.01617138 | Loss_int: 0.00774072 | Loss_Clamped: 0.00000044 | Loss_dirichlet: 0.00000041
# Epoch 770 | Total loss: 0.04443186 | Loss_int: 0.00848704 | Loss_Clamped: 0.00000177 | Loss_dirichlet: 0.00000183
# Epoch 780 | Total loss: 0.02006360 | Loss_int: 0.00694007 | Loss_Clamped: 0.00000042 | Loss_dirichlet: 0.00000089
# Epoch 790 | Total loss: 0.08494023 | Loss_int: 0.00967878 | Loss_Clamped: 0.00000413 | Loss_dirichlet: 0.00000340
# Epoch 800 | Total loss: 0.18423030 | Loss_int: 0.01388711 | Loss_Clamped: 0.00000820 | Loss_dirichlet: 0.00000884
# Epoch 810 | Total loss: 0.01279657 | Loss_int: 0.00662406 | Loss_Clamped: 0.00000034 | Loss_dirichlet: 0.00000028
# Epoch 820 | Total loss: 0.47125530 | Loss_int: 0.02063086 | Loss_Clamped: 0.00001025 | Loss_dirichlet: 0.00003481
# Epoch 830 | Total loss: 0.06470016 | Loss_int: 0.00786080 | Loss_Clamped: 0.00000362 | Loss_dirichlet: 0.00000206
# Epoch 840 | Total loss: 0.31827092 | Loss_int: 0.02020349 | Loss_Clamped: 0.00001926 | Loss_dirichlet: 0.00001055
# Epoch 850 | Total loss: 0.02044235 | Loss_int: 0.00646410 | Loss_Clamped: 0.00000093 | Loss_dirichlet: 0.00000047
# Epoch 860 | Total loss: 0.02007646 | Loss_int: 0.00639389 | Loss_Clamped: 0.00000063 | Loss_dirichlet: 0.00000074
# Epoch 870 | Total loss: 0.01036183 | Loss_int: 0.00606370 | Loss_Clamped: 0.00000023 | Loss_dirichlet: 0.00000020
# Epoch 880 | Total loss: 0.02036172 | Loss_int: 0.00568065 | Loss_Clamped: 0.00000085 | Loss_dirichlet: 0.00000062
# Epoch 890 | Total loss: 0.20011020 | Loss_int: 0.01399896 | Loss_Clamped: 0.00001350 | Loss_dirichlet: 0.00000511
# Epoch 900 | Total loss: 0.32605249 | Loss_int: 0.01705528 | Loss_Clamped: 0.00001953 | Loss_dirichlet: 0.00001137
# Epoch 910 | Total loss: 0.03346788 | Loss_int: 0.00779024 | Loss_Clamped: 0.00000164 | Loss_dirichlet: 0.00000093
# Epoch 920 | Total loss: 0.17572914 | Loss_int: 0.01231830 | Loss_Clamped: 0.00000734 | Loss_dirichlet: 0.00000900
# Epoch 930 | Total loss: 0.04813437 | Loss_int: 0.00693066 | Loss_Clamped: 0.00000249 | Loss_dirichlet: 0.00000163
# Epoch 940 | Total loss: 0.02429904 | Loss_int: 0.00567865 | Loss_Clamped: 0.00000107 | Loss_dirichlet: 0.00000079
# Epoch 950 | Total loss: 0.16047582 | Loss_int: 0.01357309 | Loss_Clamped: 0.00000540 | Loss_dirichlet: 0.00000929
# Epoch 960 | Total loss: 0.02084409 | Loss_int: 0.00536912 | Loss_Clamped: 0.00000103 | Loss_dirichlet: 0.00000052
# Epoch 970 | Total loss: 0.02390984 | Loss_int: 0.00570264 | Loss_Clamped: 0.00000097 | Loss_dirichlet: 0.00000085
# Epoch 980 | Total loss: 0.19258310 | Loss_int: 0.01017075 | Loss_Clamped: 0.00001244 | Loss_dirichlet: 0.00000580
# Epoch 990 | Total loss: 0.09239371 | Loss_int: 0.00952175 | Loss_Clamped: 0.00000514 | Loss_dirichlet: 0.00000315
# Epoch 1000 | Total loss: 0.61152142 | Loss_int: 0.01867577 | Loss_Clamped: 0.00001702 | Loss_dirichlet: 0.00004226
# Epoch 1010 | Total loss: 0.00659643 | Loss_int: 0.00436897 | Loss_Clamped: 0.00000009 | Loss_dirichlet: 0.00000013
# Epoch 1020 | Total loss: 0.01002487 | Loss_int: 0.00432643 | Loss_Clamped: 0.00000021 | Loss_dirichlet: 0.00000036
# Epoch 1030 | Total loss: 0.00674995 | Loss_int: 0.00432150 | Loss_Clamped: 0.00000011 | Loss_dirichlet: 0.00000014
# Epoch 1040 | Total loss: 0.03882185 | Loss_int: 0.00922353 | Loss_Clamped: 0.00000182 | Loss_dirichlet: 0.00000114
# Epoch 1050 | Total loss: 0.33935946 | Loss_int: 0.01464723 | Loss_Clamped: 0.00001080 | Loss_dirichlet: 0.00002167
# Epoch 1060 | Total loss: 0.02938118 | Loss_int: 0.00488620 | Loss_Clamped: 0.00000141 | Loss_dirichlet: 0.00000104
# Epoch 1070 | Total loss: 0.00952891 | Loss_int: 0.00477314 | Loss_Clamped: 0.00000025 | Loss_dirichlet: 0.00000022
# Epoch 1080 | Total loss: 0.00971144 | Loss_int: 0.00428251 | Loss_Clamped: 0.00000031 | Loss_dirichlet: 0.00000023
# Epoch 1090 | Total loss: 0.24279563 | Loss_int: 0.02419039 | Loss_Clamped: 0.00001457 | Loss_dirichlet: 0.00000729
# Epoch 1100 | Total loss: 0.36927611 | Loss_int: 0.02026183 | Loss_Clamped: 0.00002390 | Loss_dirichlet: 0.00001100
# Epoch 1110 | Total loss: 0.13418594 | Loss_int: 0.01480485 | Loss_Clamped: 0.00000695 | Loss_dirichlet: 0.00000499
# Epoch 1120 | Total loss: 0.04112917 | Loss_int: 0.01779613 | Loss_Clamped: 0.00000150 | Loss_dirichlet: 0.00000083
# Epoch 1130 | Total loss: 0.03160715 | Loss_int: 0.00436008 | Loss_Clamped: 0.00000139 | Loss_dirichlet: 0.00000133
# Epoch 1140 | Total loss: 0.06705665 | Loss_int: 0.00626349 | Loss_Clamped: 0.00000303 | Loss_dirichlet: 0.00000305
# Epoch 1150 | Total loss: 0.02583181 | Loss_int: 0.00564456 | Loss_Clamped: 0.00000112 | Loss_dirichlet: 0.00000089
# Epoch 1160 | Total loss: 0.01592506 | Loss_int: 0.00697393 | Loss_Clamped: 0.00000049 | Loss_dirichlet: 0.00000041
# Epoch 1170 | Total loss: 0.01295037 | Loss_int: 0.00404678 | Loss_Clamped: 0.00000040 | Loss_dirichlet: 0.00000049
# Epoch 1180 | Total loss: 0.01114823 | Loss_int: 0.00372937 | Loss_Clamped: 0.00000033 | Loss_dirichlet: 0.00000042
# Epoch 1190 | Total loss: 0.01783895 | Loss_int: 0.00346611 | Loss_Clamped: 0.00000079 | Loss_dirichlet: 0.00000065
# Epoch 1200 | Total loss: 0.02875549 | Loss_int: 0.00365940 | Loss_Clamped: 0.00000119 | Loss_dirichlet: 0.00000132
# Epoch 1210 | Total loss: 0.16313760 | Loss_int: 0.01977508 | Loss_Clamped: 0.00000365 | Loss_dirichlet: 0.00001069
# Epoch 1220 | Total loss: 0.02457057 | Loss_int: 0.00536796 | Loss_Clamped: 0.00000126 | Loss_dirichlet: 0.00000066
# Epoch 1230 | Total loss: 0.10355123 | Loss_int: 0.02592262 | Loss_Clamped: 0.00000349 | Loss_dirichlet: 0.00000428
# Epoch 1240 | Total loss: 0.00951361 | Loss_int: 0.00320815 | Loss_Clamped: 0.00000037 | Loss_dirichlet: 0.00000026
# Epoch 1250 | Total loss: 0.26072323 | Loss_int: 0.01629036 | Loss_Clamped: 0.00001780 | Loss_dirichlet: 0.00000665
# Epoch 1260 | Total loss: 0.28056186 | Loss_int: 0.01797413 | Loss_Clamped: 0.00001395 | Loss_dirichlet: 0.00001231
# Epoch 1270 | Total loss: 0.10590865 | Loss_int: 0.01970271 | Loss_Clamped: 0.00000456 | Loss_dirichlet: 0.00000406
# Epoch 1280 | Total loss: 0.02042184 | Loss_int: 0.00531786 | Loss_Clamped: 0.00000090 | Loss_dirichlet: 0.00000061
# Epoch 1290 | Total loss: 0.09259434 | Loss_int: 0.02352886 | Loss_Clamped: 0.00000432 | Loss_dirichlet: 0.00000259
# Epoch 1300 | Total loss: 0.00831668 | Loss_int: 0.00299715 | Loss_Clamped: 0.00000029 | Loss_dirichlet: 0.00000024
# Epoch 1310 | Total loss: 0.01163048 | Loss_int: 0.00327175 | Loss_Clamped: 0.00000052 | Loss_dirichlet: 0.00000032
# Epoch 1320 | Total loss: 0.23937778 | Loss_int: 0.02299288 | Loss_Clamped: 0.00000948 | Loss_dirichlet: 0.00001216
# Epoch 1330 | Total loss: 0.01705844 | Loss_int: 0.00379239 | Loss_Clamped: 0.00000086 | Loss_dirichlet: 0.00000047
# Epoch 1340 | Total loss: 0.03547488 | Loss_int: 0.00495185 | Loss_Clamped: 0.00000136 | Loss_dirichlet: 0.00000170
# Epoch 1350 | Total loss: 0.20743676 | Loss_int: 0.05769039 | Loss_Clamped: 0.00001060 | Loss_dirichlet: 0.00000437
# Epoch 1360 | Total loss: 0.01509744 | Loss_int: 0.00411061 | Loss_Clamped: 0.00000063 | Loss_dirichlet: 0.00000047
# Epoch 1370 | Total loss: 0.08556642 | Loss_int: 0.00447602 | Loss_Clamped: 0.00000419 | Loss_dirichlet: 0.00000392
# Epoch 1380 | Total loss: 0.24974528 | Loss_int: 0.02444595 | Loss_Clamped: 0.00000938 | Loss_dirichlet: 0.00001315
# Epoch 1390 | Total loss: 0.08403720 | Loss_int: 0.04381796 | Loss_Clamped: 0.00000322 | Loss_dirichlet: 0.00000080
# Epoch 1400 | Total loss: 0.01061127 | Loss_int: 0.00264112 | Loss_Clamped: 0.00000041 | Loss_dirichlet: 0.00000039
# Epoch 1410 | Total loss: 0.21839905 | Loss_int: 0.01424836 | Loss_Clamped: 0.00000759 | Loss_dirichlet: 0.00001282
# Epoch 1420 | Total loss: 0.01168852 | Loss_int: 0.00355424 | Loss_Clamped: 0.00000050 | Loss_dirichlet: 0.00000032
# Epoch 1430 | Total loss: 0.00652629 | Loss_int: 0.00302281 | Loss_Clamped: 0.00000019 | Loss_dirichlet: 0.00000016
# Epoch 1440 | Total loss: 0.02102161 | Loss_int: 0.00423585 | Loss_Clamped: 0.00000073 | Loss_dirichlet: 0.00000095
# Epoch 1450 | Total loss: 0.04055495 | Loss_int: 0.00658257 | Loss_Clamped: 0.00000133 | Loss_dirichlet: 0.00000207
# Epoch 1460 | Total loss: 0.26653975 | Loss_int: 0.06682075 | Loss_Clamped: 0.00000910 | Loss_dirichlet: 0.00001087
# Epoch 1470 | Total loss: 0.17315778 | Loss_int: 0.00802370 | Loss_Clamped: 0.00001148 | Loss_dirichlet: 0.00000503
# Epoch 1480 | Total loss: 0.00699589 | Loss_int: 0.00273800 | Loss_Clamped: 0.00000014 | Loss_dirichlet: 0.00000028
# Epoch 1490 | Total loss: 0.00469820 | Loss_int: 0.00230204 | Loss_Clamped: 0.00000011 | Loss_dirichlet: 0.00000013
# Epoch 1500 | Total loss: 0.00477756 | Loss_int: 0.00246217 | Loss_Clamped: 0.00000010 | Loss_dirichlet: 0.00000014
# Epoch 1510 | Total loss: 0.05932783 | Loss_int: 0.00841116 | Loss_Clamped: 0.00000167 | Loss_dirichlet: 0.00000342
# Epoch 1520 | Total loss: 0.02690155 | Loss_int: 0.00591339 | Loss_Clamped: 0.00000130 | Loss_dirichlet: 0.00000080
# Epoch 1530 | Total loss: 0.08779705 | Loss_int: 0.00665514 | Loss_Clamped: 0.00000448 | Loss_dirichlet: 0.00000363
# Epoch 1540 | Total loss: 0.00956588 | Loss_int: 0.00417666 | Loss_Clamped: 0.00000033 | Loss_dirichlet: 0.00000021
# Epoch 1550 | Total loss: 0.01941023 | Loss_int: 0.00452810 | Loss_Clamped: 0.00000057 | Loss_dirichlet: 0.00000092
# Epoch 1560 | Total loss: 0.27872160 | Loss_int: 0.02630388 | Loss_Clamped: 0.00000922 | Loss_dirichlet: 0.00001602
# Epoch 1570 | Total loss: 0.02551952 | Loss_int: 0.00456574 | Loss_Clamped: 0.00000077 | Loss_dirichlet: 0.00000133
# Epoch 1580 | Total loss: 0.09500127 | Loss_int: 0.03128551 | Loss_Clamped: 0.00000479 | Loss_dirichlet: 0.00000158
# Epoch 1590 | Total loss: 0.23018155 | Loss_int: 0.02002744 | Loss_Clamped: 0.00000551 | Loss_dirichlet: 0.00001551
# Epoch 1600 | Total loss: 0.00467686 | Loss_int: 0.00237670 | Loss_Clamped: 0.00000011 | Loss_dirichlet: 0.00000012
# Epoch 1610 | Total loss: 0.00956411 | Loss_int: 0.00280880 | Loss_Clamped: 0.00000032 | Loss_dirichlet: 0.00000036
# Epoch 1620 | Total loss: 0.08398052 | Loss_int: 0.00993204 | Loss_Clamped: 0.00000514 | Loss_dirichlet: 0.00000226
# Epoch 1630 | Total loss: 0.02955667 | Loss_int: 0.00450108 | Loss_Clamped: 0.00000109 | Loss_dirichlet: 0.00000142
# Epoch 1640 | Total loss: 0.05620816 | Loss_int: 0.01377605 | Loss_Clamped: 0.00000273 | Loss_dirichlet: 0.00000151
# Epoch 1650 | Total loss: 0.07061945 | Loss_int: 0.00770444 | Loss_Clamped: 0.00000421 | Loss_dirichlet: 0.00000209
# Epoch 1660 | Total loss: 0.00969409 | Loss_int: 0.00273030 | Loss_Clamped: 0.00000042 | Loss_dirichlet: 0.00000028
# Epoch 1670 | Total loss: 0.01497807 | Loss_int: 0.00305915 | Loss_Clamped: 0.00000078 | Loss_dirichlet: 0.00000041
# Epoch 1680 | Total loss: 0.04467542 | Loss_int: 0.00697613 | Loss_Clamped: 0.00000158 | Loss_dirichlet: 0.00000219
# Epoch 1690 | Total loss: 0.20894523 | Loss_int: 0.01001989 | Loss_Clamped: 0.00001196 | Loss_dirichlet: 0.00000793
# Epoch 1700 | Total loss: 0.00371875 | Loss_int: 0.00194677 | Loss_Clamped: 0.00000007 | Loss_dirichlet: 0.00000011
# Epoch 1710 | Total loss: 0.00487930 | Loss_int: 0.00205608 | Loss_Clamped: 0.00000010 | Loss_dirichlet: 0.00000018
# Epoch 1720 | Total loss: 0.03856650 | Loss_int: 0.01421257 | Loss_Clamped: 0.00000168 | Loss_dirichlet: 0.00000076
# Epoch 1730 | Total loss: 0.01543399 | Loss_int: 0.00322368 | Loss_Clamped: 0.00000057 | Loss_dirichlet: 0.00000065
# Epoch 1740 | Total loss: 0.16840236 | Loss_int: 0.01039016 | Loss_Clamped: 0.00000657 | Loss_dirichlet: 0.00000924
# Epoch 1750 | Total loss: 0.24379659 | Loss_int: 0.01348259 | Loss_Clamped: 0.00000961 | Loss_dirichlet: 0.00001342
# Epoch 1760 | Total loss: 0.09162702 | Loss_int: 0.02211535 | Loss_Clamped: 0.00000370 | Loss_dirichlet: 0.00000325
# Epoch 1770 | Total loss: 0.08530940 | Loss_int: 0.01869958 | Loss_Clamped: 0.00000439 | Loss_dirichlet: 0.00000228
# Epoch 1780 | Total loss: 0.79393226 | Loss_int: 0.05948504 | Loss_Clamped: 0.00001874 | Loss_dirichlet: 0.00005470
# Epoch 1790 | Total loss: 0.00438739 | Loss_int: 0.00220052 | Loss_Clamped: 0.00000010 | Loss_dirichlet: 0.00000012
# Epoch 1800 | Total loss: 0.00380256 | Loss_int: 0.00195607 | Loss_Clamped: 0.00000008 | Loss_dirichlet: 0.00000011
# Epoch 1810 | Total loss: 0.00938947 | Loss_int: 0.00255946 | Loss_Clamped: 0.00000033 | Loss_dirichlet: 0.00000035
# Epoch 1820 | Total loss: 0.03940601 | Loss_int: 0.00539309 | Loss_Clamped: 0.00000114 | Loss_dirichlet: 0.00000226
# Epoch 1830 | Total loss: 0.03196246 | Loss_int: 0.00707709 | Loss_Clamped: 0.00000087 | Loss_dirichlet: 0.00000162
# Epoch 1840 | Total loss: 0.01584004 | Loss_int: 0.00816618 | Loss_Clamped: 0.00000056 | Loss_dirichlet: 0.00000021
# Epoch 1850 | Total loss: 0.02496405 | Loss_int: 0.00314498 | Loss_Clamped: 0.00000129 | Loss_dirichlet: 0.00000089
# Epoch 1860 | Total loss: 0.01841607 | Loss_int: 0.00927596 | Loss_Clamped: 0.00000071 | Loss_dirichlet: 0.00000020
# Epoch 1870 | Total loss: 0.03374838 | Loss_int: 0.00715781 | Loss_Clamped: 0.00000158 | Loss_dirichlet: 0.00000108
# Epoch 1880 | Total loss: 0.11765523 | Loss_int: 0.04226925 | Loss_Clamped: 0.00000553 | Loss_dirichlet: 0.00000201
# Epoch 1890 | Total loss: 0.07500974 | Loss_int: 0.00236568 | Loss_Clamped: 0.00000487 | Loss_dirichlet: 0.00000240
# Epoch 1900 | Total loss: 0.04378030 | Loss_int: 0.00489990 | Loss_Clamped: 0.00000128 | Loss_dirichlet: 0.00000261
# Epoch 1910 | Total loss: 0.22477213 | Loss_int: 0.01380585 | Loss_Clamped: 0.00000648 | Loss_dirichlet: 0.00001461
# Epoch 1920 | Total loss: 0.03952549 | Loss_int: 0.00509707 | Loss_Clamped: 0.00000172 | Loss_dirichlet: 0.00000172
# Epoch 1930 | Total loss: 0.13097917 | Loss_int: 0.00558326 | Loss_Clamped: 0.00000735 | Loss_dirichlet: 0.00000518
# Epoch 1940 | Total loss: 0.00376055 | Loss_int: 0.00169896 | Loss_Clamped: 0.00000009 | Loss_dirichlet: 0.00000012
# Epoch 1950 | Total loss: 0.23578091 | Loss_int: 0.03036479 | Loss_Clamped: 0.00001134 | Loss_dirichlet: 0.00000921
# Epoch 1960 | Total loss: 0.01358264 | Loss_int: 0.00210611 | Loss_Clamped: 0.00000051 | Loss_dirichlet: 0.00000063
# Epoch 1970 | Total loss: 0.26839310 | Loss_int: 0.01395467 | Loss_Clamped: 0.00001364 | Loss_dirichlet: 0.00001181
# Epoch 1980 | Total loss: 0.06520440 | Loss_int: 0.00849936 | Loss_Clamped: 0.00000228 | Loss_dirichlet: 0.00000339
# Epoch 1990 | Total loss: 0.03308278 | Loss_int: 0.00977633 | Loss_Clamped: 0.00000103 | Loss_dirichlet: 0.00000130
# Epoch 2000 | Total loss: 0.02513518 | Loss_int: 0.00852905 | Loss_Clamped: 0.00000097 | Loss_dirichlet: 0.00000069
# Epoch 2010 | Total loss: 0.02074387 | Loss_int: 0.00315271 | Loss_Clamped: 0.00000117 | Loss_dirichlet: 0.00000059
# Epoch 2020 | Total loss: 0.03131549 | Loss_int: 0.00404515 | Loss_Clamped: 0.00000186 | Loss_dirichlet: 0.00000086
# Epoch 2030 | Total loss: 0.07473716 | Loss_int: 0.01677004 | Loss_Clamped: 0.00000321 | Loss_dirichlet: 0.00000259
# Epoch 2040 | Total loss: 0.07858722 | Loss_int: 0.02621202 | Loss_Clamped: 0.00000365 | Loss_dirichlet: 0.00000159
# Epoch 2050 | Total loss: 0.02985278 | Loss_int: 0.00480424 | Loss_Clamped: 0.00000141 | Loss_dirichlet: 0.00000110
# Epoch 2060 | Total loss: 0.01494256 | Loss_int: 0.00464982 | Loss_Clamped: 0.00000057 | Loss_dirichlet: 0.00000046
# Epoch 2070 | Total loss: 0.11074743 | Loss_int: 0.01038093 | Loss_Clamped: 0.00000281 | Loss_dirichlet: 0.00000722
# Epoch 2080 | Total loss: 0.00842913 | Loss_int: 0.00328750 | Loss_Clamped: 0.00000027 | Loss_dirichlet: 0.00000025
# Epoch 2090 | Total loss: 0.00662686 | Loss_int: 0.00274403 | Loss_Clamped: 0.00000024 | Loss_dirichlet: 0.00000015
# Epoch 2100 | Total loss: 0.02229816 | Loss_int: 0.00236068 | Loss_Clamped: 0.00000113 | Loss_dirichlet: 0.00000086
# Epoch 2110 | Total loss: 0.00751057 | Loss_int: 0.00256694 | Loss_Clamped: 0.00000027 | Loss_dirichlet: 0.00000023
# Epoch 2120 | Total loss: 0.05808744 | Loss_int: 0.01697013 | Loss_Clamped: 0.00000285 | Loss_dirichlet: 0.00000127
# Epoch 2130 | Total loss: 0.11111425 | Loss_int: 0.00390376 | Loss_Clamped: 0.00000681 | Loss_dirichlet: 0.00000391
# Epoch 2140 | Total loss: 0.13210492 | Loss_int: 0.00973650 | Loss_Clamped: 0.00000419 | Loss_dirichlet: 0.00000805
# Epoch 2150 | Total loss: 0.02716439 | Loss_int: 0.00298525 | Loss_Clamped: 0.00000149 | Loss_dirichlet: 0.00000092
# Epoch 2160 | Total loss: 0.00554736 | Loss_int: 0.00250968 | Loss_Clamped: 0.00000016 | Loss_dirichlet: 0.00000014
# Epoch 2170 | Total loss: 0.00607997 | Loss_int: 0.00214134 | Loss_Clamped: 0.00000020 | Loss_dirichlet: 0.00000019
# Epoch 2180 | Total loss: 0.14177568 | Loss_int: 0.00585316 | Loss_Clamped: 0.00000948 | Loss_dirichlet: 0.00000411
# Epoch 2190 | Total loss: 0.07665964 | Loss_int: 0.01540581 | Loss_Clamped: 0.00000286 | Loss_dirichlet: 0.00000326
# Epoch 2200 | Total loss: 0.12605919 | Loss_int: 0.00691889 | Loss_Clamped: 0.00000740 | Loss_dirichlet: 0.00000451
# Epoch 2210 | Total loss: 0.01366601 | Loss_int: 0.00204258 | Loss_Clamped: 0.00000051 | Loss_dirichlet: 0.00000065
# Epoch 2220 | Total loss: 0.00719473 | Loss_int: 0.00273857 | Loss_Clamped: 0.00000027 | Loss_dirichlet: 0.00000018
# Epoch 2230 | Total loss: 0.01961496 | Loss_int: 0.00288096 | Loss_Clamped: 0.00000087 | Loss_dirichlet: 0.00000081
# Epoch 2240 | Total loss: 0.23298232 | Loss_int: 0.02086334 | Loss_Clamped: 0.00000756 | Loss_dirichlet: 0.00001366
# Epoch 2250 | Total loss: 0.07511954 | Loss_int: 0.00777813 | Loss_Clamped: 0.00000351 | Loss_dirichlet: 0.00000323
# Epoch 2260 | Total loss: 0.05579184 | Loss_int: 0.00526072 | Loss_Clamped: 0.00000260 | Loss_dirichlet: 0.00000245
# Epoch 2270 | Total loss: 0.44318324 | Loss_int: 0.06402122 | Loss_Clamped: 0.00002074 | Loss_dirichlet: 0.00001717
# Epoch 2280 | Total loss: 0.00284194 | Loss_int: 0.00133445 | Loss_Clamped: 0.00000005 | Loss_dirichlet: 0.00000010
# Epoch 2290 | Total loss: 0.02625425 | Loss_int: 0.00347979 | Loss_Clamped: 0.00000100 | Loss_dirichlet: 0.00000127
# Epoch 2300 | Total loss: 0.05774057 | Loss_int: 0.00755858 | Loss_Clamped: 0.00000304 | Loss_dirichlet: 0.00000198
# Epoch 2310 | Total loss: 0.05057372 | Loss_int: 0.00932890 | Loss_Clamped: 0.00000201 | Loss_dirichlet: 0.00000212
# Epoch 2320 | Total loss: 0.01461076 | Loss_int: 0.00293681 | Loss_Clamped: 0.00000053 | Loss_dirichlet: 0.00000064
# Epoch 2330 | Total loss: 0.00344595 | Loss_int: 0.00159697 | Loss_Clamped: 0.00000009 | Loss_dirichlet: 0.00000010
# Epoch 2340 | Total loss: 0.05597250 | Loss_int: 0.00695279 | Loss_Clamped: 0.00000216 | Loss_dirichlet: 0.00000274
# Epoch 2350 | Total loss: 0.04979445 | Loss_int: 0.00521610 | Loss_Clamped: 0.00000171 | Loss_dirichlet: 0.00000275
# Epoch 2360 | Total loss: 0.07525514 | Loss_int: 0.00562047 | Loss_Clamped: 0.00000305 | Loss_dirichlet: 0.00000392
# Epoch 2370 | Total loss: 0.03817314 | Loss_int: 0.00843418 | Loss_Clamped: 0.00000182 | Loss_dirichlet: 0.00000115
# Epoch 2380 | Total loss: 0.00330013 | Loss_int: 0.00157650 | Loss_Clamped: 0.00000008 | Loss_dirichlet: 0.00000010
# Epoch 2390 | Total loss: 0.00743980 | Loss_int: 0.00147152 | Loss_Clamped: 0.00000027 | Loss_dirichlet: 0.00000032
# Epoch 2400 | Total loss: 0.01785495 | Loss_int: 0.00778416 | Loss_Clamped: 0.00000075 | Loss_dirichlet: 0.00000026
# Epoch 2410 | Total loss: 0.00505787 | Loss_int: 0.00121515 | Loss_Clamped: 0.00000014 | Loss_dirichlet: 0.00000025
# Epoch 2420 | Total loss: 0.08756228 | Loss_int: 0.00500960 | Loss_Clamped: 0.00000601 | Loss_dirichlet: 0.00000224
# Epoch 2430 | Total loss: 0.15191825 | Loss_int: 0.03666774 | Loss_Clamped: 0.00000686 | Loss_dirichlet: 0.00000467
# Epoch 2440 | Total loss: 0.18630086 | Loss_int: 0.01456362 | Loss_Clamped: 0.00000642 | Loss_dirichlet: 0.00001075
# Epoch 2450 | Total loss: 0.02831737 | Loss_int: 0.00338568 | Loss_Clamped: 0.00000163 | Loss_dirichlet: 0.00000087
# Epoch 2460 | Total loss: 0.03302500 | Loss_int: 0.00761513 | Loss_Clamped: 0.00000182 | Loss_dirichlet: 0.00000072
# Epoch 2470 | Total loss: 0.26249415 | Loss_int: 0.04147790 | Loss_Clamped: 0.00001037 | Loss_dirichlet: 0.00001173
# Epoch 2480 | Total loss: 0.00388479 | Loss_int: 0.00118365 | Loss_Clamped: 0.00000012 | Loss_dirichlet: 0.00000015
# Epoch 2490 | Total loss: 0.02865044 | Loss_int: 0.00286209 | Loss_Clamped: 0.00000112 | Loss_dirichlet: 0.00000146
# Epoch 2500 | Total loss: 0.31338355 | Loss_int: 0.03154731 | Loss_Clamped: 0.00001271 | Loss_dirichlet: 0.00001547
# Epoch 2510 | Total loss: 0.00513761 | Loss_int: 0.00178895 | Loss_Clamped: 0.00000012 | Loss_dirichlet: 0.00000022
# Epoch 2520 | Total loss: 0.17615804 | Loss_int: 0.02894270 | Loss_Clamped: 0.00000979 | Loss_dirichlet: 0.00000493
# Epoch 2530 | Total loss: 0.05726879 | Loss_int: 0.01338567 | Loss_Clamped: 0.00000161 | Loss_dirichlet: 0.00000278
# Epoch 2540 | Total loss: 0.31420571 | Loss_int: 0.03983758 | Loss_Clamped: 0.00000948 | Loss_dirichlet: 0.00001796
# Epoch 2550 | Total loss: 0.00456272 | Loss_int: 0.00118495 | Loss_Clamped: 0.00000013 | Loss_dirichlet: 0.00000020
# Epoch 2560 | Total loss: 0.00769852 | Loss_int: 0.00355424 | Loss_Clamped: 0.00000027 | Loss_dirichlet: 0.00000014
# Epoch 2570 | Total loss: 0.01034115 | Loss_int: 0.00392487 | Loss_Clamped: 0.00000033 | Loss_dirichlet: 0.00000031
# Epoch 2580 | Total loss: 0.00787915 | Loss_int: 0.00332821 | Loss_Clamped: 0.00000024 | Loss_dirichlet: 0.00000021
# Epoch 2590 | Total loss: 0.08642627 | Loss_int: 0.01898314 | Loss_Clamped: 0.00000480 | Loss_dirichlet: 0.00000194
# Epoch 2600 | Total loss: 0.01911794 | Loss_int: 0.00239372 | Loss_Clamped: 0.00000090 | Loss_dirichlet: 0.00000077
# Epoch 2610 | Total loss: 0.00377573 | Loss_int: 0.00170664 | Loss_Clamped: 0.00000009 | Loss_dirichlet: 0.00000012
# Epoch 2620 | Total loss: 0.03450163 | Loss_int: 0.00318643 | Loss_Clamped: 0.00000190 | Loss_dirichlet: 0.00000124
# Epoch 2630 | Total loss: 0.17018449 | Loss_int: 0.01816822 | Loss_Clamped: 0.00000636 | Loss_dirichlet: 0.00000884
# Epoch 2640 | Total loss: 0.13009378 | Loss_int: 0.01396493 | Loss_Clamped: 0.00000725 | Loss_dirichlet: 0.00000436
# Epoch 2650 | Total loss: 0.11321087 | Loss_int: 0.03018858 | Loss_Clamped: 0.00000627 | Loss_dirichlet: 0.00000203
# Epoch 2660 | Total loss: 0.05278451 | Loss_int: 0.00486234 | Loss_Clamped: 0.00000159 | Loss_dirichlet: 0.00000320
# Epoch 2670 | Total loss: 0.12744023 | Loss_int: 0.01144294 | Loss_Clamped: 0.00000481 | Loss_dirichlet: 0.00000678
# Epoch 2680 | Total loss: 0.01582433 | Loss_int: 0.00486218 | Loss_Clamped: 0.00000076 | Loss_dirichlet: 0.00000034
# Epoch 2690 | Total loss: 0.03880871 | Loss_int: 0.01268055 | Loss_Clamped: 0.00000209 | Loss_dirichlet: 0.00000052
# Epoch 2700 | Total loss: 0.02512867 | Loss_int: 0.00739985 | Loss_Clamped: 0.00000114 | Loss_dirichlet: 0.00000063
# Epoch 2710 | Total loss: 0.00918460 | Loss_int: 0.00251945 | Loss_Clamped: 0.00000037 | Loss_dirichlet: 0.00000030
# Epoch 2720 | Total loss: 0.03548192 | Loss_int: 0.00213922 | Loss_Clamped: 0.00000196 | Loss_dirichlet: 0.00000137
# Epoch 2730 | Total loss: 0.09063561 | Loss_int: 0.01293756 | Loss_Clamped: 0.00000438 | Loss_dirichlet: 0.00000339
# Epoch 2740 | Total loss: 0.07822223 | Loss_int: 0.00977169 | Loss_Clamped: 0.00000452 | Loss_dirichlet: 0.00000233
# Epoch 2750 | Total loss: 0.01629191 | Loss_int: 0.00707448 | Loss_Clamped: 0.00000064 | Loss_dirichlet: 0.00000028
# Epoch 2760 | Total loss: 0.00899319 | Loss_int: 0.00231562 | Loss_Clamped: 0.00000043 | Loss_dirichlet: 0.00000024
# Epoch 2770 | Total loss: 0.01045792 | Loss_int: 0.00378659 | Loss_Clamped: 0.00000046 | Loss_dirichlet: 0.00000021
# Epoch 2780 | Total loss: 0.04505717 | Loss_int: 0.01683860 | Loss_Clamped: 0.00000188 | Loss_dirichlet: 0.00000094
# Epoch 2790 | Total loss: 0.20048721 | Loss_int: 0.03887601 | Loss_Clamped: 0.00001041 | Loss_dirichlet: 0.00000575
# Epoch 2800 | Total loss: 0.08030694 | Loss_int: 0.00729524 | Loss_Clamped: 0.00000201 | Loss_dirichlet: 0.00000529
# Epoch 2810 | Total loss: 0.00433140 | Loss_int: 0.00150357 | Loss_Clamped: 0.00000015 | Loss_dirichlet: 0.00000013
# Epoch 2820 | Total loss: 0.05502587 | Loss_int: 0.00912408 | Loss_Clamped: 0.00000209 | Loss_dirichlet: 0.00000250
# Epoch 2830 | Total loss: 0.00876960 | Loss_int: 0.00164204 | Loss_Clamped: 0.00000039 | Loss_dirichlet: 0.00000032
# Epoch 2840 | Total loss: 0.16489428 | Loss_int: 0.02924856 | Loss_Clamped: 0.00000663 | Loss_dirichlet: 0.00000694
# Epoch 2850 | Total loss: 0.02681922 | Loss_int: 0.00640983 | Loss_Clamped: 0.00000086 | Loss_dirichlet: 0.00000118
# Epoch 2860 | Total loss: 0.04245099 | Loss_int: 0.00534900 | Loss_Clamped: 0.00000191 | Loss_dirichlet: 0.00000180
# Epoch 2870 | Total loss: 0.29175124 | Loss_int: 0.06928765 | Loss_Clamped: 0.00001614 | Loss_dirichlet: 0.00000610
# Epoch 2880 | Total loss: 0.00338679 | Loss_int: 0.00104139 | Loss_Clamped: 0.00000011 | Loss_dirichlet: 0.00000012
# Epoch 2890 | Total loss: 0.01772162 | Loss_int: 0.00618375 | Loss_Clamped: 0.00000083 | Loss_dirichlet: 0.00000033
# Epoch 2900 | Total loss: 0.06936929 | Loss_int: 0.00177222 | Loss_Clamped: 0.00000477 | Loss_dirichlet: 0.00000199
# Epoch 2910 | Total loss: 0.01609437 | Loss_int: 0.00194848 | Loss_Clamped: 0.00000062 | Loss_dirichlet: 0.00000079
# Epoch 2920 | Total loss: 0.01143058 | Loss_int: 0.00422842 | Loss_Clamped: 0.00000035 | Loss_dirichlet: 0.00000037
# Epoch 2930 | Total loss: 0.00230904 | Loss_int: 0.00111495 | Loss_Clamped: 0.00000005 | Loss_dirichlet: 0.00000007
# Epoch 2940 | Total loss: 0.00379440 | Loss_int: 0.00144513 | Loss_Clamped: 0.00000013 | Loss_dirichlet: 0.00000010
# Epoch 2950 | Total loss: 0.00332993 | Loss_int: 0.00097256 | Loss_Clamped: 0.00000009 | Loss_dirichlet: 0.00000015
# Epoch 2960 | Total loss: 0.00467747 | Loss_int: 0.00205873 | Loss_Clamped: 0.00000015 | Loss_dirichlet: 0.00000011
# Epoch 2970 | Total loss: 0.00268490 | Loss_int: 0.00110722 | Loss_Clamped: 0.00000008 | Loss_dirichlet: 0.00000008
# Epoch 2980 | Total loss: 0.00595152 | Loss_int: 0.00229989 | Loss_Clamped: 0.00000023 | Loss_dirichlet: 0.00000014
# Epoch 2990 | Total loss: 0.02090823 | Loss_int: 0.00504770 | Loss_Clamped: 0.00000111 | Loss_dirichlet: 0.00000047
# Epoch 3000 | Total loss: 0.00846010 | Loss_int: 0.00266809 | Loss_Clamped: 0.00000024 | Loss_dirichlet: 0.00000033
# Epoch 3010 | Total loss: 0.05385652 | Loss_int: 0.01498300 | Loss_Clamped: 0.00000280 | Loss_dirichlet: 0.00000108
# Epoch 3020 | Total loss: 0.08492541 | Loss_int: 0.02336542 | Loss_Clamped: 0.00000440 | Loss_dirichlet: 0.00000175
# Epoch 3030 | Total loss: 0.10688838 | Loss_int: 0.00633080 | Loss_Clamped: 0.00000563 | Loss_dirichlet: 0.00000443
# Epoch 3040 | Total loss: 0.04622816 | Loss_int: 0.00855464 | Loss_Clamped: 0.00000154 | Loss_dirichlet: 0.00000223
# Epoch 3050 | Total loss: 0.03962224 | Loss_int: 0.01200133 | Loss_Clamped: 0.00000189 | Loss_dirichlet: 0.00000088
# Epoch 3060 | Total loss: 0.01264893 | Loss_int: 0.00168312 | Loss_Clamped: 0.00000070 | Loss_dirichlet: 0.00000039
# Epoch 3070 | Total loss: 0.00439485 | Loss_int: 0.00229775 | Loss_Clamped: 0.00000014 | Loss_dirichlet: 0.00000007
# Epoch 3080 | Total loss: 0.02434439 | Loss_int: 0.01460740 | Loss_Clamped: 0.00000083 | Loss_dirichlet: 0.00000014
# Epoch 3090 | Total loss: 0.01612020 | Loss_int: 0.00171122 | Loss_Clamped: 0.00000069 | Loss_dirichlet: 0.00000075
# Epoch 3100 | Total loss: 0.02432202 | Loss_int: 0.00444420 | Loss_Clamped: 0.00000113 | Loss_dirichlet: 0.00000086
# Epoch 3110 | Total loss: 0.00855311 | Loss_int: 0.00152847 | Loss_Clamped: 0.00000046 | Loss_dirichlet: 0.00000024
# Epoch 3120 | Total loss: 0.00593117 | Loss_int: 0.00181967 | Loss_Clamped: 0.00000023 | Loss_dirichlet: 0.00000019
# Epoch 3130 | Total loss: 0.03178675 | Loss_int: 0.00361267 | Loss_Clamped: 0.00000171 | Loss_dirichlet: 0.00000111
# Epoch 3140 | Total loss: 0.03326393 | Loss_int: 0.00446768 | Loss_Clamped: 0.00000141 | Loss_dirichlet: 0.00000147
# Epoch 3150 | Total loss: 0.01132217 | Loss_int: 0.00367505 | Loss_Clamped: 0.00000051 | Loss_dirichlet: 0.00000025
# Epoch 3160 | Total loss: 0.00593693 | Loss_int: 0.00122365 | Loss_Clamped: 0.00000030 | Loss_dirichlet: 0.00000017
# Epoch 3170 | Total loss: 0.01637730 | Loss_int: 0.00289517 | Loss_Clamped: 0.00000092 | Loss_dirichlet: 0.00000043
# Epoch 3180 | Total loss: 0.08078547 | Loss_int: 0.00625048 | Loss_Clamped: 0.00000325 | Loss_dirichlet: 0.00000420
# Epoch 3190 | Total loss: 0.00817194 | Loss_int: 0.00118818 | Loss_Clamped: 0.00000022 | Loss_dirichlet: 0.00000048
# Epoch 3200 | Total loss: 0.01465955 | Loss_int: 0.00518908 | Loss_Clamped: 0.00000050 | Loss_dirichlet: 0.00000045
# Epoch 3210 | Total loss: 0.15325528 | Loss_int: 0.01378039 | Loss_Clamped: 0.00000432 | Loss_dirichlet: 0.00000962
# Epoch 3220 | Total loss: 0.04244471 | Loss_int: 0.00972865 | Loss_Clamped: 0.00000221 | Loss_dirichlet: 0.00000106
# Epoch 3230 | Total loss: 0.00880486 | Loss_int: 0.00155535 | Loss_Clamped: 0.00000040 | Loss_dirichlet: 0.00000033
# Epoch 3240 | Total loss: 0.00460922 | Loss_int: 0.00151636 | Loss_Clamped: 0.00000016 | Loss_dirichlet: 0.00000015
# Epoch 3250 | Total loss: 0.08336897 | Loss_int: 0.01124853 | Loss_Clamped: 0.00000230 | Loss_dirichlet: 0.00000492
# Epoch 3260 | Total loss: 0.01210407 | Loss_int: 0.00447154 | Loss_Clamped: 0.00000050 | Loss_dirichlet: 0.00000027
# Epoch 3270 | Total loss: 0.03702487 | Loss_int: 0.00129600 | Loss_Clamped: 0.00000252 | Loss_dirichlet: 0.00000106
# Epoch 3280 | Total loss: 0.13053069 | Loss_int: 0.02172984 | Loss_Clamped: 0.00000449 | Loss_dirichlet: 0.00000639
# Epoch 3290 | Total loss: 0.00117449 | Loss_int: 0.00059548 | Loss_Clamped: 0.00000001 | Loss_dirichlet: 0.00000005
# Epoch 3300 | Total loss: 0.00116459 | Loss_int: 0.00058705 | Loss_Clamped: 0.00000001 | Loss_dirichlet: 0.00000005
# Epoch 3310 | Total loss: 0.00115709 | Loss_int: 0.00058085 | Loss_Clamped: 0.00000001 | Loss_dirichlet: 0.00000005
# Epoch 3320 | Total loss: 0.00114968 | Loss_int: 0.00057409 | Loss_Clamped: 0.00000001 | Loss_dirichlet: 0.00000005
# Epoch 3330 | Total loss: 0.00114295 | Loss_int: 0.00056784 | Loss_Clamped: 0.00000001 | Loss_dirichlet: 0.00000005
# Epoch 3340 | Total loss: 0.00113823 | Loss_int: 0.00056302 | Loss_Clamped: 0.00000001 | Loss_dirichlet: 0.00000005
# Epoch 3350 | Total loss: 0.00113362 | Loss_int: 0.00055940 | Loss_Clamped: 0.00000001 | Loss_dirichlet: 0.00000005
# Epoch 3360 | Total loss: 0.00112737 | Loss_int: 0.00055378 | Loss_Clamped: 0.00000001 | Loss_dirichlet: 0.00000005
# Epoch 3370 | Total loss: 0.00112156 | Loss_int: 0.00054873 | Loss_Clamped: 0.00000001 | Loss_dirichlet: 0.00000005
# Epoch 3380 | Total loss: 0.00111711 | Loss_int: 0.00054474 | Loss_Clamped: 0.00000001 | Loss_dirichlet: 0.00000005
# Epoch 3390 | Total loss: 0.00111120 | Loss_int: 0.00053960 | Loss_Clamped: 0.00000001 | Loss_dirichlet: 0.00000005
# Epoch 3400 | Total loss: 0.00110707 | Loss_int: 0.00053592 | Loss_Clamped: 0.00000001 | Loss_dirichlet: 0.00000005
# Epoch 3410 | Total loss: 0.00110281 | Loss_int: 0.00053119 | Loss_Clamped: 0.00000001 | Loss_dirichlet: 0.00000005
# Epoch 3420 | Total loss: 0.00109656 | Loss_int: 0.00052604 | Loss_Clamped: 0.00000001 | Loss_dirichlet: 0.00000005
# Epoch 3430 | Total loss: 0.00109258 | Loss_int: 0.00052279 | Loss_Clamped: 0.00000001 | Loss_dirichlet: 0.00000005
# Epoch 3440 | Total loss: 0.00108697 | Loss_int: 0.00051860 | Loss_Clamped: 0.00000001 | Loss_dirichlet: 0.00000005
# Epoch 3450 | Total loss: 0.00108251 | Loss_int: 0.00051561 | Loss_Clamped: 0.00000001 | Loss_dirichlet: 0.00000005
# Epoch 3460 | Total loss: 0.00107609 | Loss_int: 0.00050924 | Loss_Clamped: 0.00000001 | Loss_dirichlet: 0.00000005
# Epoch 3470 | Total loss: 0.00106990 | Loss_int: 0.00050385 | Loss_Clamped: 0.00000001 | Loss_dirichlet: 0.00000005
# Epoch 3480 | Total loss: 0.00106489 | Loss_int: 0.00049981 | Loss_Clamped: 0.00000001 | Loss_dirichlet: 0.00000005
# Epoch 3490 | Total loss: 0.00105836 | Loss_int: 0.00049555 | Loss_Clamped: 0.00000001 | Loss_dirichlet: 0.00000005
# Epoch 3500 | Total loss: 0.00105440 | Loss_int: 0.00049204 | Loss_Clamped: 0.00000001 | Loss_dirichlet: 0.00000005
# Epoch 3510 | Total loss: 0.00104815 | Loss_int: 0.00048815 | Loss_Clamped: 0.00000001 | Loss_dirichlet: 0.00000005
# Epoch 3520 | Total loss: 0.00104501 | Loss_int: 0.00048615 | Loss_Clamped: 0.00000001 | Loss_dirichlet: 0.00000005
# Epoch 3530 | Total loss: 0.00103491 | Loss_int: 0.00047812 | Loss_Clamped: 0.00000001 | Loss_dirichlet: 0.00000005
# Epoch 3540 | Total loss: 0.00102975 | Loss_int: 0.00047390 | Loss_Clamped: 0.00000001 | Loss_dirichlet: 0.00000005
# Epoch 3550 | Total loss: 0.00102462 | Loss_int: 0.00046857 | Loss_Clamped: 0.00000001 | Loss_dirichlet: 0.00000005
# Epoch 3560 | Total loss: 0.00101852 | Loss_int: 0.00046542 | Loss_Clamped: 0.00000001 | Loss_dirichlet: 0.00000005
# Epoch 3570 | Total loss: 0.00100964 | Loss_int: 0.00045831 | Loss_Clamped: 0.00000001 | Loss_dirichlet: 0.00000005
# Epoch 3580 | Total loss: 0.00101248 | Loss_int: 0.00045863 | Loss_Clamped: 0.00000001 | Loss_dirichlet: 0.00000005
# Epoch 3590 | Total loss: 0.00099761 | Loss_int: 0.00045038 | Loss_Clamped: 0.00000001 | Loss_dirichlet: 0.00000005
# Epoch 3600 | Total loss: 0.00098888 | Loss_int: 0.00044329 | Loss_Clamped: 0.00000001 | Loss_dirichlet: 0.00000005
# Epoch 3610 | Total loss: 0.00098003 | Loss_int: 0.00043873 | Loss_Clamped: 0.00000001 | Loss_dirichlet: 0.00000005
# Epoch 3620 | Total loss: 0.00097784 | Loss_int: 0.00043618 | Loss_Clamped: 0.00000001 | Loss_dirichlet: 0.00000005
# Epoch 3630 | Total loss: 0.00097343 | Loss_int: 0.00043508 | Loss_Clamped: 0.00000001 | Loss_dirichlet: 0.00000005
# Epoch 3640 | Total loss: 0.00096944 | Loss_int: 0.00042943 | Loss_Clamped: 0.00000001 | Loss_dirichlet: 0.00000005
# Epoch 3650 | Total loss: 0.00095939 | Loss_int: 0.00042389 | Loss_Clamped: 0.00000001 | Loss_dirichlet: 0.00000005
# Epoch 3660 | Total loss: 0.00095220 | Loss_int: 0.00042014 | Loss_Clamped: 0.00000001 | Loss_dirichlet: 0.00000005
# Epoch 3670 | Total loss: 0.00094198 | Loss_int: 0.00041397 | Loss_Clamped: 0.00000001 | Loss_dirichlet: 0.00000005
# Epoch 3680 | Total loss: 0.00094065 | Loss_int: 0.00041069 | Loss_Clamped: 0.00000001 | Loss_dirichlet: 0.00000004
# Epoch 3690 | Total loss: 0.00094066 | Loss_int: 0.00041153 | Loss_Clamped: 0.00000001 | Loss_dirichlet: 0.00000004
# Epoch 3700 | Total loss: 0.00093361 | Loss_int: 0.00040932 | Loss_Clamped: 0.00000001 | Loss_dirichlet: 0.00000004
# Epoch 3710 | Total loss: 0.00092541 | Loss_int: 0.00040229 | Loss_Clamped: 0.00000001 | Loss_dirichlet: 0.00000004
# Epoch 3720 | Total loss: 0.00092174 | Loss_int: 0.00039883 | Loss_Clamped: 0.00000001 | Loss_dirichlet: 0.00000004
# Epoch 3730 | Total loss: 0.00091684 | Loss_int: 0.00039243 | Loss_Clamped: 0.00000001 | Loss_dirichlet: 0.00000004
# Epoch 3740 | Total loss: 0.00114761 | Loss_int: 0.00039894 | Loss_Clamped: 0.00000002 | Loss_dirichlet: 0.00000005
# Epoch 3750 | Total loss: 0.00101444 | Loss_int: 0.00039655 | Loss_Clamped: 0.00000001 | Loss_dirichlet: 0.00000005
# Epoch 3760 | Total loss: 0.00138391 | Loss_int: 0.00044709 | Loss_Clamped: 0.00000003 | Loss_dirichlet: 0.00000006
# Epoch 3770 | Total loss: 0.00104047 | Loss_int: 0.00041744 | Loss_Clamped: 0.00000001 | Loss_dirichlet: 0.00000005
# Epoch 3780 | Total loss: 0.00100666 | Loss_int: 0.00038099 | Loss_Clamped: 0.00000001 | Loss_dirichlet: 0.00000005
# Epoch 3790 | Total loss: 0.00101697 | Loss_int: 0.00039556 | Loss_Clamped: 0.00000002 | Loss_dirichlet: 0.00000005
# Epoch 3800 | Total loss: 0.00166656 | Loss_int: 0.00046042 | Loss_Clamped: 0.00000003 | Loss_dirichlet: 0.00000009
# Epoch 3810 | Total loss: 0.00163470 | Loss_int: 0.00041654 | Loss_Clamped: 0.00000006 | Loss_dirichlet: 0.00000006
# Epoch 3820 | Total loss: 0.00097821 | Loss_int: 0.00037188 | Loss_Clamped: 0.00000001 | Loss_dirichlet: 0.00000005
# Epoch 3830 | Total loss: 0.00154954 | Loss_int: 0.00042360 | Loss_Clamped: 0.00000003 | Loss_dirichlet: 0.00000008
# Epoch 3840 | Total loss: 0.00103350 | Loss_int: 0.00036189 | Loss_Clamped: 0.00000002 | Loss_dirichlet: 0.00000005
# Epoch 3850 | Total loss: 0.00110764 | Loss_int: 0.00040016 | Loss_Clamped: 0.00000002 | Loss_dirichlet: 0.00000005
# Epoch 3860 | Total loss: 0.00121192 | Loss_int: 0.00043858 | Loss_Clamped: 0.00000002 | Loss_dirichlet: 0.00000006
# Epoch 3870 | Total loss: 0.00112927 | Loss_int: 0.00041917 | Loss_Clamped: 0.00000002 | Loss_dirichlet: 0.00000005
# Epoch 3880 | Total loss: 0.00094633 | Loss_int: 0.00035755 | Loss_Clamped: 0.00000002 | Loss_dirichlet: 0.00000004
# Epoch 3890 | Total loss: 0.00089628 | Loss_int: 0.00036704 | Loss_Clamped: 0.00000001 | Loss_dirichlet: 0.00000004
# Epoch 3900 | Total loss: 0.00119900 | Loss_int: 0.00059547 | Loss_Clamped: 0.00000002 | Loss_dirichlet: 0.00000004
# Epoch 3910 | Total loss: 0.00125467 | Loss_int: 0.00041916 | Loss_Clamped: 0.00000003 | Loss_dirichlet: 0.00000005
# Epoch 3920 | Total loss: 0.00111293 | Loss_int: 0.00038460 | Loss_Clamped: 0.00000003 | Loss_dirichlet: 0.00000005
# Epoch 3930 | Total loss: 0.00098780 | Loss_int: 0.00037374 | Loss_Clamped: 0.00000002 | Loss_dirichlet: 0.00000004
# Epoch 3940 | Total loss: 0.00108328 | Loss_int: 0.00038762 | Loss_Clamped: 0.00000001 | Loss_dirichlet: 0.00000006
# Epoch 3950 | Total loss: 0.00092101 | Loss_int: 0.00035690 | Loss_Clamped: 0.00000002 | Loss_dirichlet: 0.00000004
# Epoch 3960 | Total loss: 0.00096024 | Loss_int: 0.00037045 | Loss_Clamped: 0.00000001 | Loss_dirichlet: 0.00000005
# Epoch 3970 | Total loss: 0.00155312 | Loss_int: 0.00046934 | Loss_Clamped: 0.00000004 | Loss_dirichlet: 0.00000007
# Epoch 3980 | Total loss: 0.00119524 | Loss_int: 0.00038133 | Loss_Clamped: 0.00000003 | Loss_dirichlet: 0.00000005
# Epoch 3990 | Total loss: 0.00092171 | Loss_int: 0.00035687 | Loss_Clamped: 0.00000001 | Loss_dirichlet: 0.00000004
# Epoch 4000 | Total loss: 0.00111795 | Loss_int: 0.00038281 | Loss_Clamped: 0.00000002 | Loss_dirichlet: 0.00000005
# Epoch 4010 | Total loss: 0.00087202 | Loss_int: 0.00034195 | Loss_Clamped: 0.00000001 | Loss_dirichlet: 0.00000004
# Epoch 4020 | Total loss: 0.00157181 | Loss_int: 0.00037509 | Loss_Clamped: 0.00000004 | Loss_dirichlet: 0.00000008
# Epoch 4030 | Total loss: 0.00100869 | Loss_int: 0.00037478 | Loss_Clamped: 0.00000002 | Loss_dirichlet: 0.00000004
# Epoch 4040 | Total loss: 0.00085125 | Loss_int: 0.00036041 | Loss_Clamped: 0.00000001 | Loss_dirichlet: 0.00000004
# Epoch 4050 | Total loss: 0.00124723 | Loss_int: 0.00033301 | Loss_Clamped: 0.00000003 | Loss_dirichlet: 0.00000006
# Epoch 4060 | Total loss: 0.00133661 | Loss_int: 0.00034198 | Loss_Clamped: 0.00000004 | Loss_dirichlet: 0.00000006
# Epoch 4070 | Total loss: 0.00134089 | Loss_int: 0.00038150 | Loss_Clamped: 0.00000003 | Loss_dirichlet: 0.00000007
# Epoch 4080 | Total loss: 0.00130449 | Loss_int: 0.00032867 | Loss_Clamped: 0.00000004 | Loss_dirichlet: 0.00000006
# Epoch 4090 | Total loss: 0.00083696 | Loss_int: 0.00032285 | Loss_Clamped: 0.00000001 | Loss_dirichlet: 0.00000004
# Epoch 4100 | Total loss: 0.00080295 | Loss_int: 0.00031706 | Loss_Clamped: 0.00000001 | Loss_dirichlet: 0.00000004
# Epoch 4110 | Total loss: 0.00141589 | Loss_int: 0.00035381 | Loss_Clamped: 0.00000005 | Loss_dirichlet: 0.00000006
# Epoch 4120 | Total loss: 0.00095652 | Loss_int: 0.00041044 | Loss_Clamped: 0.00000002 | Loss_dirichlet: 0.00000004
# Epoch 4130 | Total loss: 0.00110332 | Loss_int: 0.00035697 | Loss_Clamped: 0.00000003 | Loss_dirichlet: 0.00000004
# Epoch 4140 | Total loss: 0.00081836 | Loss_int: 0.00031564 | Loss_Clamped: 0.00000001 | Loss_dirichlet: 0.00000004
# Epoch 4150 | Total loss: 0.00074829 | Loss_int: 0.00029824 | Loss_Clamped: 0.00000001 | Loss_dirichlet: 0.00000004
# ...
# Epoch 6700 | Total loss: 0.00065324 | Loss_int: 0.00023821 | Loss_Clamped: 0.00000002 | Loss_dirichlet: 0.00000002
# Epoch 6710 | Total loss: 0.00180317 | Loss_int: 0.00023419 | Loss_Clamped: 0.00000006 | Loss_dirichlet: 0.00000010
# Epoch 6720 | Total loss: 0.00078966 | Loss_int: 0.00017801 | Loss_Clamped: 0.00000003 | Loss_dirichlet: 0.00000003
# Epoch 6730 | Total loss: 0.00098909 | Loss_int: 0.00025925 | Loss_Clamped: 0.00000004 | Loss_dirichlet: 0.00000003
# Epoch 6740 | Total loss: 0.00063689 | Loss_int: 0.00020534 | Loss_Clamped: 0.00000001 | Loss_dirichlet: 0.00000003
# Epoch 6750 | Total loss: 0.00089965 | Loss_int: 0.00021506 | Loss_Clamped: 0.00000004 | Loss_dirichlet: 0.00000003
# Epoch 6760 | Total loss: 0.00046786 | Loss_int: 0.00019752 | Loss_Clamped: 0.00000001 | Loss_dirichlet: 0.00000002
# Epoch 6770 | Total loss: 0.00057091 | Loss_int: 0.00018073 | Loss_Clamped: 0.00000001 | Loss_dirichlet: 0.00000003
# Epoch 6780 | Total loss: 0.00076686 | Loss_int: 0.00022608 | Loss_Clamped: 0.00000002 | Loss_dirichlet: 0.00000004
# Epoch 6790 | Total loss: 0.00057287 | Loss_int: 0.00021302 | Loss_Clamped: 0.00000001 | Loss_dirichlet: 0.00000002
# Epoch 6800 | Total loss: 0.00110059 | Loss_int: 0.00023258 | Loss_Clamped: 0.00000004 | Loss_dirichlet: 0.00000005
# Epoch 6810 | Total loss: 0.00055498 | Loss_int: 0.00020602 | Loss_Clamped: 0.00000001 | Loss_dirichlet: 0.00000002
# Epoch 6820 | Total loss: 0.00082019 | Loss_int: 0.00021529 | Loss_Clamped: 0.00000002 | Loss_dirichlet: 0.00000004
# Epoch 6830 | Total loss: 0.00109574 | Loss_int: 0.00020136 | Loss_Clamped: 0.00000005 | Loss_dirichlet: 0.00000004
# Epoch 6840 | Total loss: 0.00072592 | Loss_int: 0.00027806 | Loss_Clamped: 0.00000002 | Loss_dirichlet: 0.00000003
# Epoch 6850 | Total loss: 0.00049613 | Loss_int: 0.00019437 | Loss_Clamped: 0.00000001 | Loss_dirichlet: 0.00000002
# Epoch 6860 | Total loss: 0.00066632 | Loss_int: 0.00025155 | Loss_Clamped: 0.00000002 | Loss_dirichlet: 0.00000002
# Epoch 6870 | Total loss: 0.00086863 | Loss_int: 0.00028631 | Loss_Clamped: 0.00000003 | Loss_dirichlet: 0.00000003
# Epoch 6880 | Total loss: 0.00157420 | Loss_int: 0.00021829 | Loss_Clamped: 0.00000008 | Loss_dirichlet: 0.00000005
# Epoch 6890 | Total loss: 0.00050812 | Loss_int: 0.00019605 | Loss_Clamped: 0.00000001 | Loss_dirichlet: 0.00000002
# Epoch 6900 | Total loss: 0.00064983 | Loss_int: 0.00022305 | Loss_Clamped: 0.00000002 | Loss_dirichlet: 0.00000002
# Epoch 6910 | Total loss: 0.00053114 | Loss_int: 0.00016694 | Loss_Clamped: 0.00000001 | Loss_dirichlet: 0.00000003
# Epoch 6920 | Total loss: 0.00111604 | Loss_int: 0.00028288 | Loss_Clamped: 0.00000003 | Loss_dirichlet: 0.00000005
# Epoch 6930 | Total loss: 0.00054197 | Loss_int: 0.00021407 | Loss_Clamped: 0.00000001 | Loss_dirichlet: 0.00000002
# Epoch 6940 | Total loss: 0.00202503 | Loss_int: 0.00025748 | Loss_Clamped: 0.00000006 | Loss_dirichlet: 0.00000012
# Epoch 6950 | Total loss: 0.00097536 | Loss_int: 0.00022478 | Loss_Clamped: 0.00000004 | Loss_dirichlet: 0.00000004
# Epoch 6960 | Total loss: 0.00043409 | Loss_int: 0.00018300 | Loss_Clamped: 0.00000001 | Loss_dirichlet: 0.00000002
# Epoch 6970 | Total loss: 0.00065290 | Loss_int: 0.00024566 | Loss_Clamped: 0.00000002 | Loss_dirichlet: 0.00000002
# Epoch 6980 | Total loss: 0.00067724 | Loss_int: 0.00018940 | Loss_Clamped: 0.00000001 | Loss_dirichlet: 0.00000003
# Epoch 6990 | Total loss: 0.00094459 | Loss_int: 0.00022588 | Loss_Clamped: 0.00000003 | Loss_dirichlet: 0.00000004
# Epoch 7000 | Total loss: 0.00195885 | Loss_int: 0.00025617 | Loss_Clamped: 0.00000007 | Loss_dirichlet: 0.00000010
# Epoch 7010 | Total loss: 0.00042570 | Loss_int: 0.00018185 | Loss_Clamped: 0.00000001 | Loss_dirichlet: 0.00000002
# Epoch 7020 | Total loss: 0.00043500 | Loss_int: 0.00016842 | Loss_Clamped: 0.00000001 | Loss_dirichlet: 0.00000002
# Epoch 7030 | Total loss: 0.00143427 | Loss_int: 0.00019969 | Loss_Clamped: 0.00000007 | Loss_dirichlet: 0.00000005
# Epoch 7040 | Total loss: 0.00043691 | Loss_int: 0.00016717 | Loss_Clamped: 0.00000001 | Loss_dirichlet: 0.00000002
# Epoch 7050 | Total loss: 0.00074556 | Loss_int: 0.00016644 | Loss_Clamped: 0.00000003 | Loss_dirichlet: 0.00000003
# Epoch 7060 | Total loss: 0.00047163 | Loss_int: 0.00016313 | Loss_Clamped: 0.00000001 | Loss_dirichlet: 0.00000002
# Epoch 7070 | Total loss: 0.00054502 | Loss_int: 0.00018845 | Loss_Clamped: 0.00000001 | Loss_dirichlet: 0.00000002
# Epoch 7080 | Total loss: 0.00082917 | Loss_int: 0.00019564 | Loss_Clamped: 0.00000003 | Loss_dirichlet: 0.00000004
# Epoch 7090 | Total loss: 0.00088993 | Loss_int: 0.00021479 | Loss_Clamped: 0.00000003 | Loss_dirichlet: 0.00000004
# Epoch 7100 | Total loss: 0.00219520 | Loss_int: 0.00028977 | Loss_Clamped: 0.00000007 | Loss_dirichlet: 0.00000012
# Epoch 7110 | Total loss: 0.00062305 | Loss_int: 0.00018971 | Loss_Clamped: 0.00000001 | Loss_dirichlet: 0.00000003
# Epoch 7120 | Total loss: 0.00106598 | Loss_int: 0.00030480 | Loss_Clamped: 0.00000004 | Loss_dirichlet: 0.00000004
# Epoch 7130 | Total loss: 0.00135810 | Loss_int: 0.00029429 | Loss_Clamped: 0.00000004 | Loss_dirichlet: 0.00000006
# Epoch 7140 | Total loss: 0.00080047 | Loss_int: 0.00023543 | Loss_Clamped: 0.00000003 | Loss_dirichlet: 0.00000003
# Epoch 7150 | Total loss: 0.00078506 | Loss_int: 0.00021464 | Loss_Clamped: 0.00000002 | Loss_dirichlet: 0.00000004
# Epoch 7160 | Total loss: 0.00043425 | Loss_int: 0.00018098 | Loss_Clamped: 0.00000001 | Loss_dirichlet: 0.00000002
# Epoch 7170 | Total loss: 0.00079693 | Loss_int: 0.00021863 | Loss_Clamped: 0.00000002 | Loss_dirichlet: 0.00000004
# Epoch 7180 | Total loss: 0.00141189 | Loss_int: 0.00037685 | Loss_Clamped: 0.00000006 | Loss_dirichlet: 0.00000004
# Epoch 7190 | Total loss: 0.00053262 | Loss_int: 0.00019737 | Loss_Clamped: 0.00000001 | Loss_dirichlet: 0.00000002
# Epoch 7200 | Total loss: 0.00036680 | Loss_int: 0.00014980 | Loss_Clamped: 0.00000001 | Loss_dirichlet: 0.00000002
# Epoch 7210 | Total loss: 0.00134591 | Loss_int: 0.00024733 | Loss_Clamped: 0.00000005 | Loss_dirichlet: 0.00000006
# Epoch 7220 | Total loss: 0.00046094 | Loss_int: 0.00020723 | Loss_Clamped: 0.00000001 | Loss_dirichlet: 0.00000002
# Epoch 7230 | Total loss: 0.00096341 | Loss_int: 0.00024965 | Loss_Clamped: 0.00000003 | Loss_dirichlet: 0.00000004
# Epoch 7240 | Total loss: 0.00044598 | Loss_int: 0.00016508 | Loss_Clamped: 0.00000001 | Loss_dirichlet: 0.00000002
# Epoch 7250 | Total loss: 0.00068016 | Loss_int: 0.00019715 | Loss_Clamped: 0.00000002 | Loss_dirichlet: 0.00000003
# Epoch 7260 | Total loss: 0.00043003 | Loss_int: 0.00016944 | Loss_Clamped: 0.00000001 | Loss_dirichlet: 0.00000002
# Epoch 7270 | Total loss: 0.00035099 | Loss_int: 0.00014545 | Loss_Clamped: 0.00000000 | Loss_dirichlet: 0.00000002
# Epoch 7280 | Total loss: 0.00200619 | Loss_int: 0.00031382 | Loss_Clamped: 0.00000005 | Loss_dirichlet: 0.00000012
# Epoch 7290 | Total loss: 0.00056550 | Loss_int: 0.00018198 | Loss_Clamped: 0.00000002 | Loss_dirichlet: 0.00000002
# Epoch 7300 | Total loss: 0.00065947 | Loss_int: 0.00018975 | Loss_Clamped: 0.00000002 | Loss_dirichlet: 0.00000003
# Epoch 7310 | Total loss: 0.00041106 | Loss_int: 0.00016374 | Loss_Clamped: 0.00000001 | Loss_dirichlet: 0.00000002
# Epoch 7320 | Total loss: 0.00058911 | Loss_int: 0.00020095 | Loss_Clamped: 0.00000002 | Loss_dirichlet: 0.00000002
# Epoch 7330 | Total loss: 0.00048103 | Loss_int: 0.00018228 | Loss_Clamped: 0.00000001 | Loss_dirichlet: 0.00000002
# Epoch 7340 | Total loss: 0.00048211 | Loss_int: 0.00021461 | Loss_Clamped: 0.00000001 | Loss_dirichlet: 0.00000002
# Epoch 7350 | Total loss: 0.00049444 | Loss_int: 0.00014738 | Loss_Clamped: 0.00000001 | Loss_dirichlet: 0.00000002
# Epoch 7360 | Total loss: 0.00040587 | Loss_int: 0.00016544 | Loss_Clamped: 0.00000001 | Loss_dirichlet: 0.00000002
# Epoch 7370 | Total loss: 0.00088655 | Loss_int: 0.00022182 | Loss_Clamped: 0.00000004 | Loss_dirichlet: 0.00000003
# Epoch 7380 | Total loss: 0.00049003 | Loss_int: 0.00017216 | Loss_Clamped: 0.00000001 | Loss_dirichlet: 0.00000002
# Epoch 7390 | Total loss: 0.00067718 | Loss_int: 0.00018658 | Loss_Clamped: 0.00000002 | Loss_dirichlet: 0.00000003
# Epoch 7400 | Total loss: 0.00117182 | Loss_int: 0.00028455 | Loss_Clamped: 0.00000005 | Loss_dirichlet: 0.00000004
# Epoch 7410 | Total loss: 0.00107487 | Loss_int: 0.00023982 | Loss_Clamped: 0.00000002 | Loss_dirichlet: 0.00000006
# Epoch 7420 | Total loss: 0.00067358 | Loss_int: 0.00025462 | Loss_Clamped: 0.00000001 | Loss_dirichlet: 0.00000003
# Epoch 7430 | Total loss: 0.00090399 | Loss_int: 0.00017290 | Loss_Clamped: 0.00000004 | Loss_dirichlet: 0.00000003
# Epoch 7440 | Total loss: 0.00069775 | Loss_int: 0.00021271 | Loss_Clamped: 0.00000002 | Loss_dirichlet: 0.00000003
# Epoch 7450 | Total loss: 0.00055915 | Loss_int: 0.00016658 | Loss_Clamped: 0.00000002 | Loss_dirichlet: 0.00000002
# Epoch 7460 | Total loss: 0.00041865 | Loss_int: 0.00014866 | Loss_Clamped: 0.00000001 | Loss_dirichlet: 0.00000002
# Epoch 7470 | Total loss: 0.00047569 | Loss_int: 0.00018779 | Loss_Clamped: 0.00000001 | Loss_dirichlet: 0.00000002
# Epoch 7480 | Total loss: 0.00046334 | Loss_int: 0.00017384 | Loss_Clamped: 0.00000001 | Loss_dirichlet: 0.00000002
# Epoch 7490 | Total loss: 0.00051740 | Loss_int: 0.00017038 | Loss_Clamped: 0.00000001 | Loss_dirichlet: 0.00000002
# Epoch 7500 | Total loss: 0.00112872 | Loss_int: 0.00027082 | Loss_Clamped: 0.00000004 | Loss_dirichlet: 0.00000004
# Epoch 7510 | Total loss: 0.00062996 | Loss_int: 0.00023440 | Loss_Clamped: 0.00000002 | Loss_dirichlet: 0.00000002
# Epoch 7520 | Total loss: 0.00059157 | Loss_int: 0.00020560 | Loss_Clamped: 0.00000001 | Loss_dirichlet: 0.00000003
# Epoch 7530 | Total loss: 0.00056426 | Loss_int: 0.00019850 | Loss_Clamped: 0.00000001 | Loss_dirichlet: 0.00000003
# Epoch 7540 | Total loss: 0.00068182 | Loss_int: 0.00021524 | Loss_Clamped: 0.00000002 | Loss_dirichlet: 0.00000003
# Epoch 7550 | Total loss: 0.00049361 | Loss_int: 0.00018699 | Loss_Clamped: 0.00000001 | Loss_dirichlet: 0.00000002
# Epoch 7560 | Total loss: 0.00089741 | Loss_int: 0.00016596 | Loss_Clamped: 0.00000003 | Loss_dirichlet: 0.00000004
# Epoch 7570 | Total loss: 0.00049636 | Loss_int: 0.00020706 | Loss_Clamped: 0.00000001 | Loss_dirichlet: 0.00000002
# Epoch 7580 | Total loss: 0.00073846 | Loss_int: 0.00017196 | Loss_Clamped: 0.00000003 | Loss_dirichlet: 0.00000003
# Epoch 7590 | Total loss: 0.00043556 | Loss_int: 0.00014655 | Loss_Clamped: 0.00000001 | Loss_dirichlet: 0.00000002
# Epoch 7600 | Total loss: 0.00033861 | Loss_int: 0.00014148 | Loss_Clamped: 0.00000000 | Loss_dirichlet: 0.00000002
# Epoch 7610 | Total loss: 0.00037443 | Loss_int: 0.00015352 | Loss_Clamped: 0.00000001 | Loss_dirichlet: 0.00000002
# Epoch 7620 | Total loss: 0.00066973 | Loss_int: 0.00020893 | Loss_Clamped: 0.00000002 | Loss_dirichlet: 0.00000002
# Epoch 7630 | Total loss: 0.00074527 | Loss_int: 0.00022973 | Loss_Clamped: 0.00000002 | Loss_dirichlet: 0.00000003
# Epoch 7640 | Total loss: 0.00042739 | Loss_int: 0.00016100 | Loss_Clamped: 0.00000001 | Loss_dirichlet: 0.00000002
# Epoch 7650 | Total loss: 0.00060123 | Loss_int: 0.00017285 | Loss_Clamped: 0.00000002 | Loss_dirichlet: 0.00000002
# Epoch 7660 | Total loss: 0.00081613 | Loss_int: 0.00037595 | Loss_Clamped: 0.00000002 | Loss_dirichlet: 0.00000002
# Epoch 7670 | Total loss: 0.00040754 | Loss_int: 0.00014853 | Loss_Clamped: 0.00000001 | Loss_dirichlet: 0.00000002
# Epoch 7680 | Total loss: 0.00160027 | Loss_int: 0.00019848 | Loss_Clamped: 0.00000005 | Loss_dirichlet: 0.00000009
# Epoch 7690 | Total loss: 0.00065373 | Loss_int: 0.00017596 | Loss_Clamped: 0.00000002 | Loss_dirichlet: 0.00000003
# Epoch 7700 | Total loss: 0.00056557 | Loss_int: 0.00019962 | Loss_Clamped: 0.00000002 | Loss_dirichlet: 0.00000002
# Epoch 7710 | Total loss: 0.00041674 | Loss_int: 0.00018154 | Loss_Clamped: 0.00000001 | Loss_dirichlet: 0.00000002
# Epoch 7720 | Total loss: 0.00034717 | Loss_int: 0.00014478 | Loss_Clamped: 0.00000000 | Loss_dirichlet: 0.00000002
# Epoch 7730 | Total loss: 0.00066326 | Loss_int: 0.00017611 | Loss_Clamped: 0.00000002 | Loss_dirichlet: 0.00000002
# Epoch 7740 | Total loss: 0.00036385 | Loss_int: 0.00015389 | Loss_Clamped: 0.00000001 | Loss_dirichlet: 0.00000002
# Epoch 7750 | Total loss: 0.00043726 | Loss_int: 0.00017469 | Loss_Clamped: 0.00000001 | Loss_dirichlet: 0.00000002
# Epoch 7760 | Total loss: 0.00041391 | Loss_int: 0.00016497 | Loss_Clamped: 0.00000001 | Loss_dirichlet: 0.00000002
# Epoch 7770 | Total loss: 0.00066541 | Loss_int: 0.00017220 | Loss_Clamped: 0.00000002 | Loss_dirichlet: 0.00000003
# Epoch 7780 | Total loss: 0.00055495 | Loss_int: 0.00018259 | Loss_Clamped: 0.00000002 | Loss_dirichlet: 0.00000002
# Epoch 7790 | Total loss: 0.00040536 | Loss_int: 0.00017342 | Loss_Clamped: 0.00000001 | Loss_dirichlet: 0.00000002
# Epoch 7800 | Total loss: 0.00063131 | Loss_int: 0.00016622 | Loss_Clamped: 0.00000002 | Loss_dirichlet: 0.00000002
# Epoch 7810 | Total loss: 0.00035364 | Loss_int: 0.00014855 | Loss_Clamped: 0.00000000 | Loss_dirichlet: 0.00000002
# Epoch 7820 | Total loss: 0.00241674 | Loss_int: 0.00034946 | Loss_Clamped: 0.00000014 | Loss_dirichlet: 0.00000007
# Epoch 7830 | Total loss: 0.00129183 | Loss_int: 0.00028468 | Loss_Clamped: 0.00000005 | Loss_dirichlet: 0.00000005
# Epoch 7840 | Total loss: 0.00043793 | Loss_int: 0.00016282 | Loss_Clamped: 0.00000001 | Loss_dirichlet: 0.00000002
# Epoch 7850 | Total loss: 0.00046847 | Loss_int: 0.00017276 | Loss_Clamped: 0.00000001 | Loss_dirichlet: 0.00000002
# Epoch 7860 | Total loss: 0.00271986 | Loss_int: 0.00023407 | Loss_Clamped: 0.00000009 | Loss_dirichlet: 0.00000016
# Epoch 7870 | Total loss: 0.00052172 | Loss_int: 0.00017053 | Loss_Clamped: 0.00000001 | Loss_dirichlet: 0.00000002
# Epoch 7880 | Total loss: 0.00113263 | Loss_int: 0.00023325 | Loss_Clamped: 0.00000005 | Loss_dirichlet: 0.00000004
# Epoch 7890 | Total loss: 0.00052427 | Loss_int: 0.00017835 | Loss_Clamped: 0.00000001 | Loss_dirichlet: 0.00000002
# Epoch 7900 | Total loss: 0.00059513 | Loss_int: 0.00020832 | Loss_Clamped: 0.00000002 | Loss_dirichlet: 0.00000002
# Epoch 7910 | Total loss: 0.00043402 | Loss_int: 0.00015977 | Loss_Clamped: 0.00000001 | Loss_dirichlet: 0.00000002
# Epoch 7920 | Total loss: 0.00067335 | Loss_int: 0.00016282 | Loss_Clamped: 0.00000003 | Loss_dirichlet: 0.00000003
# Epoch 7930 | Total loss: 0.00057127 | Loss_int: 0.00015994 | Loss_Clamped: 0.00000001 | Loss_dirichlet: 0.00000003
# Epoch 7940 | Total loss: 0.00064403 | Loss_int: 0.00016159 | Loss_Clamped: 0.00000002 | Loss_dirichlet: 0.00000003
# Epoch 7950 | Total loss: 0.00069852 | Loss_int: 0.00020942 | Loss_Clamped: 0.00000002 | Loss_dirichlet: 0.00000003
# Epoch 7960 | Total loss: 0.00047053 | Loss_int: 0.00020192 | Loss_Clamped: 0.00000001 | Loss_dirichlet: 0.00000002
# Epoch 7970 | Total loss: 0.00064606 | Loss_int: 0.00020025 | Loss_Clamped: 0.00000002 | Loss_dirichlet: 0.00000003
# Epoch 7980 | Total loss: 0.00077209 | Loss_int: 0.00024958 | Loss_Clamped: 0.00000003 | Loss_dirichlet: 0.00000002
# Epoch 7990 | Total loss: 0.00036876 | Loss_int: 0.00015019 | Loss_Clamped: 0.00000001 | Loss_dirichlet: 0.00000002
# Training finished.
# Calculating final errors...
# Relative L2 Error: 1.4162e-02
# Relative H1 Error: 6.9963e-03
# Relative H2 Error: 1.0545e-02
# Plotting loss history...
#
# ---Training Summary ---
# Device: cpu
#
# [Network Architecture]
# NN(
#   (L1): Linear(in_features=2, out_features=60, bias=True)
#   (L2): Linear(in_features=60, out_features=60, bias=True)
#   (L3): Linear(in_features=60, out_features=60, bias=True)
#   (L4): Linear(in_features=60, out_features=60, bias=True)
#   (L5): Linear(in_features=60, out_features=60, bias=True)
#   (L6): Linear(in_features=60, out_features=1, bias=True)
# )
#
# [Hyperparameters]
#   Optimizer: Adam (lr=0.001)
#   Epochs (Adam): 8000
#   Batch Size: 2000
#   Interior Points: 20000
#   Boundary Points: 10000
#   Loss Weight (Dirichlet): 1.0e+04
#   Loss Weight (Clamped): 1.0e+04
#
# [Performance]
#   Training Time: 44216.61 seconds
#   Total Script Time: 44218.29 seconds
#   Final Total Loss: 2.4768e-03
#   Relative L2 Error: 1.4162e-02
#   Relative H1 Error: 6.9963e-03
#   Relative H2 Error: 1.0545e-02
# Plotting 3D solution comparison...
